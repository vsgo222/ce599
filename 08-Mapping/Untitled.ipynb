# %%
import pandas as pd
import numpy as np

# These files use \N as a missing value indicator.  When reading the CSVs, we will tell
# it to use that value as missing or NA.  The double backslash is required because
# otherwise it will interpret \N as a carriage return. 

# Read in the airports data.
airports = pd.read_csv("data/airports.dat", header=None, na_values='\\N')
airports.columns = ["id", "name", "city", "country", "iata", "icao", "latitude", "longitude", "altitude","timezone", "dst", "tz", "type", "source"]

# Read in the airlines data.
airlines = pd.read_csv("data/airlines.dat", header=None, na_values='\\N')
airlines.columns = ["id", "name", "alias", "iata", "icao", "callsign", "country", "active"]

# Read in the routes data.
routes = pd.read_csv("data/routes.dat", header=None, na_values='\\N')
routes.columns = ["airline", "airline_id", "source", "source_id", "dest", "dest_id", "codeshare", "stops", "equipment"]

# %%
routes
# Out:
#       airline  airline_id source  source_id dest  dest_id codeshare  stops  \
# 0          2B       410.0    AER     2965.0  KZN   2990.0       NaN      0
# 1          2B       410.0    ASF     2966.0  KZN   2990.0       NaN      0
# 2          2B       410.0    ASF     2966.0  MRV   2962.0       NaN      0
# 3          2B       410.0    CEK     2968.0  KZN   2990.0       NaN      0
# 4          2B       410.0    CEK     2968.0  OVB   4078.0       NaN      0
# ...       ...         ...    ...        ...  ...      ...       ...    ...
# 67658      ZL      4178.0    WYA     6334.0  ADL   3341.0       NaN      0
# 67659      ZM     19016.0    DME     4029.0  FRU   2912.0       NaN      0
# 67660      ZM     19016.0    FRU     2912.0  DME   4029.0       NaN      0
# 67661      ZM     19016.0    FRU     2912.0  OSS   2913.0       NaN      0
# 67662      ZM     19016.0    OSS     2913.0  FRU   2912.0       NaN      0
#
#       equipment
# 0           CR2
# 1           CR2
# 2           CR2
# 3           CR2
# 4           CR2
# ...         ...
# 67658       SF3
# 67659       734
# 67660       734
# 67661       734
# 67662       734
#
# [67663 rows x 9 columns]

# %%
route_sub = routes[["source","dest"]]
cUnique = set()
cUnique.add("LEX")
lexroutes = routes[routes["source"]=="LEX"]
lexroutes = routes[routes["source"]=="LEX"].drop_duplicates(subset=["source","dest"])[["source","dest"]]
clist = lexroutes["dest"].to_list()
cUnique = cUnique.union(clist)

# %%
lexroutes
# Out:
#       source dest
# 3588     LEX  ATL
# 5763     LEX  CLT
# 5764     LEX  DFW
# 5765     LEX  ORD
# 21096    LEX  DCA
# 21097    LEX  DTW
# 21098    LEX  LGA
# 21099    LEX  MSP
# 29047    LEX  FLL
# 29048    LEX  PGD
# 29049    LEX  PIE
# 29050    LEX  SFB
# 57029    LEX  IAH

# %%
cUnique
# Out:
# {'ATL',
#  'CLT',
#  'DCA',
#  'DFW',
#  'DTW',
#  'FLL',
#  'IAH',
#  'LEX',
#  'LGA',
#  'MSP',
#  'ORD',
#  'PGD',
#  'PIE',
#  'SFB'}

# %%
def unique_func(df,cUnique):
    for row in df.iterrows():
        if row["dest_1"] in cUnique:
            bValue = True
        else:
            bValue = False
    return bValue

# %%
temp = pd.merge(lexroutes,route_sub,left_on="dest",right_on="source", how="inner",suffixes=('_org', '_1'))
temp["drop"]=temp["dest_1"].apply(lambda x: x in cUnique)
temp[["source_org","source_1","dest_1","drop"]]
# Out:
#      source_org source_1 dest_1   drop
# 0           LEX      ATL    LWB  False
# 1           LEX      ATL    MCN  False
# 2           LEX      ATL    MEI  False
# 3           LEX      ATL    MSL  False
# 4           LEX      ATL    PIB  False
# ...         ...      ...    ...    ...
# 3553        LEX      IAH    PHX  False
# 3554        LEX      IAH    SAL  False
# 3555        LEX      IAH    ATL   True
# 3556        LEX      IAH    MTY  False
# 3557        LEX      IAH    ATL   True
#
# [3558 rows x 4 columns]

# %%
# get the first transfer list and connections
xfer1 = pd.merge(lexroutes,route_sub,left_on="dest",right_on="source", how="inner",suffixes=('_org', '_1'))
xfer1["drop"] = xfer1["dest_1"].apply(lambda x: x in cUnique)
xfer1 = xfer1[xfer1["drop"]==True]
clist = xfer1["dest_1"].to_list()
cUnique = cUnique.union(clist)
xfer1.drop(['drop'], axis=1, inplace=True)
xfer1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 402 entries, 16 to 3557
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   source_org  402 non-null    object
#  1   dest_org    402 non-null    object
#  2   source_1    402 non-null    object
#  3   dest_1      402 non-null    object
# dtypes: object(4)
# memory usage: 15.7+ KB

# %%
# get the second transfer list and connections
xfer2 = pd.merge(xfer1,route_sub,left_on="dest_1",right_on="source", how="inner")
xfer2["drop"] = xfer2["dest"].apply(lambda x: x in cUnique)
xfer2 = xfer2[xfer2["drop"]==True]
clist = xfer2["dest"].to_list()
cUnique = cUnique.union(clist)
xfer2.drop(['drop'], axis=1, inplace=True)
xfer2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 18690 entries, 0 to 168708
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   source_org  18690 non-null  object
#  1   dest_org    18690 non-null  object
#  2   source_1    18690 non-null  object
#  3   dest_1      18690 non-null  object
#  4   source      18690 non-null  object
#  5   dest        18690 non-null  object
# dtypes: object(6)
# memory usage: 1022.1+ KB

# %%
xfer_final = xfer2[["source","dest"]]
xfer_final.drop_duplicates()
# Out:
#       source dest
# 0        LEX  ATL
# 1        LEX  CLT
# 2        LEX  DFW
# 3        LEX  ORD
# 6        LEX  DCA
# ...      ...  ...
# 91922    ATL  DCA
# 91927    ATL  DTW
# 91938    ATL  FLL
# 91955    ATL  IAH
# 91966    ATL  LGA
#
# [113 rows x 2 columns]

# %%
# Select the LEX routes, then join the source airports
lex_routes = xfer_final[(xfer_final['source']=="LEX")]
lex_routes = pd.merge(xfer_final, airports, left_on='source', right_on='iata', how='left')

# join the destination airports.  Here we need to use the suffixes option, because 
# the column names overlap, and we want to distinguish between source and dest
lex_routes = pd.merge(lex_routes, airports, 
                      left_on='dest', 
                      right_on='iata', 
                      how='left', 
                      suffixes=['_source','_dest'])

# here is what our data looks like
# lex_routes

# %%
# It looks like source has some duplicate names.  Drop the values from the airports
# file ane keep the one from the routes file
lex_routes = lex_routes.drop(['source_y','source'], axis=1)
lex_routes = lex_routes.rename(columns={'source_x': 'source'})

# %%
lunique = lex_routes["source"].unique
lunique
# Out:
# <bound method Series.unique of 0        LEX
# 1        LEX
# 2        LEX
# 3        LEX
# 6        LEX
#         ...
# 11136    ATL
# 11138    ATL
# 11139    ATL
# 11140    ATL
# 11142    ATL
# Name: source, Length: 113, dtype: object>

# %%
# Let's keep only one route between each airport pair
# so we don't have a bunch of lines on top of each other
# The subset option tells it to consider just those columns when determining
# what is a duplicate. 

lex_routes = lex_routes.drop_duplicates(subset=['source', 'dest'])
lex_routes.head(50)
# Out:
#      source dest  id_source  \
# 0       LEX  ATL       4017
# 1       LEX  CLT       4017
# 2       LEX  DFW       4017
# 3       LEX  ORD       4017
# 6       LEX  DCA       4017
# 7       LEX  DTW       4017
# 8       LEX  LGA       4017
# 9       LEX  MSP       4017
# 10      LEX  FLL       4017
# 11      LEX  PGD       4017
# 12      LEX  PIE       4017
# 13      LEX  SFB       4017
# 15      LEX  IAH       4017
# 400     MSP  ATL       3858
# 401     MSP  CLT       3858
# 402     MSP  DCA       3858
# 403     MSP  DFW       3858
# 404     MSP  ORD       3858
# 411     MSP  DTW       3858
# 412     MSP  FLL       3858
# 413     MSP  IAH       3858
# 414     MSP  LEX       3858
# 415     MSP  LGA       3858
# 1361    CLT  ATL       3876
# 1362    CLT  DCA       3876
# 1363    CLT  DFW       3876
# 1364    CLT  DTW       3876
# 1365    CLT  FLL       3876
# 1366    CLT  IAH       3876
# 1367    CLT  LEX       3876
# 1368    CLT  LGA       3876
# 1369    CLT  MSP       3876
# 1370    CLT  ORD       3876
# 2260    DFW  ATL       3670
# 2261    DFW  CLT       3670
# 2262    DFW  DCA       3670
# 2263    DFW  DTW       3670
# 2264    DFW  FLL       3670
# 2265    DFW  IAH       3670
# 2266    DFW  LEX       3670
# 2267    DFW  LGA       3670
# 2268    DFW  MSP       3670
# 2269    DFW  ORD       3670
# 3742    ORD  ATL       3830
# 3743    ORD  CLT       3830
# 3744    ORD  DCA       3830
# 3745    ORD  DFW       3830
# 3746    ORD  DTW       3830
# 3747    ORD  FLL       3830
# 3748    ORD  IAH       3830
#
#                                             name_source        city_source  \
# 0                                    Blue Grass Airport       Lexington KY
# 1                                    Blue Grass Airport       Lexington KY
# 2                                    Blue Grass Airport       Lexington KY
# 3                                    Blue Grass Airport       Lexington KY
# 6                                    Blue Grass Airport       Lexington KY
# 7                                    Blue Grass Airport       Lexington KY
# 8                                    Blue Grass Airport       Lexington KY
# 9                                    Blue Grass Airport       Lexington KY
# 10                                   Blue Grass Airport       Lexington KY
# 11                                   Blue Grass Airport       Lexington KY
# 12                                   Blue Grass Airport       Lexington KY
# 13                                   Blue Grass Airport       Lexington KY
# 15                                   Blue Grass Airport       Lexington KY
# 400   Minneapolis-St Paul International/Wold-Chamber...        Minneapolis
# 401   Minneapolis-St Paul International/Wold-Chamber...        Minneapolis
# 402   Minneapolis-St Paul International/Wold-Chamber...        Minneapolis
# 403   Minneapolis-St Paul International/Wold-Chamber...        Minneapolis
# 404   Minneapolis-St Paul International/Wold-Chamber...        Minneapolis
# 411   Minneapolis-St Paul International/Wold-Chamber...        Minneapolis
# 412   Minneapolis-St Paul International/Wold-Chamber...        Minneapolis
# 413   Minneapolis-St Paul International/Wold-Chamber...        Minneapolis
# 414   Minneapolis-St Paul International/Wold-Chamber...        Minneapolis
# 415   Minneapolis-St Paul International/Wold-Chamber...        Minneapolis
# 1361            Charlotte Douglas International Airport          Charlotte
# 1362            Charlotte Douglas International Airport          Charlotte
# 1363            Charlotte Douglas International Airport          Charlotte
# 1364            Charlotte Douglas International Airport          Charlotte
# 1365            Charlotte Douglas International Airport          Charlotte
# 3744        -87.904800  ...  United States        DCA      KDCA     38.852100
# 3745        -87.904800  ...  United States        DFW      KDFW     32.896801
# 3746        -87.904800  ...  United States        DTW      KDTW     42.212399
# 3747        -87.904800  ...  United States        FLL      KFLL     26.072599
# 3748        -87.904800  ...  United States        IAH      KIAH     29.984400
#
#      longitude_dest  altitude_dest timezone_dest dst_dest           tz_dest  \
# 0        -84.428101           1026          -5.0        A  America/New_York
# 1        -80.943100            748          -5.0        A  America/New_York
# 2        -97.038002            607          -6.0        A   America/Chicago
# 3        -87.904800            672          -6.0        A   America/Chicago
# 6        -77.037697             15          -5.0        A  America/New_York
# 7        -83.353401            645          -5.0        A  America/New_York
# 8        -73.872597             21          -5.0        A  America/New_York
# 9        -93.221802            841          -6.0        A   America/Chicago
# 10       -80.152702              9          -5.0        A  America/New_York
# 11       -81.990501             26          -5.0        A  America/New_York
# 12       -82.687401             11          -5.0        A  America/New_York
# 13       -81.237503             55          -5.0        A  America/New_York
# 15       -95.341400             97          -6.0        A   America/Chicago
# 400      -84.428101           1026          -5.0        A  America/New_York
# 401      -80.943100            748          -5.0        A  America/New_York
# 402      -77.037697             15          -5.0        A  America/New_York
# 403      -97.038002            607          -6.0        A   America/Chicago
# 404      -87.904800            672          -6.0        A   America/Chicago
# 411      -83.353401            645          -5.0        A  America/New_York
# 412      -80.152702              9          -5.0        A  America/New_York
# 413      -95.341400             97          -6.0        A   America/Chicago
# 414      -84.605904            979          -5.0        A  America/New_York
# 415      -73.872597             21          -5.0        A  America/New_York
# 1361     -84.428101           1026          -5.0        A  America/New_York
# 1362     -77.037697             15          -5.0        A  America/New_York
# 1363     -97.038002            607          -6.0        A   America/Chicago
# 1364     -83.353401            645          -5.0        A  America/New_York
# 1365     -80.152702              9          -5.0        A  America/New_York
# 1366     -95.341400             97          -6.0        A   America/Chicago
# 1367     -84.605904            979          -5.0        A  America/New_York
# 1368     -73.872597             21          -5.0        A  America/New_York
# 1369     -93.221802            841          -6.0        A   America/Chicago
# 1370     -87.904800            672          -6.0        A   America/Chicago
# 2260     -84.428101           1026          -5.0        A  America/New_York
# 2261     -80.943100            748          -5.0        A  America/New_York
# 2262     -77.037697             15          -5.0        A  America/New_York
# 2263     -83.353401            645          -5.0        A  America/New_York
# 2264     -80.152702              9          -5.0        A  America/New_York
# 2265     -95.341400             97          -6.0        A   America/Chicago
# 2266     -84.605904            979          -5.0        A  America/New_York
# 2267     -73.872597             21          -5.0        A  America/New_York
# 2268     -93.221802            841          -6.0        A   America/Chicago
# 2269     -87.904800            672          -6.0        A   America/Chicago
# 3742     -84.428101           1026          -5.0        A  America/New_York
# 3743     -80.943100            748          -5.0        A  America/New_York
# 3744     -77.037697             15          -5.0        A  America/New_York
# 3745     -97.038002            607          -6.0        A   America/Chicago
# 3746     -83.353401            645          -5.0        A  America/New_York
# 3747     -80.152702              9          -5.0        A  America/New_York
# 3748     -95.341400             97          -6.0        A   America/Chicago
#
#      type_dest
# 0      airport
# 1      airport
# 2      airport
# 3      airport
# 6      airport
# 7      airport
# 8      airport
# 9      airport
# 10     airport
# 11     airport
# 12     airport
# 13     airport
# 15     airport
# 400    airport
# 401    airport
# 402    airport
# 403    airport
# 404    airport
# 411    airport
# 412    airport
# 413    airport
# 414    airport
# 415    airport
# 1361   airport
# 1362   airport
# 1363   airport
# 1364   airport
# 1365   airport
# 1366   airport
# 1367   airport
# 1368   airport
# 1369   airport
# 1370   airport
# 2260   airport
# 2261   airport
# 2262   airport
# 2263   airport
# 2264   airport
# 2265   airport
# 2266   airport
# 2267   airport
# 2268   airport
# 2269   airport
# 3742   airport
# 3743   airport
# 3744   airport
# 3745   airport
# 3746   airport
# 3747   airport
# 3748   airport
#
# [50 rows x 28 columns]

# %%
import folium
# create a basic map, centered on Lexington
lex_air = folium.Map(
    location=[38.034,-84.500],
    tiles='Stamen Toner',
    zoom_start=4
)

# %%
import pyproj

# when creating a function, it is good practice to define the API!
def getGreatCirclePoints(startlat, startlon, endlat, endlon): 
    """
    startlat - starting latitude 
    startlon - starting longitude 
    endlat   - ending latitude 
    endlon   - ending longitude 
    
    returns - a list of tuples, where each tuple is the lat-long for a point
              along the curve.  
    """
    # calculate distance between points
    g = pyproj.Geod(ellps='WGS84')
    (az12, az21, dist) = g.inv(startlon, startlat, endlon, endlat)

    # calculate line string along path with segments <= 20 km
    lonlats = g.npts(startlon, startlat, endlon, endlat,
                     1 + int(dist / 20000))

    # the npts function uses lon-lat, while the folium functions use lat-lon
    # This sort of thing is maddening!  What happens is the lines don't show
    # up on the map and you don't know why.  Learn from my mistakes
    latlons = []
    for lon_lat in lonlats: 
        
        # this is how you get values out of a tuple
        (lon, lat) = lon_lat
        
        # add them to our list
        latlons.append((lat, lon)) 
    
    # npts doesn't include start/end points, so prepend/append them
    latlons.insert(0, (startlat, startlon))
    latlons.append((endlat, endlon))
    
    return latlons

# %%
# define the map in the same way, but use great circles for the lines

# Define some empty sets
airport_set = set()
route_set = set()

# Make sure we don't add duplicates, especially for the origins
for name, row in lex_routes.iterrows():
    
    if row['source'] not in airport_set: 
        popup_string = row['city_source'] + ' (' + row['source'] + ')'
        marker = folium.CircleMarker([row["latitude_source"], row["longitude_source"]], 
                                     color='DarkCyan',
                                     fill_color='DarkCyan', 
                                     radius=5, popup=popup_string)
        marker.add_to(lex_air)
        airport_set.add(row['source'])
        
    if row['dest'] not in airport_set: 
        popup_string = row['city_dest'] + '(' + row['dest'] + ')'
        marker = folium.CircleMarker([row["latitude_dest"], row["longitude_dest"]], 
                                     color='MidnightBlue',
                                     fill_color='MidnightBlue', 
                                     radius=5, popup=popup_string)
        marker.add_to(lex_air)
        airport_set.add(row['dest'])
    
    # PolyLine will accept a whole list of tuples, not just two
    if (row['source'],row['dest']) not in route_set:            
        popup_string = row['source'] + '-' + row['dest']       
        
        gc_points = getGreatCirclePoints(row["latitude_source"], 
                                         row["longitude_source"], 
                                         row["latitude_dest"], 
                                         row["longitude_dest"])
        
        line = folium.PolyLine(gc_points, weight=2, popup=popup_string)
        line.add_to(lex_air)
        route_set.add((row['source'],row['dest']))
        
lex_air
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
lex_routes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 18690 entries, 0 to 18689
# Data columns (total 30 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   source_x          18690 non-null  object
#  1   dest              18690 non-null  object
#  2   id_source         18690 non-null  int64
#  3   name_source       18690 non-null  object
#  4   city_source       18690 non-null  object
#  5   country_source    18690 non-null  object
#  6   iata_source       18690 non-null  object
#  7   icao_source       18690 non-null  object
#  8   latitude_source   18690 non-null  float64
#  9   longitude_source  18690 non-null  float64
#  10  altitude_source   18690 non-null  int64
#  11  timezone_source   18690 non-null  float64
#  12  dst_source        18690 non-null  object
#  13  tz_source         18690 non-null  object
#  14  type_source       18690 non-null  object
#  15  source_y          18690 non-null  object
#  16  id_dest           18690 non-null  int64
#  17  name_dest         18690 non-null  object
#  18  city_dest         18690 non-null  object
#  19  country_dest      18690 non-null  object
#  20  iata_dest         18690 non-null  object
#  21  icao_dest         18690 non-null  object
#  22  latitude_dest     18690 non-null  float64
#  23  longitude_dest    18690 non-null  float64
#  24  altitude_dest     18690 non-null  int64
#  25  timezone_dest     18690 non-null  float64
#  26  dst_dest          18690 non-null  object
#  27  tz_dest           18690 non-null  object
#  28  type_dest         18690 non-null  object
#  29  source            18690 non-null  object
# dtypes: float64(6), int64(4), object(20)
# memory usage: 4.4+ MB
