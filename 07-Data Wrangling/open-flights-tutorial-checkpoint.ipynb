# %% [markdown]
# ### Open Flights Data Wrangling
#
# To practice, you are going to wrangle data from OpenFlights.  You can read about it here:
#
# http://openflights.org/data.html
#
# This includes five files:
#
# 1. A file with one record for each airport,
# 2. A file with one record for each airline,
# 3. A file with one record for each each route,
# 4. A file with one record for each type of airplane, and
# 5. A file with one record for each country.
#
# Each file has a relationship to the others, with some fields in common.  To make best use of the data, we will need to combine all three files.  This is the core challenge of relational databases.  This lesson looks at how to do that, specifically using the merge() function in python.
#
# Credits:
#
# This lesson draws from the Data Analysis and Visualization in Python for Ecologists course by Data Carpentry:
#
# https://datacarpentry.org/python-ecology-lesson/05-merging-data/index.html
#
# and from the pandas documentation:
#
# https://pandas.pydata.org/pandas-docs/stable/user_guide/merging.html

# %% [markdown]
# ### Learning Objectives:
#
# 1. Understand the meaning of relational data and be able to identify common keys.
#
# 2. Understand the different types of relational joins: concatenate, inner join, outer join, left join, right join.
#
# 3. Use the pandas syntax pd.concat() and pd.merge() to perform those relational joins.
#
# 4. Start to build an awareness of open data resources, and of documentation/tutorials for ongoing learning.

# %%
import pandas as pd
import numpy as np

# %%
# These files use \N as a missing value indicator.  When reading the CSVs, we will tell
# it to use that value as missing or NA.  The double backslash is required because
# otherwise it will interpret \N as a carriage return. 

# Read in the airports data.
airports = pd.read_csv("data/airports.dat", header=None, na_values='\\N')
airports.columns = ["ID", "NAME", "CITY", "COUNTRY", "IATA", "ICAO", "LATITUDE", "LONGITUDE", "ALTITUDE", "TIMEZONE", "DST", "TZ", "TYPE", "SOURCE"]

# Read in the airlines data.
airlines = pd.read_csv("data/airlines.dat", header=None, na_values='\\N')
airlines.columns = ["ID", "NAME", "ALIAS", "IATA", "ICAO", "CALLSIGN", "COUNTRY", "ACTIVE"]

# Read in the routes data.
routes = pd.read_csv("data/routes.dat", header=None, na_values='\\N')
routes.columns = ["AIRLINE", "AIRLINE_ID", "SOURCE", "SOURCE_ID", "DEST", "DEST_ID", "CODESHARE", "STOPS", "EQUIPMENT"]

# Read in the planes data.
planes = pd.read_csv("data/planes.dat", header=None, na_values='\\N')
planes.columns = ["NAME", "IATA", "ICAO"]

# Read in the countries data.
countries = pd.read_csv("data/countries.dat", header=None, na_values='\\N')
countries.columns = ["NAME", "ISO", "DAFIF"]

# %% [markdown]
# ### Start by seeing what's in the data.
#
# What columns are there?  What data types are the columns?
#
# Remember, 'object' means it is a string, while the numerical values can be floats or ints.  Sometimes you will have problems if it reads numeric data in as strings.  If that happens, you can use the function .astype() to convert it.  Look it up in the pandas API to get more details

# %% [markdown]
# Start with the airports table

# %%
# printing the first few rows gives us a good sense of what is in there
airports.head()
# Out:
#    ID                                         NAME          CITY  \
# 0   1                               Goroka Airport        Goroka
# 1   2                               Madang Airport        Madang
# 2   3                 Mount Hagen Kagamuga Airport   Mount Hagen
# 3   4                               Nadzab Airport        Nadzab
# 4   5  Port Moresby Jacksons International Airport  Port Moresby
#
#             COUNTRY IATA  ICAO  LATITUDE   LONGITUDE  ALTITUDE  TIMEZONE DST  \
# 0  Papua New Guinea  GKA  AYGA -6.081690  145.391998      5282      10.0   U
# 1  Papua New Guinea  MAG  AYMD -5.207080  145.789001        20      10.0   U
# 2  Papua New Guinea  HGU  AYMH -5.826790  144.296005      5388      10.0   U
# 3  Papua New Guinea  LAE  AYNZ -6.569803  146.725977       239      10.0   U
# 4  Papua New Guinea  POM  AYPY -9.443380  147.220001       146      10.0   U
#
#                      TZ     TYPE       SOURCE
# 0  Pacific/Port_Moresby  airport  OurAirports
# 1  Pacific/Port_Moresby  airport  OurAirports
# 2  Pacific/Port_Moresby  airport  OurAirports
# 3  Pacific/Port_Moresby  airport  OurAirports
# 4  Pacific/Port_Moresby  airport  OurAirports

# %%
# we can also look a the data types
# alternatively, we could summarize the data as we did in the previous lesson
airports.dtypes
# Out:
# ID             int64
# NAME          object
# CITY          object
# COUNTRY       object
# IATA          object
# ICAO          object
# LATITUDE     float64
# LONGITUDE    float64
# ALTITUDE       int64
# TIMEZONE     float64
# DST           object
# TZ            object
# TYPE          object
# SOURCE        object
# dtype: object

# %% [markdown]
# ##### Your turn:
#
# Spend a few minutes examining the remaining tables.  See if you can identify which fields are common across multiple tables.  These are the "keys".  Together, we will make sure we have identified the right keys.

# %%
airlines.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6162 entries, 0 to 6161
# Data columns (total 8 columns):
# ID          6162 non-null int64
# NAME        6162 non-null object
# ALIAS       178 non-null object
# IATA        1534 non-null object
# ICAO        5887 non-null object
# CALLSIGN    5351 non-null object
# COUNTRY     6144 non-null object
# ACTIVE      6162 non-null object
# dtypes: int64(1), object(7)
# memory usage: 385.2+ KB

# %%
routes.head(10)
# Out:
#   AIRLINE  AIRLINE_ID SOURCE  SOURCE_ID DEST  DEST_ID CODESHARE  STOPS  \
# 0      2B       410.0    AER     2965.0  KZN   2990.0       NaN      0
# 1      2B       410.0    ASF     2966.0  KZN   2990.0       NaN      0
# 2      2B       410.0    ASF     2966.0  MRV   2962.0       NaN      0
# 3      2B       410.0    CEK     2968.0  KZN   2990.0       NaN      0
# 4      2B       410.0    CEK     2968.0  OVB   4078.0       NaN      0
# 5      2B       410.0    DME     4029.0  KZN   2990.0       NaN      0
# 6      2B       410.0    DME     4029.0  NBC   6969.0       NaN      0
# 7      2B       410.0    DME     4029.0  TGK      NaN       NaN      0
# 8      2B       410.0    DME     4029.0  UUA   6160.0       NaN      0
# 9      2B       410.0    EGO     6156.0  KGD   2952.0       NaN      0
#
#   EQUIPMENT
# 0       CR2
# 1       CR2
# 2       CR2
# 3       CR2
# 4       CR2
# 5       CR2
# 6       CR2
# 7       CR2
# 8       CR2
# 9       CR2

# %%
planes.head(10)
# Out:
#                                            NAME IATA  ICAO
# 0                       Aerospatiale (Nord) 262  ND2  N262
# 1  Aerospatiale (Sud Aviation) Se.210 Caravelle  CRV  S210
# 2                  Aerospatiale SN.601 Corvette  NDC  S601
# 3                Aerospatiale/Alenia ATR 42-300  AT4  AT43
# 4                Aerospatiale/Alenia ATR 42-500  AT5  AT45
# 5                Aerospatiale/Alenia ATR 42-600  ATR  AT46
# 6                    Aerospatiale/Alenia ATR 72  AT7  AT72
# 7                                   Airbus A300  AB3  A30B
# 8                               Airbus A300-600  AB6  A306
# 9  Airbus A300-600ST Super Transporter / Beluga  ABB  A3ST

# %%
airlines.head(20)
# Out:
#     ID                                          NAME ALIAS IATA ICAO  \
# 0   -1                                       Unknown   NaN    -  NaN
# 1    1                                Private flight   NaN    -  NaN
# 2    2                                   135 Airways   NaN  NaN  GNL
# 3    3                                 1Time Airline   NaN   1T  RNX
# 4    4  2 Sqn No 1 Elementary Flying Training School   NaN  NaN  WYT
# 5    5                               213 Flight Unit   NaN  NaN  TFU
# 6    6                 223 Flight Unit State Airline   NaN  NaN  CHD
# 7    7                             224th Flight Unit   NaN  NaN  TTF
# 8    8                                   247 Jet Ltd   NaN  NaN  TWF
# 9    9                                   3D Aviation   NaN  NaN  SEC
# 10  10                                   40-Mile Air   NaN   Q5  MLA
# 11  11                                        4D Air   NaN  NaN  QRT
# 12  12                        611897 Alberta Limited   NaN  NaN  THD
# 13  13                              Ansett Australia   NaN   AN  AAA
# 14  14                          Abacus International   NaN   1B  NaN
# 15  15                               Abelag Aviation   NaN   W9  AAB
# 16  16                                Army Air Corps   NaN  NaN  AAC
# 17  17                     Aero Aviation Centre Ltd.   NaN  NaN  AAD
# 18  18     Aero Servicios Ejecutivos Internacionales   NaN  NaN  SII
# 19  19                                   Aero Biniza   NaN  NaN  BZS
#
#           CALLSIGN         COUNTRY ACTIVE
# 0              NaN             NaN      Y
# 1              NaN             NaN      Y
# 2          GENERAL   United States      N
# 3          NEXTIME    South Africa      Y
# 4              NaN  United Kingdom      N
# 5              NaN          Russia      N
# 6   CHKALOVSK-AVIA          Russia      N
# 7       CARGO UNIT          Russia      N
# 8     CLOUD RUNNER  United Kingdom      N
# 9          SECUREX   United States      N
# 10        MILE-AIR   United States      Y
# 11         QUARTET        Thailand      N
# 12           DONUT          Canada      N
# 13          ANSETT       Australia      Y
# 14             NaN       Singapore      Y
# 15             ABG         Belgium      N
# 16         ARMYAIR  United Kingdom      N
# 17         SUNRISE          Canada      N
# 18          ASEISA          Mexico      N
# 19          BINIZA          Mexico      N

# %% [markdown]
# ### Selecting data
#
# We might want to work with a subset of data.  If so, we can select data just like we did in the previous lesson.

# %%
# we can select all airports in one of the least visited countries on earth
airports[airports['COUNTRY']=="Tuvalu"]
# Out:
#         ID                            NAME      CITY COUNTRY IATA  ICAO  \
# 3835  4077  Funafuti International Airport  Funafuti  Tuvalu  FUN  NGFU
#
#       LATITUDE   LONGITUDE  ALTITUDE  TIMEZONE DST                TZ     TYPE  \
# 3835    -8.525  179.195999         9      12.0   U  Pacific/Funafuti  airport
#
#            SOURCE
# 3835  OurAirports

# %%
# we can select all routes to that airport
routes[routes['DEST']=='FUN']
# Out:
#       AIRLINE  AIRLINE_ID SOURCE  SOURCE_ID DEST  DEST_ID CODESHARE  STOPS  \
# 24819      FJ       879.0    SUV     1961.0  FUN   4077.0       NaN      0
#
#       EQUIPMENT
# 24819       AT5

# %%
# and routes from that airport
routes[routes['SOURCE']=='FUN']
# Out:
#       AIRLINE  AIRLINE_ID SOURCE  SOURCE_ID DEST  DEST_ID CODESHARE  STOPS  \
# 24784      FJ       879.0    FUN     4077.0  SUV   1961.0       NaN      0
#
#       EQUIPMENT
# 24784       AT5

# %%
# where are these flights going to/from? 
airports[airports[]]

# %% [markdown]
# #####  Your turn:
#
# Select just the routes that go to or from Lexington Bluegrass Airport, and store them in their own dataframe.
#
# The airport code is LEX.  You should have a much smaller dataframe.  How many inbound routes and how many outbound routes are there?

# %%
dfLex = routes[(routes['SOURCE']=='LEX') | (routes['DEST']=='LEX')]
dfLex
# Out:
#       AIRLINE  AIRLINE_ID SOURCE  SOURCE_ID DEST  DEST_ID CODESHARE  STOPS  \
# 3569       9E      3976.0    ATL     3682.0  LEX   4017.0       NaN      0
# 3588       9E      3976.0    LEX     4017.0  ATL   3682.0       NaN      0
# 4953       AA        24.0    CLT     3876.0  LEX   4017.0       NaN      0
# 5247       AA        24.0    DFW     3670.0  LEX   4017.0         Y      0
# 5763       AA        24.0    LEX     4017.0  CLT   3876.0         Y      0
# 5764       AA        24.0    LEX     4017.0  DFW   3670.0         Y      0
# 5765       AA        24.0    LEX     4017.0  ORD   3830.0         Y      0
# 6283       AA        24.0    ORD     3830.0  LEX   4017.0         Y      0
# 9097       AF       137.0    ATL     3682.0  LEX   4017.0         Y      0
# 9641       AF       137.0    LEX     4017.0  ATL   3682.0         Y      0
# 20164      DL      2009.0    ATL     3682.0  LEX   4017.0       NaN      0
# 20534      DL      2009.0    DCA     3520.0  LEX   4017.0         Y      0
# 20638      DL      2009.0    DTW     3645.0  LEX   4017.0       NaN      0
# 21095      DL      2009.0    LEX     4017.0  ATL   3682.0       NaN      0
# 21096      DL      2009.0    LEX     4017.0  DCA   3520.0         Y      0
# 21097      DL      2009.0    LEX     4017.0  DTW   3645.0         Y      0
# 21098      DL      2009.0    LEX     4017.0  LGA   3697.0       NaN      0
# 21099      DL      2009.0    LEX     4017.0  MSP   3858.0         Y      0
# 21131      DL      2009.0    LGA     3697.0  LEX   4017.0         Y      0
# 21402      DL      2009.0    MSP     3858.0  LEX   4017.0         Y      0
# 28951      G4        35.0    FLL     3533.0  LEX   4017.0       NaN      0
# 29047      G4        35.0    LEX     4017.0  FLL   3533.0       NaN      0
# 29048      G4        35.0    LEX     4017.0  PGD   7056.0       NaN      0
# 29049      G4        35.0    LEX     4017.0  PIE   3617.0       NaN      0
# 29050      G4        35.0    LEX     4017.0  SFB   4167.0       NaN      0
# 29090      G4        35.0    PGD     7056.0  LEX   4017.0       NaN      0
# 29120      G4        35.0    PIE     3617.0  LEX   4017.0       NaN      0
# 29187      G4        35.0    SFB     4167.0  LEX   4017.0       NaN      0
# 36396      KL      3090.0    ATL     3682.0  LEX   4017.0         Y      0
# 36746      KL      3090.0    LEX     4017.0  ATL   3682.0         Y      0
# 56775      UA      5209.0    IAH     3550.0  LEX   4017.0         Y      0
# 57029      UA      5209.0    LEX     4017.0  IAH   3550.0         Y      0
# 57030      UA      5209.0    LEX     4017.0  ORD   3830.0         Y      0
# 57322      UA      5209.0    ORD     3830.0  LEX   4017.0         Y      0
# 58812      US      5265.0    CLT     3876.0  LEX   4017.0       NaN      0
# 59096      US      5265.0    DFW     3670.0  LEX   4017.0       NaN      0
# 59544      US      5265.0    LEX     4017.0  CLT   3876.0       NaN      0
# 59545      US      5265.0    LEX     4017.0  DFW   3670.0       NaN      0
# 59546      US      5265.0    LEX     4017.0  ORD   3830.0         Y      0
# 59924      US      5265.0    ORD     3830.0  LEX   4017.0         Y      0
#
#              EQUIPMENT
# 3569               CRJ
# 3588               CRJ
# 4953               CR7
# 5247           ERD ER4
# 5763           CR7 CRJ
# 5764           ERD ER4
# 5765           ERD ER4
# 6283           ERD ER4
# 9097   CR9 M88 CRJ 717
# 9641           CRJ CR9
# 20164          M88 717
# 20534              CRJ
# 20638              717
# 21095          M88 717
# 21096              CRJ
# 21097      CR7 CRJ CR9
# 21098              ERJ
# 21099              CRJ
# 21131              ERJ
# 21402              CRJ
# 28951              M80
# 29047              M80
# 29048              M80
# 29049              320
# 29050          M80 320
# 29090              M80
# 29120              320
# 29187          M80 320
# 36396      CR9 M88 CRJ
# 36746          CR9 CRJ
# 56775              ERJ
# 57029              ERJ
# 57030          ERJ CRJ
# 57322          ERJ CRJ
# 58812              CR7
# 59096              ERD
# 59544              CR7
# 59545              ERD
# 59546          ERD ER4
# 59924          ERD ER4

# %%
# dfDest = routes[routes['DEST']=='LEX']

# %%
dfLex.count()
# Out:
# AIRLINE       40
# AIRLINE_ID    40
# SOURCE        40
# SOURCE_ID     40
# DEST          40
# DEST_ID       40
# CODESHARE     21
# STOPS         40
# EQUIPMENT     40
# dtype: int64

# %% [markdown]
# ### Concatentating data
#
# To concatenate is to link things together in a series or chain.  It is similar to, but more powerful than appending data, because it can work on either rows or columns, is faster, and will perform set logic (union or intersection).

# %%
# let's go back and contatenate the routes both to and from Tuvalu
to_tuvalu = routes[routes['DEST']=='FUN']
from_tuvalu = routes[routes['SOURCE']=='FUN']

# %%
# the basic function, given a list of dataframes to concatenate
# note that we call concatenate as a "static" method, rather than a method 
# associated with a specific object. 

pd.concat([to_tuvalu, from_tuvalu])
# Out:
#       AIRLINE  AIRLINE_ID SOURCE  SOURCE_ID DEST  DEST_ID CODESHARE  STOPS  \
# 24819      FJ       879.0    SUV     1961.0  FUN   4077.0       NaN      0
# 24784      FJ       879.0    FUN     4077.0  SUV   1961.0       NaN      0
#
#       EQUIPMENT
# 24819       AT5
# 24784       AT5

# %%
# if we want to use the dataframe later, we need to assign it to a variable name

tuvalu_routes = pd.concat([to_tuvalu, from_tuvalu])

# %% [markdown]
# Note to see more about this method, we can examine the pandas docs:
#
# https://pandas.pydata.org/pandas-docs/stable/user_guide/merging.html

# %%
# note that one of the arguments is axis.  
# axis=0 indicates that the rows should be concatenated, 
# while axis=1 indicates to concatenate the columns 

pd.concat([to_tuvalu, from_tuvalu], axis=1)
# Out:
#       AIRLINE  AIRLINE_ID SOURCE  SOURCE_ID DEST  DEST_ID CODESHARE  STOPS  \
# 24784     NaN         NaN    NaN        NaN  NaN      NaN       NaN    NaN
# 24819      FJ       879.0    SUV     1961.0  FUN   4077.0       NaN    0.0
#
#       EQUIPMENT AIRLINE  AIRLINE_ID SOURCE  SOURCE_ID DEST  DEST_ID CODESHARE  \
# 24784       NaN      FJ       879.0    FUN     4077.0  SUV   1961.0       NaN
# 24819       AT5     NaN         NaN    NaN        NaN  NaN      NaN       NaN
#
#        STOPS EQUIPMENT
# 24784    0.0       AT5
# 24819    NaN       NaN

# %% [markdown]
# ##### Your turn:
#
# Can you use the concat() function to create one dataframe with flights both into and out of LEX?

# %% [markdown]
# ### Merging data
#
# Sometimes we want to merge, or join, the data instead of concatenating it.  For example, maybe we hate flying on small planes, so want to know what kind of aircraft we would need to fly on to visit Tuvalu.  This data comes from a different table.

# %%
# we see that the Tuvalu routes operate with AT5 equipment
tuvalu_routes
# Out:
#       AIRLINE  AIRLINE_ID SOURCE  SOURCE_ID DEST  DEST_ID CODESHARE  STOPS  \
# 24819      FJ       879.0    SUV     1961.0  FUN   4077.0       NaN      0
# 24784      FJ       879.0    FUN     4077.0  SUV   1961.0       NaN      0
#
#       EQUIPMENT
# 24819       AT5
# 24784       AT5

# %%
# but what is an AT5? Let's look in the planes table. 
planes.head()

# %%
# in this case, we are lucky, and it is in the first few rows.  But to do this systemactically, we
# would want to join the tables.  To do this, we use the merge() function in pandas.  

pd.merge(tuvalu_routes, planes, left_on='EQUIPMENT', right_on='IATA')
# Out:
#   AIRLINE  AIRLINE_ID SOURCE  SOURCE_ID DEST  DEST_ID CODESHARE  STOPS  \
# 0      FJ       879.0    SUV     1961.0  FUN   4077.0       NaN      0
# 1      FJ       879.0    FUN     4077.0  SUV   1961.0       NaN      0
#
#   EQUIPMENT                            NAME IATA  ICAO
# 0       AT5  Aerospatiale/Alenia ATR 42-500  AT5  AT45
# 1       AT5  Aerospatiale/Alenia ATR 42-500  AT5  AT45

# %% [markdown]
# Let's stop and look at what is going on in the above command.
#
# It is important to understand the type of merge, as specified by the how option.  Here is what the pandas docs say:
#
#
# ![alt text](img/how.png)
#
#
# ![alt text](img/how2.png)
#
# So it looks like the above merge defaulted to an inner join

# %% [markdown]
# ![alt text](img/inner.png)

# %%
# we can check this by explicitly setting the option and confirming that we get the same result  
# next, let's check what happens if we choose the other options

pd.merge(tuvalu_routes, planes, left_on='EQUIPMENT', right_on='IATA', how='inner')
# Out:
#   AIRLINE  AIRLINE_ID SOURCE  SOURCE_ID DEST  DEST_ID CODESHARE  STOPS  \
# 0      FJ       879.0    SUV     1961.0  FUN   4077.0       NaN      0
# 1      FJ       879.0    FUN     4077.0  SUV   1961.0       NaN      0
#
#   EQUIPMENT                            NAME IATA  ICAO
# 0       AT5  Aerospatiale/Alenia ATR 42-500  AT5  AT45
# 1       AT5  Aerospatiale/Alenia ATR 42-500  AT5  AT45

# %%
# outer join

pd.merge(tuvalu_routes, planes, left_on='EQUIPMENT', right_on='IATA', how='outer')
# Out:
#     AIRLINE  AIRLINE_ID SOURCE  SOURCE_ID DEST  DEST_ID CODESHARE  STOPS  \
# 0        FJ       879.0    SUV     1961.0  FUN   4077.0       NaN    0.0
# 1        FJ       879.0    FUN     4077.0  SUV   1961.0       NaN    0.0
# 2       NaN         NaN    NaN        NaN  NaN      NaN       NaN    NaN
# 3       NaN         NaN    NaN        NaN  NaN      NaN       NaN    NaN
# 4       NaN         NaN    NaN        NaN  NaN      NaN       NaN    NaN
# ..      ...         ...    ...        ...  ...      ...       ...    ...
# 242     NaN         NaN    NaN        NaN  NaN      NaN       NaN    NaN
# 243     NaN         NaN    NaN        NaN  NaN      NaN       NaN    NaN
# 244     NaN         NaN    NaN        NaN  NaN      NaN       NaN    NaN
# 245     NaN         NaN    NaN        NaN  NaN      NaN       NaN    NaN
# 246     NaN         NaN    NaN        NaN  NaN      NaN       NaN    NaN
#
#     EQUIPMENT                                          NAME IATA  ICAO
# 0         AT5                Aerospatiale/Alenia ATR 42-500  AT5  AT45
# 1         AT5                Aerospatiale/Alenia ATR 42-500  AT5  AT45
# 2         NaN                       Aerospatiale (Nord) 262  ND2  N262
# 3         NaN  Aerospatiale (Sud Aviation) Se.210 Caravelle  CRV  S210
# 4         NaN                  Aerospatiale SN.601 Corvette  NDC  S601
# ..        ...                                           ...  ...   ...
# 242       NaN                                Tupolev Tu-134  TU3  T134
# 243       NaN                                Tupolev Tu-154  TU5  T154
# 244       NaN                                Tupolev Tu-204  T20  T204
# 245       NaN                               Yakovlev Yak-40  YK4  YK40
# 246       NaN                               Yakovlev Yak-42  YK2  YK42
#
# [247 rows x 12 columns]

# %%
# left join

pd.merge(tuvalu_routes, planes, left_on='EQUIPMENT', right_on='IATA', how='left')
# Out:
#   AIRLINE  AIRLINE_ID SOURCE  SOURCE_ID DEST  DEST_ID CODESHARE  STOPS  \
# 0      FJ       879.0    SUV     1961.0  FUN   4077.0       NaN      0
# 1      FJ       879.0    FUN     4077.0  SUV   1961.0       NaN      0
#
#   EQUIPMENT                            NAME IATA  ICAO
# 0       AT5  Aerospatiale/Alenia ATR 42-500  AT5  AT45
# 1       AT5  Aerospatiale/Alenia ATR 42-500  AT5  AT45

# %%
# right join

pd.merge(tuvalu_routes, planes, left_on='EQUIPMENT', right_on='IATA', how='right')
# Out:
#     AIRLINE  AIRLINE_ID SOURCE  SOURCE_ID DEST  DEST_ID CODESHARE  STOPS  \
# 0        FJ       879.0    SUV     1961.0  FUN   4077.0       NaN    0.0
# 1        FJ       879.0    FUN     4077.0  SUV   1961.0       NaN    0.0
# 2       NaN         NaN    NaN        NaN  NaN      NaN       NaN    NaN
# 3       NaN         NaN    NaN        NaN  NaN      NaN       NaN    NaN
# 4       NaN         NaN    NaN        NaN  NaN      NaN       NaN    NaN
# ..      ...         ...    ...        ...  ...      ...       ...    ...
# 242     NaN         NaN    NaN        NaN  NaN      NaN       NaN    NaN
# 243     NaN         NaN    NaN        NaN  NaN      NaN       NaN    NaN
# 244     NaN         NaN    NaN        NaN  NaN      NaN       NaN    NaN
# 245     NaN         NaN    NaN        NaN  NaN      NaN       NaN    NaN
# 246     NaN         NaN    NaN        NaN  NaN      NaN       NaN    NaN
#
#     EQUIPMENT                                          NAME IATA  ICAO
# 0         AT5                Aerospatiale/Alenia ATR 42-500  AT5  AT45
# 1         AT5                Aerospatiale/Alenia ATR 42-500  AT5  AT45
# 2         NaN                       Aerospatiale (Nord) 262  ND2  N262
# 3         NaN  Aerospatiale (Sud Aviation) Se.210 Caravelle  CRV  S210
# 4         NaN                  Aerospatiale SN.601 Corvette  NDC  S601
# ..        ...                                           ...  ...   ...
# 242       NaN                                Tupolev Tu-134  TU3  T134
# 243       NaN                                Tupolev Tu-154  TU5  T154
# 244       NaN                                Tupolev Tu-204  T20  T204
# 245       NaN                               Yakovlev Yak-40  YK4  YK40
# 246       NaN                               Yakovlev Yak-42  YK2  YK42
#
# [247 rows x 12 columns]

# %% [markdown]
# I find that I most often want a left join, as described here:
#
# ![alt text](img/left.png)

# %% [markdown]
# It may be worth examining some of the other options used in merge().  We can refer to the pandas documentation to learn more.
#
# https://pandas.pydata.org/pandas-docs/stable/user_guide/merging.html#database-style-dataframe-or-named-series-joining-merging

# %% [markdown]
# #### Your turn
#
# Now let's look at which airlines operate in and out of Lexington.  How many routes does each airline have?
#
# First, let's spend some time planning together.  Then individually take some time to implement the code we planned.

# %% [markdown]
# #### It looks like there are some international airlines with Lexington routes.
#
# To look at how many routes they have, create a new column in your dataframe called 'International', which is set to True for an overseas airline and False for a domestic airline.  Calculate the percent of routes with an overseas airline.
#
# You should have the tools you need to answer this question using what we learned in last week's lesson.  Again, let's start by planning together, then implement the code on your own.

# %% [markdown]
# #### Codeshares
#
# It looks like a bunch of these routes are codeshares.  That means they are marketed by this airline, but operated by a different airline.  See the note in the data documentation on openflights.org/data.  The implication of this is that there are duplicates.
#
# Can you figure out which ones are duplicates?  Can you then create a dataframe with only the unique routes?  How many unique inbound and outbound routes are there?
#
# Remember, someone has to operate the flight, so if all the routes to/from a particular airport are listed as codeshares, then something is funny...
#
# It is also possible that more than one airline actually operates a route between the same two airports. (Having this sort of competition generally means that you will get better fares as a traveler.)  It may not be obvious what is actually in the data set, so dig or do external research as needed.
#
# It is this sort of messiness that will consume much of your effort in research and data science.  It is very important to "become one with your data".
#
# Figuring this out will be the first part of your homework.

# %% [markdown]
# ### Review Questions:
#
# 1. What is a key in relational data?
#
# 2. Explain the difference between a left join and an outer join.
#
# 3. Explain the difference between pd.concat() and pd.merge()
#
# 4. Identify two possible places to look for help if you get stuck on the homework.

# %% [markdown]
# ### Homework 1 - Code shares
#
# Dig into the data as described above, and do your best to identify which routes are code shares, and how many unique routes operate into/out of Lexington.

# %%
routes.head(100)
# Out:
#    AIRLINE  AIRLINE_ID SOURCE  SOURCE_ID DEST  DEST_ID CODESHARE  STOPS  \
# 0       2B       410.0    AER     2965.0  KZN   2990.0       NaN      0
# 1       2B       410.0    ASF     2966.0  KZN   2990.0       NaN      0
# 2       2B       410.0    ASF     2966.0  MRV   2962.0       NaN      0
# 3       2B       410.0    CEK     2968.0  KZN   2990.0       NaN      0
# 4       2B       410.0    CEK     2968.0  OVB   4078.0       NaN      0
# ..     ...         ...    ...        ...  ...      ...       ...    ...
# 95      2J       470.0    OUA      246.0  ABJ    253.0       NaN      0
# 96      2J       470.0    OUA      246.0  ACC    248.0       NaN      0
# 97      2J       470.0    OUA      246.0  BKO   1044.0       NaN      0
# 98      2J       470.0    OUA      246.0  BOY    247.0       NaN      0
# 99      2J       470.0    OUA      246.0  COO    245.0       NaN      0
#
#       EQUIPMENT
# 0           CR2
# 1           CR2
# 2           CR2
# 3           CR2
# 4           CR2
# ..          ...
# 95  E70 CRJ M87
# 96          CRJ
# 97      M87 CRJ
# 98          CRJ
# 99          M87
#
# [100 rows x 9 columns]

# %%
dfLexRoutes = routes[routes['SOURCE'].str.contains("LEX") | routes['DEST'].str.contains("LEX")]
dfLexRoutes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 40 entries, 3569 to 59924
# Data columns (total 9 columns):
# AIRLINE       40 non-null object
# AIRLINE_ID    40 non-null float64
# SOURCE        40 non-null object
# SOURCE_ID     40 non-null float64
# DEST          40 non-null object
# DEST_ID       40 non-null float64
# CODESHARE     21 non-null object
# STOPS         40 non-null int64
# EQUIPMENT     40 non-null object
# dtypes: float64(3), int64(1), object(5)
# memory usage: 3.1+ KB

# %%
dfLexRoutes_codeshared = routes[(routes['SOURCE'].str.contains("LEX") | routes['DEST'].str.contains("LEX")) &  routes['CODESHARE'].str.contains("Y")]
dfLexRoutes_codeshared.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 21 entries, 5247 to 59924
# Data columns (total 9 columns):
# AIRLINE       21 non-null object
# AIRLINE_ID    21 non-null float64
# SOURCE        21 non-null object
# SOURCE_ID     21 non-null float64
# DEST          21 non-null object
# DEST_ID       21 non-null float64
# CODESHARE     21 non-null object
# STOPS         21 non-null int64
# EQUIPMENT     21 non-null object
# dtypes: float64(3), int64(1), object(5)
# memory usage: 1.6+ KB

# %%
dfLexRoutes_withoutdupl = dfLexRoutes.drop_duplicates(subset=['SOURCE','DEST'],keep=False)[['SOURCE','DEST']]
dfLexRoutes_withoutdupl
# Out:
#       SOURCE DEST
# 20534    DCA  LEX
# 20638    DTW  LEX
# 21096    LEX  DCA
# 21097    LEX  DTW
# 21098    LEX  LGA
# 21099    LEX  MSP
# 21131    LGA  LEX
# 21402    MSP  LEX
# 28951    FLL  LEX
# 29047    LEX  FLL
# 29048    LEX  PGD
# 29049    LEX  PIE
# 29050    LEX  SFB
# 29090    PGD  LEX
# 29120    PIE  LEX
# 29187    SFB  LEX
# 56775    IAH  LEX
# 57029    LEX  IAH

# %%
dfLexRoutes_withoutdupl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 18 entries, 20534 to 57029
# Data columns (total 2 columns):
# SOURCE    18 non-null object
# DEST      18 non-null object
# dtypes: object(2)
# memory usage: 432.0+ bytes

# %%
dfLexRoutes_withoutdupl['value'] = dfLexRoutes_withoutdupl.lookup(dfLexRoutes_withoutdupl['SOURCE'], dfLexRoutes_withoutdupl['DEST'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-64-f851469d031f> in <module>
# ----> 1 dfLexRoutes_withoutdupl['value'] = dfLexRoutes_withoutdupl.lookup(dfLexRoutes_withoutdupl['SOURCE'], dfLexRoutes_withoutdupl['DEST'])
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in lookup(self, row_labels, col_labels)
#    3817             cidx = self.columns.get_indexer(col_labels)
#    3818             if (ridx == -1).any():
# -> 3819                 raise KeyError("One or more row labels was not found")
#    3820             if (cidx == -1).any():
#    3821                 raise KeyError("One or more column labels was not found")
#
# KeyError: 'One or more row labels was not found'

# %%
dfLexRoutes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 40 entries, 3569 to 59924
# Data columns (total 9 columns):
# AIRLINE       40 non-null object
# AIRLINE_ID    40 non-null float64
# SOURCE        40 non-null object
# SOURCE_ID     40 non-null float64
# DEST          40 non-null object
# DEST_ID       40 non-null float64
# CODESHARE     21 non-null object
# STOPS         40 non-null int64
# EQUIPMENT     40 non-null object
# dtypes: float64(3), int64(1), object(5)
# memory usage: 3.1+ KB

# %%
dfSourLexRoutes = routes[routes['SOURCE'].str.contains("LEX")]
dfSourLexRoutes.loc[:,"DEST"].unique()
# Out:
# array(['ATL', 'CLT', 'DFW', 'ORD', 'DCA', 'DTW', 'LGA', 'MSP', 'FLL',
#        'PGD', 'PIE', 'SFB', 'IAH'], dtype=object)

# %%
dfDestLexRoutes = routes[routes['DEST'].str.contains("LEX")]
dfDestLexRoutes.loc[:,"SOURCE"].unique()
# Out:
# array(['ATL', 'CLT', 'DFW', 'ORD', 'DCA', 'DTW', 'LGA', 'MSP', 'FLL',
#        'PGD', 'PIE', 'SFB', 'IAH'], dtype=object)

# %%
pd.merge(dfSourLexRoutes,dfDestLexRoutes,left_on='SOURCE', right_on='DEST', how='outer')[[]]
# Out:
#     AIRLINE_x  AIRLINE_ID_x SOURCE_x  SOURCE_ID_x DEST_x  DEST_ID_x  \
# 0          9E        3976.0      LEX       4017.0    ATL     3682.0
# 1          9E        3976.0      LEX       4017.0    ATL     3682.0
# 2          9E        3976.0      LEX       4017.0    ATL     3682.0
# 3          9E        3976.0      LEX       4017.0    ATL     3682.0
# 4          9E        3976.0      LEX       4017.0    ATL     3682.0
# ..        ...           ...      ...          ...    ...        ...
# 395        US        5265.0      LEX       4017.0    ORD     3830.0
# 396        US        5265.0      LEX       4017.0    ORD     3830.0
# 397        US        5265.0      LEX       4017.0    ORD     3830.0
# 398        US        5265.0      LEX       4017.0    ORD     3830.0
# 399        US        5265.0      LEX       4017.0    ORD     3830.0
#
#     CODESHARE_x  STOPS_x EQUIPMENT_x AIRLINE_y  AIRLINE_ID_y SOURCE_y  \
# 0           NaN        0         CRJ        9E        3976.0      ATL
# 1           NaN        0         CRJ        AA          24.0      CLT
# 2           NaN        0         CRJ        AA          24.0      DFW
# 3           NaN        0         CRJ        AA          24.0      ORD
# 4           NaN        0         CRJ        AF         137.0      ATL
# ..          ...      ...         ...       ...           ...      ...
# 395           Y        0     ERD ER4        UA        5209.0      IAH
# 396           Y        0     ERD ER4        UA        5209.0      ORD
# 397           Y        0     ERD ER4        US        5265.0      CLT
# 398           Y        0     ERD ER4        US        5265.0      DFW
# 399           Y        0     ERD ER4        US        5265.0      ORD
#
#      SOURCE_ID_y DEST_y  DEST_ID_y CODESHARE_y  STOPS_y      EQUIPMENT_y
# 0         3682.0    LEX     4017.0         NaN        0              CRJ
# 1         3876.0    LEX     4017.0         NaN        0              CR7
# 2         3670.0    LEX     4017.0           Y        0          ERD ER4
# 3         3830.0    LEX     4017.0           Y        0          ERD ER4
# 4         3682.0    LEX     4017.0           Y        0  CR9 M88 CRJ 717
# ..           ...    ...        ...         ...      ...              ...
# 395       3550.0    LEX     4017.0           Y        0              ERJ
# 396       3830.0    LEX     4017.0           Y        0          ERJ CRJ
# 397       3876.0    LEX     4017.0         NaN        0              CR7
# 398       3670.0    LEX     4017.0         NaN        0              ERD
# 399       3830.0    LEX     4017.0           Y        0          ERD ER4
#
# [400 rows x 18 columns]

# %%
dfLexRoutes['AIRLINE']
# Out:
# 5247     AA
# 5763     AA
# 5764     AA
# 5765     AA
# 6283     AA
# 9097     AF
# 9641     AF
# 20534    DL
# 21096    DL
# 21097    DL
# 21099    DL
# 21131    DL
# 21402    DL
# 36396    KL
# 36746    KL
# 56775    UA
# 57029    UA
# 57030    UA
# 57322    UA
# 59546    US
# 59924    US
# Name: AIRLINE, dtype: object

# %%
# Out:
#       AIRLINE  AIRLINE_ID SOURCE  SOURCE_ID DEST  DEST_ID CODESHARE  STOPS  \
# 3569       9E      3976.0    ATL     3682.0  LEX   4017.0       NaN      0
# 3588       9E      3976.0    LEX     4017.0  ATL   3682.0       NaN      0
# 4953       AA        24.0    CLT     3876.0  LEX   4017.0       NaN      0
# 5247       AA        24.0    DFW     3670.0  LEX   4017.0         Y      0
# 5763       AA        24.0    LEX     4017.0  CLT   3876.0         Y      0
# 5764       AA        24.0    LEX     4017.0  DFW   3670.0         Y      0
# 5765       AA        24.0    LEX     4017.0  ORD   3830.0         Y      0
# 6283       AA        24.0    ORD     3830.0  LEX   4017.0         Y      0
# 9097       AF       137.0    ATL     3682.0  LEX   4017.0         Y      0
# 9641       AF       137.0    LEX     4017.0  ATL   3682.0         Y      0
# 20164      DL      2009.0    ATL     3682.0  LEX   4017.0       NaN      0
# 20534      DL      2009.0    DCA     3520.0  LEX   4017.0         Y      0
# 20638      DL      2009.0    DTW     3645.0  LEX   4017.0       NaN      0
# 21095      DL      2009.0    LEX     4017.0  ATL   3682.0       NaN      0
# 21096      DL      2009.0    LEX     4017.0  DCA   3520.0         Y      0
# 21097      DL      2009.0    LEX     4017.0  DTW   3645.0         Y      0
# 21098      DL      2009.0    LEX     4017.0  LGA   3697.0       NaN      0
# 21099      DL      2009.0    LEX     4017.0  MSP   3858.0         Y      0
# 21131      DL      2009.0    LGA     3697.0  LEX   4017.0         Y      0
# 21402      DL      2009.0    MSP     3858.0  LEX   4017.0         Y      0
# 28951      G4        35.0    FLL     3533.0  LEX   4017.0       NaN      0
# 29047      G4        35.0    LEX     4017.0  FLL   3533.0       NaN      0
# 29048      G4        35.0    LEX     4017.0  PGD   7056.0       NaN      0
# 29049      G4        35.0    LEX     4017.0  PIE   3617.0       NaN      0
# 29050      G4        35.0    LEX     4017.0  SFB   4167.0       NaN      0
# 29090      G4        35.0    PGD     7056.0  LEX   4017.0       NaN      0
# 29120      G4        35.0    PIE     3617.0  LEX   4017.0       NaN      0
# 29187      G4        35.0    SFB     4167.0  LEX   4017.0       NaN      0
# 36396      KL      3090.0    ATL     3682.0  LEX   4017.0         Y      0
# 36746      KL      3090.0    LEX     4017.0  ATL   3682.0         Y      0
#
#              EQUIPMENT
# 3569               CRJ
# 3588               CRJ
# 4953               CR7
# 5247           ERD ER4
# 5763           CR7 CRJ
# 5764           ERD ER4
# 5765           ERD ER4
# 6283           ERD ER4
# 9097   CR9 M88 CRJ 717
# 9641           CRJ CR9
# 20164          M88 717
# 20534              CRJ
# 20638              717
# 21095          M88 717
# 21096              CRJ
# 21097      CR7 CRJ CR9
# 21098              ERJ
# 21099              CRJ
# 21131              ERJ
# 21402              CRJ
# 28951              M80
# 29047              M80
# 29048              M80
# 29049              320
# 29050          M80 320
# 29090              M80
# 29120              320
# 29187          M80 320
# 36396      CR9 M88 CRJ
# 36746          CR9 CRJ

# %% [markdown]
# # Homework 2 - The Kevin Bacon Game
#
# Of course, it is possible to fly beyond those few cities from Lexington--you just have to transfer to get there.  Your task is to:
#
# 1. Identify which airports you can get to from Lexington with only one transfer.
# 2. Identify which airports you can get to from Lexington with two transfers.
#
# You have the tools to do this using the merge functionality presented today, but you will need to be smart about what you are merging.
#
# Next class, we will use these data to make interactive maps of these flight routes, similar to what you see in the back of the airline magazines.
#
#
# #### Bonus:
#
# This is the air travel version of the Kevin Bacon game (https://oracleofbacon.org/). What is the number N, such that you can reach every airport in the world with N or fewer transfers?
#
# #### Extra Bonus:
#
# Use this very important piece of knowledge to impress your friends at parties!

# %%
import pandas as pd
import numpy as np

# These files use \N as a missing value indicator.  When reading the CSVs, we will tell
# it to use that value as missing or NA.  The double backslash is required because
# otherwise it will interpret \N as a carriage return. 

# Read in the airports data.
airports = pd.read_csv("data/airports.dat", header=None, na_values='\\N')
airports.columns = ["ID", "NAME", "CITY", "COUNTRY", "IATA", "ICAO", "LATITUDE", "LONGITUDE", "ALTITUDE", "TIMEZONE", "DST", "TZ", "TYPE", "SOURCE"]

# Read in the airlines data.
airlines = pd.read_csv("data/airlines.dat", header=None, na_values='\\N')
airlines.columns = ["ID", "NAME", "ALIAS", "IATA", "ICAO", "CALLSIGN", "COUNTRY", "ACTIVE"]

# Read in the routes data.
routes = pd.read_csv("data/routes.dat", header=None, na_values='\\N')
routes.columns = ["AIRLINE", "AIRLINE_ID", "SOURCE", "SOURCE_ID", "DEST", "DEST_ID", "CODESHARE", "STOPS", "EQUIPMENT"]

# Read in the planes data.
planes = pd.read_csv("data/planes.dat", header=None, na_values='\\N')
planes.columns = ["NAME", "IATA", "ICAO"]

# Read in the countries data.
countries = pd.read_csv("data/countries.dat", header=None, na_values='\\N')
countries.columns = ["NAME", "ISO", "DAFIF"]

# %%
dfSurLexRoutes = routes[routes['SOURCE'].str.contains("LEX")].drop_duplicates("DEST")["DEST"].unique()
dfSurLexRoutes
# Out:
# array(['ATL', 'CLT', 'DFW', 'ORD', 'DCA', 'DTW', 'LGA', 'MSP', 'FLL',
#        'PGD', 'PIE', 'SFB', 'IAH'], dtype=object)

# %%
sUnique = set()
sUnique.add("LEX")
firstdestination = routes[routes['SOURCE'].str.contains("LEX")].drop_duplicates("DEST")["DEST"].unique()
firstdestination
# Out:
# array(['ATL', 'CLT', 'DFW', 'ORD', 'DCA', 'DTW', 'LGA', 'MSP', 'FLL',
#        'PGD', 'PIE', 'SFB', 'IAH'], dtype=object)

# %%
for destination in firstdestination:
    seconddestination = [(routes[routes["SOURCE"].str.contains(x)].drop_duplicates("DEST")["DEST"].unique()) for x in firstdestination]
    for dest in seconddestination:
        sUnique.add(dest)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-36-ed83fc9bb4d5> in <module>
#       2     seconddestination = [(routes[routes["SOURCE"].str.contains(x)].drop_duplicates("DEST")["DEST"].unique()) for x in firstdestination]
#       3     for dest in seconddestination:
# ----> 4         sUnique.add(dest)
#
# TypeError: unhashable type: 'numpy.ndarray'

# %%
seconddesetination == [(routes[routes["SOURCE"].str.contains(x)].drop_duplicates("DEST")["DEST"].unique()) for x in firstdestination])
    for dest in seconddestination:
# Out:
#   File "<ipython-input-33-fb254c32a9e2>", line 1
#     seconddesetination == [(routes[routes["SOURCE"].str.contains(x)].drop_duplicates("DEST")["DEST"].unique()) for x in firstdestination])
#                                                                                                                                          ^
# SyntaxError: invalid syntax

# %%
[sUnique.add(x) for x in firstdestination]
sUnique
# Out:
# {'ATL',
#  'CLT',
#  'DCA',
#  'DFW',
#  'DTW',
#  'FLL',
#  'IAH',
#  'LEX',
#  'LGA',
#  'MSP',
#  'ORD',
#  'PGD',
#  'PIE',
#  'SFB'}

# %%
seconddesetination = [(routes[routes["SOURCE"].str.contains(x)].drop_duplicates("DEST")["DEST"].unique()) for x in firstdestination]
seconddesetination
# Out:
# [array(['LWB', 'MCN', 'MEI', 'MSL', 'PIB', 'TUP', 'AZO', 'CHA', 'CID',
#         'CRW', 'CVG', 'EVV', 'FWA', 'GSO', 'GSP', 'LAN', 'LEX', 'MBS',
#         'MSP', 'ROA', 'SYR', 'TYS', 'XNA', 'CLT', 'DFW', 'LHR', 'MIA',
#         'ORD', 'PHL', 'PHX', 'DEN', 'YYZ', 'ABE', 'ABQ', 'ABY', 'AEX',
#         'AGS', 'ALB', 'ATW', 'AUS', 'AVL', 'AVP', 'BDL', 'BHM', 'BMI',
#         'BNA', 'BOS', 'BQK', 'BRU', 'BTR', 'BTV', 'BUF', 'BWI', 'CAE',
#         'CAK', 'CDG', 'CHO', 'CHS', 'CLE', 'CMH', 'COS', 'CSG', 'CUN',
#         'CZM', 'DAB', 'DAL', 'DAY', 'DCA', 'DHN', 'DSM', 'DTW', 'DUB',
#         'DUS', 'ECP', 'ELP', 'EWN', 'EWR', 'EYW', 'FAY', 'FCO', 'FLL',
#         'FNT', 'FRA', 'FSM', 'GDL', 'GNV', 'GPT', 'GRB', 'GRK', 'GRR',
#         'GTR', 'HPN', 'HSV', 'IAD', 'IAH', 'ICT', 'ILM', 'IND', 'JAN',
#         'JAX', 'JFK', 'LAS', 'LAX', 'LFT', 'LGA', 'LIT', 'MAD', 'MAN',
#         'MCI', 'MCO', 'MDT', 'MDW', 'MEM', 'MEX', 'MGM', 'MHT', 'MKE',
#         'MLB', 'MLI', 'MLU', 'MOB', 'MSN', 'MSY', 'MTY', 'MUC', 'MYR',
#         'NAS', 'OAJ', 'OKC', 'OMA', 'ORF', 'PBI', 'PDX', 'PHF', 'PIA',
#         'PIT', 'PNS', 'PTY', 'PVD', 'PWM', 'RDU', 'RIC', 'ROC', 'RSW',
#         'SAN', 'SAT', 'SAV', 'SBN', 'SDF', 'SEA', 'SFO', 'SGF', 'SHV',
#         'SJO', 'SJU', 'SLC', 'SMF', 'SNA', 'SRQ', 'STL', 'STR', 'TLH',
#         'TPA', 'TRI', 'TUL', 'TUS', 'VLD', 'VPS', 'YUL', 'PVR', 'SJD',
#         'HOU', 'AMS', 'AUA', 'BDA', 'BJX', 'BOG', 'BON', 'BSB', 'BZE',
#         'CCS', 'DXB', 'EZE', 'FAR', 'FPO', 'FSD', 'GCM', 'GGT', 'GIG',
#         'GRU', 'GUA', 'HNL', 'ICN', 'JNB', 'KIN', 'LIM', 'LIR', 'LOS',
#         'MBJ', 'MGA', 'NRT', 'PAP', 'PLS', 'PUJ', 'RTB', 'SAL', 'SAP',
#         'SCL', 'SDQ', 'SJC', 'STT', 'SXM', 'TGU', 'UIO', 'UVF', 'ZRH',
#         'TTN'], dtype=object),
#  array(['CUR', 'ABE', 'AGS', 'ALB', 'ANU', 'ATL', 'AUA', 'AUS', 'AVL',
#         'AVP', 'BDL', 'BHM', 'BNA', 'BOS', 'BTR', 'BUF', 'BWI', 'BZE',
#         'CAE', 'CAK', 'CDG', 'CHA', 'CHO', 'CHS', 'CLE', 'CMH', 'CRW',
#         'CUN', 'CVG', 'CZM', 'DAB', 'DAY', 'DCA', 'DEN', 'DFW', 'DSM',
#         'DTW', 'DUB', 'EWN', 'EWR', 'FAY', 'FCO', 'FLL', 'FLO', 'FPO',
#         'FRA', 'GCM', 'GNV', 'GPT', 'GRU', 'GSO', 'GSP', 'HHH', 'HPN',
#         'HSV', 'HTS', 'IAD', 'IAH', 'ILM', 'IND', 'JAN', 'JAX', 'JFK',
#         'LAS', 'LAX', 'LEX', 'LGA', 'LHR', 'LIR', 'LIT', 'LYH', 'MBJ',
#         'MCI', 'MCO', 'MDT', 'MEM', 'MEX', 'MGM', 'MHT', 'MIA', 'MKE',
#         'MLB', 'MOB', 'MSP', 'MSY', 'MYR', 'NAS', 'OAJ', 'OMA', 'ORD',
#         'ORF', 'PBI', 'PDX', 'PGV', 'PHF', 'PHL', 'PHX', 'PIT', 'PLS',
#         'PNS', 'PUJ', 'PVD', 'PWM', 'RDU', 'RIC', 'ROA', 'ROC', 'RSW',
#         'SAN', 'SAT', 'SAV', 'SBY', 'SDF', 'SEA', 'SFO', 'SJD', 'SJO',
#         'SJU', 'SLC', 'SMF', 'SRQ', 'STL', 'STT', 'SXM', 'SYR', 'TLH',
#         'TPA', 'TRI', 'TYS', 'UVF', 'VPS', 'XNA', 'YOW', 'YUL', 'YYZ',
#         'TTN', 'MDW', 'MUC', 'LUK', 'GIG', 'HOU'], dtype=object),
#  array(['EZE', 'ABI', 'ABQ', 'ACT', 'AEX', 'AGU', 'AMA', 'ATL', 'AUS',
#         'BDL', 'BHM', 'BJX', 'BMI', 'BNA', 'BNE', 'BOG', 'BOS', 'BPT',
#         'BRO', 'BTR', 'BWI', 'BZE', 'CAE', 'CCS', 'CDG', 'CHA', 'CHS',
#         'CID', 'CLE', 'CLL', 'CLT', 'CMH', 'CMI', 'COS', 'COU', 'CRP',
#         'CRW', 'CUN', 'CUU', 'CVG', 'CZM', 'DAY', 'DCA', 'DEN', 'DRO',
#         'DSM', 'DTW', 'ELP', 'EVV', 'EWR', 'FAR', 'FAT', 'FLL', 'FRA',
#         'FSD', 'FSM', 'FWA', 'GCK', 'GDL', 'GGG', 'GIG', 'GJT', 'GPT',
#         'GRI', 'GRK', 'GRR', 'GRU', 'GSO', 'GSP', 'GUA', 'HNL', 'HOU',
#         'HSV', 'IAD', 'IAH', 'ICN', 'ICT', 'IND', 'JAN', 'JAX', 'JFK',
#         'JLN', 'LAS', 'LAW', 'LAX', 'LBB', 'LCH', 'LEX', 'LFT', 'LGA',
#         'LHR', 'LIM', 'LIR', 'LIT', 'LRD', 'MAD', 'MAF', 'MBJ', 'MCI',
#         'MCO', 'MEM', 'MEX', 'MFE', 'MGM', 'MHK', 'MIA', 'MKE', 'MLI',
#         'MLM', 'MLU', 'MOB', 'MSN', 'MSP', 'MSY', 'MTY', 'MZT', 'NAS',
#         'NRT', 'OGG', 'OKC', 'OMA', 'ONT', 'ORD', 'ORF', 'PBC', 'PBI',
#         'PDX', 'PHL', 'PHX', 'PIA', 'PIT', 'PLS', 'PNS', 'PSP', 'PTY',
#         'PVR', 'QRO', 'RAP', 'RDU', 'RIC', 'RNO', 'ROW', 'RSW', 'RTB',
#         'SAF', 'SAL', 'SAN', 'SAT', 'SAV', 'SCL', 'SDF', 'SEA', 'SFO',
#         'SGF', 'SHV', 'SJC', 'SJD', 'SJO', 'SJT', 'SJU', 'SLC', 'SLP',
#         'SMF', 'SNA', 'SPI', 'SPS', 'STL', 'TLH', 'TPA', 'TRC', 'TUL',
#         'TUS', 'TXK', 'TYR', 'TYS', 'VPS', 'XNA', 'YEG', 'YUL', 'YVR',
#         'YYC', 'YYZ', 'ZCL', 'DXB', 'AMS', 'MYR', 'OAK'], dtype=object),
#  array(['BRL', 'DEC', 'ABQ', 'ALO', 'AMM', 'ART', 'ATL', 'AUH', 'AUS',
#         'AZO', 'BDL', 'BMI', 'BNA', 'BOS', 'BUF', 'BWI', 'CDG', 'CHA',
#         'CHO', 'CID', 'CLE', 'CLT', 'CMH', 'CMI', 'COU', 'CUN', 'CVG',
#         'CWA', 'DAY', 'DBQ', 'DCA', 'DEN', 'DFW', 'DOH', 'DSM', 'DTW',
#         'DUB', 'DUS', 'ELP', 'EVV', 'EWR', 'FAR', 'FCO', 'FLL', 'FNT',
#         'FSD', 'FWA', 'GRB', 'GRR', 'HKG', 'HPN', 'HSV', 'IAH', 'ICT',
#         'IND', 'JAX', 'JFK', 'LAS', 'LAX', 'LEX', 'LGA', 'LHR', 'LIT',
#         'LSE', 'MAD', 'MAN', 'MBJ', 'MCI', 'MCO', 'MDT', 'MEM', 'MEX',
#         'MHK', 'MIA', 'MKE', 'MLI', 'MQT', 'MSN', 'MSP', 'MSY', 'NRT',
#         'OKC', 'OMA', 'PBI', 'PDX', 'PEK', 'PHL', 'PHX', 'PIA', 'PIT',
#         'PSP', 'PVG', 'PVR', 'RDU', 'RIC', 'RNO', 'ROC', 'RST', 'RSW',
#         'SAN', 'SAT', 'SDF', 'SEA', 'SFO', 'SGF', 'SJC', 'SJD', 'SJU',
#         'SLC', 'SNA', 'STL', 'SUX', 'SYR', 'TOL', 'TPA', 'TUL', 'TUS',
#         'TVC', 'TXL', 'TYS', 'XNA', 'YKF', 'YUL', 'YVR', 'YYC', 'YYZ',
#         'YEG', 'YHZ', 'YOW', 'YQB', 'YQR', 'YWG', 'YXU', 'DEL', 'GDL',
#         'ANC', 'SAL', 'PTY', 'AMS', 'ICN', 'PUJ', 'GCM', 'FRA', 'MUC',
#         'WAW', 'ZRH', 'ACY', 'MYR', 'OAK', 'VIE', 'ARN', 'CPH', 'BRU',
#         'IST', 'ABE', 'ALB', 'ATW', 'AVL', 'AVP', 'BHM', 'BOI', 'BTV',
#         'BZN', 'CAE', 'CAK', 'CHS', 'CMX', 'COS', 'CRW', 'DLH', 'EAU',
#         'ELM', 'FOE', 'GRU', 'GSO', 'GSP', 'HNL', 'IAD', 'JAN', 'LAN',
#         'LNK', 'MBS', 'MHT', 'MKG', 'MOB', 'MTY', 'NAS', 'OGG', 'ORF',
#         'PAH', 'PNS', 'PVD', 'PWM', 'RAP', 'ROA', 'SAV', 'SBN', 'SCE',
#         'SJO', 'SMF', 'SPI', 'SRQ', 'STC', 'STT', 'SXM', 'YXE'],
#        dtype=object),
#  array(['AGS', 'ALB', 'BDL', 'BGR', 'BHM', 'BNA', 'BOS', 'BTV', 'BUF',
#         'CAE', 'CAK', 'CHA', 'CHS', 'CLT', 'CMH', 'CRW', 'CVG', 'DAY',
#         'DFW', 'DSM', 'DTW', 'FAY', 'FLL', 'GSO', 'GSP', 'HHH', 'HPN',
#         'HSV', 'ILM', 'IND', 'ISP', 'JAN', 'JAX', 'JFK', 'LAS', 'LAX',
#         'LGA', 'LIT', 'MCI', 'MCO', 'MEM', 'MHT', 'MIA', 'MSP', 'MSY',
#         'MYR', 'NAS', 'OAJ', 'OMA', 'ORD', 'ORF', 'PBI', 'PDX', 'PHL',
#         'PHX', 'PIT', 'PNS', 'PVD', 'PWM', 'RDU', 'ROC', 'RSW', 'SAN',
#         'SAV', 'SDF', 'SRQ', 'STL', 'SYR', 'TLH', 'TPA', 'TYS', 'VPS',
#         'YHZ', 'YUL', 'YYZ', 'YOW', 'ATL', 'SEA', 'SJU', 'LEX', 'MSN',
#         'SLC', 'DEN', 'MKE', 'LAN', 'CLE', 'EWR', 'IAH', 'SFO', 'AUS',
#         'HOU'], dtype=object),
#  array(['MSY', 'CLT', 'DCA', 'DFW', 'LGA', 'MIA', 'ORD', 'PHL', 'PHX',
#         'YUL', 'YYZ', 'ATL', 'CDG', 'FRA', 'LHR', 'CUN', 'MEX', 'MTY',
#         'PDX', 'SAN', 'BOS', 'PEK', 'PVG', 'ABE', 'ALB', 'AMS', 'APN',
#         'ATW', 'AUS', 'AVL', 'AVP', 'AZO', 'BDL', 'BGM', 'BGR', 'BHM',
#         'BMI', 'BNA', 'BTV', 'BUF', 'BWI', 'CAE', 'CAK', 'CHA', 'CHS',
#         'CID', 'CIU', 'CLE', 'CMH', 'CRW', 'CVG', 'CWA', 'DAY', 'DEN',
#         'DSM', 'ELM', 'ERI', 'ESC', 'EVV', 'EWR', 'FLL', 'FWA', 'GCM',
#         'GRB', 'GRR', 'GRU', 'GSO', 'GSP', 'HPN', 'HSV', 'IAD', 'IAH',
#         'ICN', 'IND', 'ITH', 'JAX', 'JFK', 'LAN', 'LAS', 'LAX', 'LEX',
#         'LIT', 'MBJ', 'MBS', 'MCI', 'MCO', 'MDT', 'MDW', 'MEM', 'MHT',
#         'MKE', 'MLI', 'MQT', 'MSN', 'MSP', 'MYR', 'NAS', 'NGO', 'NRT',
#         'OKC', 'OMA', 'ORF', 'PBI', 'PIA', 'PIT', 'PLN', 'PUJ', 'PVD',
#         'PWM', 'RDU', 'RIC', 'ROA', 'ROC', 'RSW', 'SAT', 'SAV', 'SBN',
#         'SCE', 'SDF', 'SEA', 'SFO', 'SJU', 'SLC', 'STL', 'SWF', 'SYR',
#         'TPA', 'TUL', 'TVC', 'TYS', 'XNA', 'YOW', 'ILG', 'TTN', 'ACY'],
#        dtype=object),
#  array(['MSY', 'BNA', 'BOS', 'CHO', 'CLT', 'CMH', 'DAY', 'DCA', 'DFW',
#         'DTW', 'GSO', 'ILM', 'LIT', 'MIA', 'ORD', 'ORF', 'PBI', 'PHL',
#         'PIT', 'RDU', 'RIC', 'ROA', 'SDF', 'STL', 'TYS', 'XNA', 'YUL',
#         'YYZ', 'YOW', 'ATL', 'FLL', 'MCO', 'RSW', 'SRQ', 'TPA', 'AUA',
#         'BGR', 'BHM', 'BTV', 'BUF', 'CAE', 'CHS', 'CLE', 'CVG', 'DEN',
#         'DSM', 'EYW', 'GRR', 'GSP', 'IAH', 'IND', 'JAX', 'LEX', 'MCI',
#         'MEM', 'MHT', 'MKE', 'MSN', 'MSP', 'MYR', 'OMA', 'PWM', 'ROC',
#         'SAV', 'SYR', 'YHZ', 'CAK', 'MDW', 'IAD', 'HOU'], dtype=object),
#  array(['ATL', 'MSY', 'CLT', 'DCA', 'DFW', 'MIA', 'ORD', 'PHL', 'PHX',
#         'YYZ', 'CDG', 'LAX', 'LHR', 'SEA', 'SFO', 'CUN', 'SAN', 'ABQ',
#         'ABR', 'ALB', 'AMS', 'ANC', 'APN', 'ATW', 'AUS', 'AZO', 'BDL',
#         'BHM', 'BIL', 'BIS', 'BJI', 'BMI', 'BNA', 'BOI', 'BOS', 'BRD',
#         'BUF', 'BWI', 'BZN', 'CID', 'CLE', 'CMH', 'CVG', 'CWA', 'DAY',
#         'DEN', 'DIK', 'DLH', 'DSM', 'DTW', 'EWR', 'FAR', 'FCA', 'FLL',
#         'FNT', 'FSD', 'FWA', 'GEG', 'GFK', 'GRB', 'GRR', 'GTF', 'HIB',
#         'HLN', 'IAD', 'IAH', 'ICT', 'IMT', 'IND', 'INL', 'ISN', 'JAX',
#         'JFK', 'LAN', 'LAS', 'LEX', 'LGA', 'LNK', 'LSE', 'MBS', 'MCI',
#         'MCO', 'MDW', 'MEM', 'MKE', 'MLI', 'MOT', 'MSN', 'MSO', 'NRT',
#         'OKC', 'OMA', 'ORF', 'PDX', 'PIA', 'PIT', 'PSC', 'PSP', 'RAP',
#         'RDU', 'RHI', 'RIC', 'ROC', 'RST', 'RSW', 'SAT', 'SBN', 'SDF',
#         'SJC', 'SLC', 'SMF', 'SNA', 'STL', 'SYR', 'TPA', 'TUL', 'TUS',
#         'TVC', 'TYS', 'XNA', 'YEG', 'YQR', 'YUL', 'YVR', 'YWG', 'YXE',
#         'YYC', 'OAK', 'PUJ', 'ATY'], dtype=object),
#  array(['BIM', 'ELH', 'EYW', 'FPO', 'GGT', 'GHB', 'MCO', 'MHH', 'TCB',
#         'TPA', 'CLT', 'DCA', 'DFW', 'ORD', 'PAP', 'PHL', 'PHX', 'YUL',
#         'YYZ', 'ATL', 'SEA', 'BOG', 'AUS', 'BDL', 'BOS', 'CUN', 'EWR',
#         'HPN', 'JFK', 'KIN', 'LAX', 'LGA', 'LIM', 'MBJ', 'MDE', 'NAS',
#         'ORH', 'POS', 'PUJ', 'PVD', 'RDU', 'RIC', 'SDQ', 'SFO', 'SJO',
#         'SJU', 'SWF', 'CVG', 'DTW', 'MSP', 'ARN', 'CPH', 'OSL', 'DEN',
#         'TTN', 'BWI', 'HOU', 'MKE', 'MSY', 'AVL', 'GSP', 'LEX', 'PBG',
#         'TYS', 'ACY', 'AUA', 'AXM', 'BQN', 'CTG', 'GUA', 'IAG', 'LAS',
#         'LBE', 'MGA', 'MYR', 'PTY', 'SAL', 'SAP', 'STI', 'STT', 'SXM',
#         'TLC', 'ZSA', 'CLE', 'IAD', 'IAH', 'ALB', 'BNA', 'BUF', 'CMH',
#         'IND', 'ISP', 'JAX', 'MCI', 'MDW', 'PIT', 'STL'], dtype=object),
#  array(['ABE', 'AVL', 'CID', 'CVG', 'DSM', 'FWA', 'GSP', 'IAG', 'ISP',
#         'LEX', 'PIA', 'RFD', 'SBN', 'SGF', 'SPI', 'TOL', 'TYS', 'YNG'],
#        dtype=object),
#  array(['ABE', 'AVL', 'BGR', 'CHA', 'CID', 'DSM', 'ELM', 'FAR', 'FSD',
#         'FWA', 'GRR', 'GSO', 'GSP', 'HTS', 'IAG', 'LCK', 'LEX', 'MDT',
#         'MLI', 'PBG', 'PIA', 'RFD', 'ROA', 'SBN', 'SGF', 'SWF', 'SYR',
#         'TOL', 'TRI', 'TYS', 'YNG'], dtype=object),
#  array(['KEF', 'ABE', 'ATW', 'AVL', 'AVP', 'BGR', 'BIS', 'BLV', 'BMI',
#         'BTV', 'CHA', 'CID', 'CKB', 'CVG', 'DSM', 'ELM', 'FAR', 'FSD',
#         'FWA', 'GFK', 'GRR', 'GSO', 'GSP', 'HGR', 'HTS', 'IAG', 'LAN',
#         'LCK', 'LEX', 'LIT', 'MDT', 'MLI', 'OKC', 'OWB', 'PBG', 'PHF',
#         'PSM', 'RFD', 'ROA', 'SBN', 'SGF', 'SPI', 'TOL', 'TRI', 'TUL',
#         'TYS', 'XNA', 'YNG', 'MIA'], dtype=object),
#  array(['CLT', 'DFW', 'DOH', 'LAX', 'LHR', 'MIA', 'ORD', 'PHL', 'PHX',
#         'MSY', 'YEG', 'YUL', 'YYC', 'YYZ', 'ATL', 'CDG', 'MEX', 'SEA',
#         'BOG', 'SAL', 'DXB', 'CUN', 'PEK', 'PTY', 'SFO', 'AMS', 'CVG',
#         'DTW', 'LGA', 'MEM', 'MSP', 'SLC', 'DEN', 'ICN', 'FRA', 'VCT',
#         'NRT', 'LAS', 'MCO', 'DME', 'IST', 'ABQ', 'ACA', 'ACY', 'AEX',
#         'AGU', 'AMA', 'AUS', 'BFL', 'BHM', 'BJX', 'BNA', 'BON', 'BOS',
#         'BRO', 'BTR', 'BWI', 'BZE', 'CAE', 'CCS', 'CHS', 'CLE', 'CLL',
#         'CME', 'CMH', 'COS', 'CRP', 'CRW', 'CUU', 'CZM', 'DAL', 'DCA',
#         'DGO', 'DSM', 'ELP', 'EWR', 'EZE', 'FLL', 'GCM', 'GDL', 'GIG',
#         'GJT', 'GPT', 'GRK', 'GRR', 'GRU', 'GSP', 'GUA', 'HNL', 'HOB',
#         'HRL', 'HSV', 'HUX', 'IAD', 'ICT', 'IND', 'JAN', 'JAX', 'LBB',
#         'LCH', 'LEX', 'LFT', 'LIM', 'LIR', 'LIT', 'LOS', 'LRD', 'MAF',
#         'MBJ', 'MCI', 'MFE', 'MGA', 'MID', 'MKE', 'MLM', 'MLU', 'MOB',
#         'MTY', 'MUC', 'NAS', 'OAX', 'OKC', 'OMA', 'ONT', 'ORF', 'PBC',
#         'PBI', 'PDX', 'PIT', 'PNS', 'POS', 'PSP', 'PVR', 'QRO', 'RDU',
#         'RIC', 'RSW', 'RTB', 'SAN', 'SAP', 'SAT', 'SAV', 'SDF', 'SHV',
#         'SJC', 'SJD', 'SJO', 'SJU', 'SLP', 'SLW', 'SMF', 'SNA', 'STL',
#         'TAM', 'TGU', 'TPA', 'TRC', 'TUL', 'TUS', 'TYR', 'TYS', 'UIO',
#         'VER', 'VPS', 'VSA', 'XNA', 'YVR', 'ZIH', 'ZLO'], dtype=object)]

# %%
[sUnique.add(x) for x in seconddesetination]
# Out:
# [array(['MSY', 'CLT', 'DCA', 'DFW', 'LGA', 'MIA', 'ORD', 'PHL', 'PHX',
#         'YUL', 'YYZ', 'ATL', 'CDG', 'FRA', 'LHR', 'CUN', 'MEX', 'MTY',
#         'PDX', 'SAN', 'BOS', 'PEK', 'PVG', 'ABE', 'ALB', 'AMS', 'APN',
#         'ATW', 'AUS', 'AVL', 'AVP', 'AZO', 'BDL', 'BGM', 'BGR', 'BHM',
#         'BMI', 'BNA', 'BTV', 'BUF', 'BWI', 'CAE', 'CAK', 'CHA', 'CHS',
#         'CID', 'CIU', 'CLE', 'CMH', 'CRW', 'CVG', 'CWA', 'DAY', 'DEN',
#         'DSM', 'ELM', 'ERI', 'ESC', 'EVV', 'EWR', 'FLL', 'FWA', 'GCM',
#         'GRB', 'GRR', 'GRU', 'GSO', 'GSP', 'HPN', 'HSV', 'IAD', 'IAH',
#         'ICN', 'IND', 'ITH', 'JAX', 'JFK', 'LAN', 'LAS', 'LAX', 'LEX',
#         'LIT', 'MBJ', 'MBS', 'MCI', 'MCO', 'MDT', 'MDW', 'MEM', 'MHT',
#         'MKE', 'MLI', 'MQT', 'MSN', 'MSP', 'MYR', 'NAS', 'NGO', 'NRT',
#         'OKC', 'OMA', 'ORF', 'PBI', 'PIA', 'PIT', 'PLN', 'PUJ', 'PVD',
#         'PWM', 'RDU', 'RIC', 'ROA', 'ROC', 'RSW', 'SAT', 'SAV', 'SBN',
#         'SCE', 'SDF', 'SEA', 'SFO', 'SJU', 'SLC', 'STL', 'SWF', 'SYR',
#         'TPA', 'TUL', 'TVC', 'TYS', 'XNA', 'YOW', 'ILG', 'TTN', 'ACY'],
#        dtype=object),
#  array(['BRL', 'DEC', 'ABQ', 'ALO', 'AMM', 'ART', 'ATL', 'AUH', 'AUS',
#         'AZO', 'BDL', 'BMI', 'BNA', 'BOS', 'BUF', 'BWI', 'CDG', 'CHA',
#         'CHO', 'CID', 'CLE', 'CLT', 'CMH', 'CMI', 'COU', 'CUN', 'CVG',
#         'CWA', 'DAY', 'DBQ', 'DCA', 'DEN', 'DFW', 'DOH', 'DSM', 'DTW',
#         'DUB', 'DUS', 'ELP', 'EVV', 'EWR', 'FAR', 'FCO', 'FLL', 'FNT',
#         'FSD', 'FWA', 'GRB', 'GRR', 'HKG', 'HPN', 'HSV', 'IAH', 'ICT',
#         'IND', 'JAX', 'JFK', 'LAS', 'LAX', 'LEX', 'LGA', 'LHR', 'LIT',
#         'LSE', 'MAD', 'MAN', 'MBJ', 'MCI', 'MCO', 'MDT', 'MEM', 'MEX',
#         'MHK', 'MIA', 'MKE', 'MLI', 'MQT', 'MSN', 'MSP', 'MSY', 'NRT',
#         'OKC', 'OMA', 'PBI', 'PDX', 'PEK', 'PHL', 'PHX', 'PIA', 'PIT',
#         'PSP', 'PVG', 'PVR', 'RDU', 'RIC', 'RNO', 'ROC', 'RST', 'RSW',
#         'SAN', 'SAT', 'SDF', 'SEA', 'SFO', 'SGF', 'SJC', 'SJD', 'SJU',
#         'SLC', 'SNA', 'STL', 'SUX', 'SYR', 'TOL', 'TPA', 'TUL', 'TUS',
#         'TVC', 'TXL', 'TYS', 'XNA', 'YKF', 'YUL', 'YVR', 'YYC', 'YYZ',
#         'YEG', 'YHZ', 'YOW', 'YQB', 'YQR', 'YWG', 'YXU', 'DEL', 'GDL',
#         'ANC', 'SAL', 'PTY', 'AMS', 'ICN', 'PUJ', 'GCM', 'FRA', 'MUC',
#         'WAW', 'ZRH', 'ACY', 'MYR', 'OAK', 'VIE', 'ARN', 'CPH', 'BRU',
#         'IST', 'ABE', 'ALB', 'ATW', 'AVL', 'AVP', 'BHM', 'BOI', 'BTV',
#         'BZN', 'CAE', 'CAK', 'CHS', 'CMX', 'COS', 'CRW', 'DLH', 'EAU',
#         'ELM', 'FOE', 'GRU', 'GSO', 'GSP', 'HNL', 'IAD', 'JAN', 'LAN',
#         'LNK', 'MBS', 'MHT', 'MKG', 'MOB', 'MTY', 'NAS', 'OGG', 'ORF',
#         'PAH', 'PNS', 'PVD', 'PWM', 'RAP', 'ROA', 'SAV', 'SBN', 'SCE',
#         'SJO', 'SMF', 'SPI', 'SRQ', 'STC', 'STT', 'SXM', 'YXE'],
#        dtype=object),
#  array(['AGS', 'ALB', 'BDL', 'BGR', 'BHM', 'BNA', 'BOS', 'BTV', 'BUF',
#         'CAE', 'CAK', 'CHA', 'CHS', 'CLT', 'CMH', 'CRW', 'CVG', 'DAY',
#         'DFW', 'DSM', 'DTW', 'FAY', 'FLL', 'GSO', 'GSP', 'HHH', 'HPN',
#         'HSV', 'ILM', 'IND', 'ISP', 'JAN', 'JAX', 'JFK', 'LAS', 'LAX',
#         'LGA', 'LIT', 'MCI', 'MCO', 'MEM', 'MHT', 'MIA', 'MSP', 'MSY',
#         'MYR', 'NAS', 'OAJ', 'OMA', 'ORD', 'ORF', 'PBI', 'PDX', 'PHL',
#         'PHX', 'PIT', 'PNS', 'PVD', 'PWM', 'RDU', 'ROC', 'RSW', 'SAN',
#         'SAV', 'SDF', 'SRQ', 'STL', 'SYR', 'TLH', 'TPA', 'TYS', 'VPS',
#         'YHZ', 'YUL', 'YYZ', 'YOW', 'ATL', 'SEA', 'SJU', 'LEX', 'MSN',
#         'SLC', 'DEN', 'MKE', 'LAN', 'CLE', 'EWR', 'IAH', 'SFO', 'AUS',
#         'HOU'], dtype=object),
#  array(['KEF', 'ABE', 'ATW', 'AVL', 'AVP', 'BGR', 'BIS', 'BLV', 'BMI',
#         'BTV', 'CHA', 'CID', 'CKB', 'CVG', 'DSM', 'ELM', 'FAR', 'FSD',
#         'FWA', 'GFK', 'GRR', 'GSO', 'GSP', 'HGR', 'HTS', 'IAG', 'LAN',
#         'LCK', 'LEX', 'LIT', 'MDT', 'MLI', 'OKC', 'OWB', 'PBG', 'PHF',
#         'PSM', 'RFD', 'ROA', 'SBN', 'SGF', 'SPI', 'TOL', 'TRI', 'TUL',
#         'TYS', 'XNA', 'YNG', 'MIA'], dtype=object),
#  array(['ATL', 'CLT', 'DFW', 'ORD', 'DCA', 'DTW', 'LGA', 'MSP', 'FLL',
#         'PGD', 'PIE', 'SFB', 'IAH'], dtype=object),
#  array(['CLT', 'DFW', 'DOH', 'LAX', 'LHR', 'MIA', 'ORD', 'PHL', 'PHX',
#         'MSY', 'YEG', 'YUL', 'YYC', 'YYZ', 'ATL', 'CDG', 'MEX', 'SEA',
#         'BOG', 'SAL', 'DXB', 'CUN', 'PEK', 'PTY', 'SFO', 'AMS', 'CVG',
#         'DTW', 'LGA', 'MEM', 'MSP', 'SLC', 'DEN', 'ICN', 'FRA', 'VCT',
#         'NRT', 'LAS', 'MCO', 'DME', 'IST', 'ABQ', 'ACA', 'ACY', 'AEX',
#         'AGU', 'AMA', 'AUS', 'BFL', 'BHM', 'BJX', 'BNA', 'BON', 'BOS',
#         'BRO', 'BTR', 'BWI', 'BZE', 'CAE', 'CCS', 'CHS', 'CLE', 'CLL',
#         'CME', 'CMH', 'COS', 'CRP', 'CRW', 'CUU', 'CZM', 'DAL', 'DCA',
#         'DGO', 'DSM', 'ELP', 'EWR', 'EZE', 'FLL', 'GCM', 'GDL', 'GIG',
#         'GJT', 'GPT', 'GRK', 'GRR', 'GRU', 'GSP', 'GUA', 'HNL', 'HOB',
#         'HRL', 'HSV', 'HUX', 'IAD', 'ICT', 'IND', 'JAN', 'JAX', 'LBB',
#         'LCH', 'LEX', 'LFT', 'LIM', 'LIR', 'LIT', 'LOS', 'LRD', 'MAF',
#         'MBJ', 'MCI', 'MFE', 'MGA', 'MID', 'MKE', 'MLM', 'MLU', 'MOB',
#         'MTY', 'MUC', 'NAS', 'OAX', 'OKC', 'OMA', 'ONT', 'ORF', 'PBC',
#         'PBI', 'PDX', 'PIT', 'PNS', 'POS', 'PSP', 'PVR', 'QRO', 'RDU',
#         'RIC', 'RSW', 'RTB', 'SAN', 'SAP', 'SAT', 'SAV', 'SDF', 'SHV',
#         'SJC', 'SJD', 'SJO', 'SJU', 'SLP', 'SLW', 'SMF', 'SNA', 'STL',
#         'TAM', 'TGU', 'TPA', 'TRC', 'TUL', 'TUS', 'TYR', 'TYS', 'UIO',
#         'VER', 'VPS', 'VSA', 'XNA', 'YVR', 'ZIH', 'ZLO'], dtype=object),
#  array(['ABE', 'AVL', 'CID', 'CVG', 'DSM', 'FWA', 'GSP', 'IAG', 'ISP',
#         'LEX', 'PIA', 'RFD', 'SBN', 'SGF', 'SPI', 'TOL', 'TYS', 'YNG'],
#        dtype=object),
#  array(['ATL', 'MSY', 'CLT', 'DCA', 'DFW', 'MIA', 'ORD', 'PHL', 'PHX',
#         'YYZ', 'CDG', 'LAX', 'LHR', 'SEA', 'SFO', 'CUN', 'SAN', 'ABQ',
#         'ABR', 'ALB', 'AMS', 'ANC', 'APN', 'ATW', 'AUS', 'AZO', 'BDL',
#         'BHM', 'BIL', 'BIS', 'BJI', 'BMI', 'BNA', 'BOI', 'BOS', 'BRD',
#         'BUF', 'BWI', 'BZN', 'CID', 'CLE', 'CMH', 'CVG', 'CWA', 'DAY',
#         'DEN', 'DIK', 'DLH', 'DSM', 'DTW', 'EWR', 'FAR', 'FCA', 'FLL',
#         'FNT', 'FSD', 'FWA', 'GEG', 'GFK', 'GRB', 'GRR', 'GTF', 'HIB',
#         'HLN', 'IAD', 'IAH', 'ICT', 'IMT', 'IND', 'INL', 'ISN', 'JAX',
#         'JFK', 'LAN', 'LAS', 'LEX', 'LGA', 'LNK', 'LSE', 'MBS', 'MCI',
#         'MCO', 'MDW', 'MEM', 'MKE', 'MLI', 'MOT', 'MSN', 'MSO', 'NRT',
#         'OKC', 'OMA', 'ORF', 'PDX', 'PIA', 'PIT', 'PSC', 'PSP', 'RAP',
#         'RDU', 'RHI', 'RIC', 'ROC', 'RST', 'RSW', 'SAT', 'SBN', 'SDF',
#         'SJC', 'SLC', 'SMF', 'SNA', 'STL', 'SYR', 'TPA', 'TUL', 'TUS',
#         'TVC', 'TYS', 'XNA', 'YEG', 'YQR', 'YUL', 'YVR', 'YWG', 'YXE',
#         'YYC', 'OAK', 'PUJ', 'ATY'], dtype=object),
#  array(['BIM', 'ELH', 'EYW', 'FPO', 'GGT', 'GHB', 'MCO', 'MHH', 'TCB',
#         'TPA', 'CLT', 'DCA', 'DFW', 'ORD', 'PAP', 'PHL', 'PHX', 'YUL',
#         'YYZ', 'ATL', 'SEA', 'BOG', 'AUS', 'BDL', 'BOS', 'CUN', 'EWR',
#         'HPN', 'JFK', 'KIN', 'LAX', 'LGA', 'LIM', 'MBJ', 'MDE', 'NAS',
#         'ORH', 'POS', 'PUJ', 'PVD', 'RDU', 'RIC', 'SDQ', 'SFO', 'SJO',
#         'SJU', 'SWF', 'CVG', 'DTW', 'MSP', 'ARN', 'CPH', 'OSL', 'DEN',
#         'TTN', 'BWI', 'HOU', 'MKE', 'MSY', 'AVL', 'GSP', 'LEX', 'PBG',
#         'TYS', 'ACY', 'AUA', 'AXM', 'BQN', 'CTG', 'GUA', 'IAG', 'LAS',
#         'LBE', 'MGA', 'MYR', 'PTY', 'SAL', 'SAP', 'STI', 'STT', 'SXM',
#         'TLC', 'ZSA', 'CLE', 'IAD', 'IAH', 'ALB', 'BNA', 'BUF', 'CMH',
#         'IND', 'ISP', 'JAX', 'MCI', 'MDW', 'PIT', 'STL'], dtype=object),
#  array(['ABE', 'AVL', 'BGR', 'CHA', 'CID', 'DSM', 'ELM', 'FAR', 'FSD',
#         'FWA', 'GRR', 'GSO', 'GSP', 'HTS', 'IAG', 'LCK', 'LEX', 'MDT',
#         'MLI', 'PBG', 'PIA', 'RFD', 'ROA', 'SBN', 'SGF', 'SWF', 'SYR',
#         'TOL', 'TRI', 'TYS', 'YNG'], dtype=object),
#  array(['EZE', 'ABI', 'ABQ', 'ACT', 'AEX', 'AGU', 'AMA', 'ATL', 'AUS',
#         'BDL', 'BHM', 'BJX', 'BMI', 'BNA', 'BNE', 'BOG', 'BOS', 'BPT',
#         'BRO', 'BTR', 'BWI', 'BZE', 'CAE', 'CCS', 'CDG', 'CHA', 'CHS',
#         'CID', 'CLE', 'CLL', 'CLT', 'CMH', 'CMI', 'COS', 'COU', 'CRP',
#         'CRW', 'CUN', 'CUU', 'CVG', 'CZM', 'DAY', 'DCA', 'DEN', 'DRO',
#         'DSM', 'DTW', 'ELP', 'EVV', 'EWR', 'FAR', 'FAT', 'FLL', 'FRA',
#         'FSD', 'FSM', 'FWA', 'GCK', 'GDL', 'GGG', 'GIG', 'GJT', 'GPT',
#         'GRI', 'GRK', 'GRR', 'GRU', 'GSO', 'GSP', 'GUA', 'HNL', 'HOU',
#         'HSV', 'IAD', 'IAH', 'ICN', 'ICT', 'IND', 'JAN', 'JAX', 'JFK',
#         'JLN', 'LAS', 'LAW', 'LAX', 'LBB', 'LCH', 'LEX', 'LFT', 'LGA',
#         'LHR', 'LIM', 'LIR', 'LIT', 'LRD', 'MAD', 'MAF', 'MBJ', 'MCI',
#         'MCO', 'MEM', 'MEX', 'MFE', 'MGM', 'MHK', 'MIA', 'MKE', 'MLI',
#         'MLM', 'MLU', 'MOB', 'MSN', 'MSP', 'MSY', 'MTY', 'MZT', 'NAS',
#         'NRT', 'OGG', 'OKC', 'OMA', 'ONT', 'ORD', 'ORF', 'PBC', 'PBI',
#         'PDX', 'PHL', 'PHX', 'PIA', 'PIT', 'PLS', 'PNS', 'PSP', 'PTY',
#         'PVR', 'QRO', 'RAP', 'RDU', 'RIC', 'RNO', 'ROW', 'RSW', 'RTB',
#         'SAF', 'SAL', 'SAN', 'SAT', 'SAV', 'SCL', 'SDF', 'SEA', 'SFO',
#         'SGF', 'SHV', 'SJC', 'SJD', 'SJO', 'SJT', 'SJU', 'SLC', 'SLP',
#         'SMF', 'SNA', 'SPI', 'SPS', 'STL', 'TLH', 'TPA', 'TRC', 'TUL',
#         'TUS', 'TXK', 'TYR', 'TYS', 'VPS', 'XNA', 'YEG', 'YUL', 'YVR',
#         'YYC', 'YYZ', 'ZCL', 'DXB', 'AMS', 'MYR', 'OAK'], dtype=object),
#  array(['MSY', 'BNA', 'BOS', 'CHO', 'CLT', 'CMH', 'DAY', 'DCA', 'DFW',
#         'DTW', 'GSO', 'ILM', 'LIT', 'MIA', 'ORD', 'ORF', 'PBI', 'PHL',
#         'PIT', 'RDU', 'RIC', 'ROA', 'SDF', 'STL', 'TYS', 'XNA', 'YUL',
#         'YYZ', 'YOW', 'ATL', 'FLL', 'MCO', 'RSW', 'SRQ', 'TPA', 'AUA',
#         'BGR', 'BHM', 'BTV', 'BUF', 'CAE', 'CHS', 'CLE', 'CVG', 'DEN',
#         'DSM', 'EYW', 'GRR', 'GSP', 'IAH', 'IND', 'JAX', 'LEX', 'MCI',
#         'MEM', 'MHT', 'MKE', 'MSN', 'MSP', 'MYR', 'OMA', 'PWM', 'ROC',
#         'SAV', 'SYR', 'YHZ', 'CAK', 'MDW', 'IAD', 'HOU'], dtype=object),
#  array(['LWB', 'MCN', 'MEI', 'MSL', 'PIB', 'TUP', 'AZO', 'CHA', 'CID',
#         'CRW', 'CVG', 'EVV', 'FWA', 'GSO', 'GSP', 'LAN', 'LEX', 'MBS',
#         'MSP', 'ROA', 'SYR', 'TYS', 'XNA', 'CLT', 'DFW', 'LHR', 'MIA',
#         'ORD', 'PHL', 'PHX', 'DEN', 'YYZ', 'ABE', 'ABQ', 'ABY', 'AEX',
#         'AGS', 'ALB', 'ATW', 'AUS', 'AVL', 'AVP', 'BDL', 'BHM', 'BMI',
#         'BNA', 'BOS', 'BQK', 'BRU', 'BTR', 'BTV', 'BUF', 'BWI', 'CAE',
#         'CAK', 'CDG', 'CHO', 'CHS', 'CLE', 'CMH', 'COS', 'CSG', 'CUN',
#         'CZM', 'DAB', 'DAL', 'DAY', 'DCA', 'DHN', 'DSM', 'DTW', 'DUB',
#         'DUS', 'ECP', 'ELP', 'EWN', 'EWR', 'EYW', 'FAY', 'FCO', 'FLL',
#         'FNT', 'FRA', 'FSM', 'GDL', 'GNV', 'GPT', 'GRB', 'GRK', 'GRR',
#         'GTR', 'HPN', 'HSV', 'IAD', 'IAH', 'ICT', 'ILM', 'IND', 'JAN',
#         'JAX', 'JFK', 'LAS', 'LAX', 'LFT', 'LGA', 'LIT', 'MAD', 'MAN',
#         'MCI', 'MCO', 'MDT', 'MDW', 'MEM', 'MEX', 'MGM', 'MHT', 'MKE',
#         'MLB', 'MLI', 'MLU', 'MOB', 'MSN', 'MSY', 'MTY', 'MUC', 'MYR',
#         'NAS', 'OAJ', 'OKC', 'OMA', 'ORF', 'PBI', 'PDX', 'PHF', 'PIA',
#         'PIT', 'PNS', 'PTY', 'PVD', 'PWM', 'RDU', 'RIC', 'ROC', 'RSW',
#         'SAN', 'SAT', 'SAV', 'SBN', 'SDF', 'SEA', 'SFO', 'SGF', 'SHV',
#         'SJO', 'SJU', 'SLC', 'SMF', 'SNA', 'SRQ', 'STL', 'STR', 'TLH',
#         'TPA', 'TRI', 'TUL', 'TUS', 'VLD', 'VPS', 'YUL', 'PVR', 'SJD',
#         'HOU', 'AMS', 'AUA', 'BDA', 'BJX', 'BOG', 'BON', 'BSB', 'BZE',
#         'CCS', 'DXB', 'EZE', 'FAR', 'FPO', 'FSD', 'GCM', 'GGT', 'GIG',
#         'GRU', 'GUA', 'HNL', 'ICN', 'JNB', 'KIN', 'LIM', 'LIR', 'LOS',
#         'MBJ', 'MGA', 'NRT', 'PAP', 'PLS', 'PUJ', 'RTB', 'SAL', 'SAP',
#         'SCL', 'SDQ', 'SJC', 'STT', 'SXM', 'TGU', 'UIO', 'UVF', 'ZRH',
#         'TTN'], dtype=object),
#  array(['CUR', 'ABE', 'AGS', 'ALB', 'ANU', 'ATL', 'AUA', 'AUS', 'AVL',
#         'AVP', 'BDL', 'BHM', 'BNA', 'BOS', 'BTR', 'BUF', 'BWI', 'BZE',
#         'CAE', 'CAK', 'CDG', 'CHA', 'CHO', 'CHS', 'CLE', 'CMH', 'CRW',
#         'CUN', 'CVG', 'CZM', 'DAB', 'DAY', 'DCA', 'DEN', 'DFW', 'DSM',
#         'DTW', 'DUB', 'EWN', 'EWR', 'FAY', 'FCO', 'FLL', 'FLO', 'FPO',
#         'FRA', 'GCM', 'GNV', 'GPT', 'GRU', 'GSO', 'GSP', 'HHH', 'HPN',
#         'HSV', 'HTS', 'IAD', 'IAH', 'ILM', 'IND', 'JAN', 'JAX', 'JFK',
#         'LAS', 'LAX', 'LEX', 'LGA', 'LHR', 'LIR', 'LIT', 'LYH', 'MBJ',
#         'MCI', 'MCO', 'MDT', 'MEM', 'MEX', 'MGM', 'MHT', 'MIA', 'MKE',
#         'MLB', 'MOB', 'MSP', 'MSY', 'MYR', 'NAS', 'OAJ', 'OMA', 'ORD',
#         'ORF', 'PBI', 'PDX', 'PGV', 'PHF', 'PHL', 'PHX', 'PIT', 'PLS',
#         'PNS', 'PUJ', 'PVD', 'PWM', 'RDU', 'RIC', 'ROA', 'ROC', 'RSW',
#         'SAN', 'SAT', 'SAV', 'SBY', 'SDF', 'SEA', 'SFO', 'SJD', 'SJO',
#         'SJU', 'SLC', 'SMF', 'SRQ', 'STL', 'STT', 'SXM', 'SYR', 'TLH',
#         'TPA', 'TRI', 'TYS', 'UVF', 'VPS', 'XNA', 'YOW', 'YUL', 'YYZ',
#         'TTN', 'MDW', 'MUC', 'LUK', 'GIG', 'HOU'], dtype=object)]

# %%
[sUnique.add(x) for x in seconddesetination]
sUnique
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-23-fc0769cd76f5> in <module>
# ----> 1 [sUnique.add(x) for x in seconddesetination]
#       2 sUnique
#
# <ipython-input-23-fc0769cd76f5> in <listcomp>(.0)
# ----> 1 [sUnique.add(x) for x in seconddesetination]
#       2 sUnique
#
# TypeError: unhashable type: 'numpy.ndarray'

# %%
seconddestination = [(routes[routes['SOURCE'].str.contains(x)].drop_duplicates("DEST")["DEST"].unique()) for x in sUnique]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-3d6f1751fa8f> in <module>
# ----> 1 seconddestination = [(routes[routes['SOURCE'].str.contains(x)].drop_duplicates("DEST")["DEST"].unique()) for x in sUnique]
#
# NameError: name 'sUnique' is not defined

# %%
seconddestination = [(routes[routes['SOURCE'].str.contains(x)].drop_duplicates("DEST")["DEST"].unique()) for x in firstdestination]

# %%
print([x for x in source])
# Out:
# ['L', 'E', 'X']

# %%
two_transfers_4m_lex = [(x,y,z) for x in source for y in firstdestination for z in seconddestination]
# Out:
# [array(['LWB', 'MCN', 'MEI', 'MSL', 'PIB', 'TUP', 'AZO', 'CHA', 'CID',
#         'CRW', 'CVG', 'EVV', 'FWA', 'GSO', 'GSP', 'LAN', 'LEX', 'MBS',
#         'MSP', 'ROA', 'SYR', 'TYS', 'XNA', 'CLT', 'DFW', 'LHR', 'MIA',
#         'ORD', 'PHL', 'PHX', 'DEN', 'YYZ', 'ABE', 'ABQ', 'ABY', 'AEX',
#         'AGS', 'ALB', 'ATW', 'AUS', 'AVL', 'AVP', 'BDL', 'BHM', 'BMI',
#         'BNA', 'BOS', 'BQK', 'BRU', 'BTR', 'BTV', 'BUF', 'BWI', 'CAE',
#         'CAK', 'CDG', 'CHO', 'CHS', 'CLE', 'CMH', 'COS', 'CSG', 'CUN',
#         'CZM', 'DAB', 'DAL', 'DAY', 'DCA', 'DHN', 'DSM', 'DTW', 'DUB',
#         'DUS', 'ECP', 'ELP', 'EWN', 'EWR', 'EYW', 'FAY', 'FCO', 'FLL',
#         'FNT', 'FRA', 'FSM', 'GDL', 'GNV', 'GPT', 'GRB', 'GRK', 'GRR',
#         'GTR', 'HPN', 'HSV', 'IAD', 'IAH', 'ICT', 'ILM', 'IND', 'JAN',
#         'JAX', 'JFK', 'LAS', 'LAX', 'LFT', 'LGA', 'LIT', 'MAD', 'MAN',
#         'MCI', 'MCO', 'MDT', 'MDW', 'MEM', 'MEX', 'MGM', 'MHT', 'MKE',
#         'MLB', 'MLI', 'MLU', 'MOB', 'MSN', 'MSY', 'MTY', 'MUC', 'MYR',
#         'NAS', 'OAJ', 'OKC', 'OMA', 'ORF', 'PBI', 'PDX', 'PHF', 'PIA',
#         'PIT', 'PNS', 'PTY', 'PVD', 'PWM', 'RDU', 'RIC', 'ROC', 'RSW',
#         'SAN', 'SAT', 'SAV', 'SBN', 'SDF', 'SEA', 'SFO', 'SGF', 'SHV',
#         'SJO', 'SJU', 'SLC', 'SMF', 'SNA', 'SRQ', 'STL', 'STR', 'TLH',
#         'TPA', 'TRI', 'TUL', 'TUS', 'VLD', 'VPS', 'YUL', 'PVR', 'SJD',
#         'HOU', 'AMS', 'AUA', 'BDA', 'BJX', 'BOG', 'BON', 'BSB', 'BZE',
#         'CCS', 'DXB', 'EZE', 'FAR', 'FPO', 'FSD', 'GCM', 'GGT', 'GIG',
#         'GRU', 'GUA', 'HNL', 'ICN', 'JNB', 'KIN', 'LIM', 'LIR', 'LOS',
#         'MBJ', 'MGA', 'NRT', 'PAP', 'PLS', 'PUJ', 'RTB', 'SAL', 'SAP',
#         'SCL', 'SDQ', 'SJC', 'STT', 'SXM', 'TGU', 'UIO', 'UVF', 'ZRH',
#         'TTN'], dtype=object),
#  array(['CUR', 'ABE', 'AGS', 'ALB', 'ANU', 'ATL', 'AUA', 'AUS', 'AVL',
#         'AVP', 'BDL', 'BHM', 'BNA', 'BOS', 'BTR', 'BUF', 'BWI', 'BZE',
#         'CAE', 'CAK', 'CDG', 'CHA', 'CHO', 'CHS', 'CLE', 'CMH', 'CRW',
#         'CUN', 'CVG', 'CZM', 'DAB', 'DAY', 'DCA', 'DEN', 'DFW', 'DSM',
#         'DTW', 'DUB', 'EWN', 'EWR', 'FAY', 'FCO', 'FLL', 'FLO', 'FPO',
#         'FRA', 'GCM', 'GNV', 'GPT', 'GRU', 'GSO', 'GSP', 'HHH', 'HPN',
#         'HSV', 'HTS', 'IAD', 'IAH', 'ILM', 'IND', 'JAN', 'JAX', 'JFK',
#         'LAS', 'LAX', 'LEX', 'LGA', 'LHR', 'LIR', 'LIT', 'LYH', 'MBJ',
#         'MCI', 'MCO', 'MDT', 'MEM', 'MEX', 'MGM', 'MHT', 'MIA', 'MKE',
#         'MLB', 'MOB', 'MSP', 'MSY', 'MYR', 'NAS', 'OAJ', 'OMA', 'ORD',
#         'ORF', 'PBI', 'PDX', 'PGV', 'PHF', 'PHL', 'PHX', 'PIT', 'PLS',
#         'PNS', 'PUJ', 'PVD', 'PWM', 'RDU', 'RIC', 'ROA', 'ROC', 'RSW',
#         'SAN', 'SAT', 'SAV', 'SBY', 'SDF', 'SEA', 'SFO', 'SJD', 'SJO',
#         'SJU', 'SLC', 'SMF', 'SRQ', 'STL', 'STT', 'SXM', 'SYR', 'TLH',
#         'TPA', 'TRI', 'TYS', 'UVF', 'VPS', 'XNA', 'YOW', 'YUL', 'YYZ',
#         'TTN', 'MDW', 'MUC', 'LUK', 'GIG', 'HOU'], dtype=object),
#  array(['EZE', 'ABI', 'ABQ', 'ACT', 'AEX', 'AGU', 'AMA', 'ATL', 'AUS',
#         'BDL', 'BHM', 'BJX', 'BMI', 'BNA', 'BNE', 'BOG', 'BOS', 'BPT',
#         'BRO', 'BTR', 'BWI', 'BZE', 'CAE', 'CCS', 'CDG', 'CHA', 'CHS',
#         'CID', 'CLE', 'CLL', 'CLT', 'CMH', 'CMI', 'COS', 'COU', 'CRP',
#         'CRW', 'CUN', 'CUU', 'CVG', 'CZM', 'DAY', 'DCA', 'DEN', 'DRO',
#         'DSM', 'DTW', 'ELP', 'EVV', 'EWR', 'FAR', 'FAT', 'FLL', 'FRA',
#         'FSD', 'FSM', 'FWA', 'GCK', 'GDL', 'GGG', 'GIG', 'GJT', 'GPT',
#         'GRI', 'GRK', 'GRR', 'GRU', 'GSO', 'GSP', 'GUA', 'HNL', 'HOU',
#         'HSV', 'IAD', 'IAH', 'ICN', 'ICT', 'IND', 'JAN', 'JAX', 'JFK',
#         'JLN', 'LAS', 'LAW', 'LAX', 'LBB', 'LCH', 'LEX', 'LFT', 'LGA',
#         'LHR', 'LIM', 'LIR', 'LIT', 'LRD', 'MAD', 'MAF', 'MBJ', 'MCI',
#         'MCO', 'MEM', 'MEX', 'MFE', 'MGM', 'MHK', 'MIA', 'MKE', 'MLI',
#         'MLM', 'MLU', 'MOB', 'MSN', 'MSP', 'MSY', 'MTY', 'MZT', 'NAS',
#         'NRT', 'OGG', 'OKC', 'OMA', 'ONT', 'ORD', 'ORF', 'PBC', 'PBI',
#         'PDX', 'PHL', 'PHX', 'PIA', 'PIT', 'PLS', 'PNS', 'PSP', 'PTY',
#         'PVR', 'QRO', 'RAP', 'RDU', 'RIC', 'RNO', 'ROW', 'RSW', 'RTB',
#         'SAF', 'SAL', 'SAN', 'SAT', 'SAV', 'SCL', 'SDF', 'SEA', 'SFO',
#         'SGF', 'SHV', 'SJC', 'SJD', 'SJO', 'SJT', 'SJU', 'SLC', 'SLP',
#         'SMF', 'SNA', 'SPI', 'SPS', 'STL', 'TLH', 'TPA', 'TRC', 'TUL',
#         'TUS', 'TXK', 'TYR', 'TYS', 'VPS', 'XNA', 'YEG', 'YUL', 'YVR',
#         'YYC', 'YYZ', 'ZCL', 'DXB', 'AMS', 'MYR', 'OAK'], dtype=object),
#  array(['BRL', 'DEC', 'ABQ', 'ALO', 'AMM', 'ART', 'ATL', 'AUH', 'AUS',
#         'AZO', 'BDL', 'BMI', 'BNA', 'BOS', 'BUF', 'BWI', 'CDG', 'CHA',
#         'CHO', 'CID', 'CLE', 'CLT', 'CMH', 'CMI', 'COU', 'CUN', 'CVG',
#         'CWA', 'DAY', 'DBQ', 'DCA', 'DEN', 'DFW', 'DOH', 'DSM', 'DTW',
#         'DUB', 'DUS', 'ELP', 'EVV', 'EWR', 'FAR', 'FCO', 'FLL', 'FNT',
#         'FSD', 'FWA', 'GRB', 'GRR', 'HKG', 'HPN', 'HSV', 'IAH', 'ICT',
#         'IND', 'JAX', 'JFK', 'LAS', 'LAX', 'LEX', 'LGA', 'LHR', 'LIT',
#         'LSE', 'MAD', 'MAN', 'MBJ', 'MCI', 'MCO', 'MDT', 'MEM', 'MEX',
#         'MHK', 'MIA', 'MKE', 'MLI', 'MQT', 'MSN', 'MSP', 'MSY', 'NRT',
#         'OKC', 'OMA', 'PBI', 'PDX', 'PEK', 'PHL', 'PHX', 'PIA', 'PIT',
#         'PSP', 'PVG', 'PVR', 'RDU', 'RIC', 'RNO', 'ROC', 'RST', 'RSW',
#         'SAN', 'SAT', 'SDF', 'SEA', 'SFO', 'SGF', 'SJC', 'SJD', 'SJU',
#         'SLC', 'SNA', 'STL', 'SUX', 'SYR', 'TOL', 'TPA', 'TUL', 'TUS',
#         'TVC', 'TXL', 'TYS', 'XNA', 'YKF', 'YUL', 'YVR', 'YYC', 'YYZ',
#         'YEG', 'YHZ', 'YOW', 'YQB', 'YQR', 'YWG', 'YXU', 'DEL', 'GDL',
#         'ANC', 'SAL', 'PTY', 'AMS', 'ICN', 'PUJ', 'GCM', 'FRA', 'MUC',
#         'WAW', 'ZRH', 'ACY', 'MYR', 'OAK', 'VIE', 'ARN', 'CPH', 'BRU',
#         'IST', 'ABE', 'ALB', 'ATW', 'AVL', 'AVP', 'BHM', 'BOI', 'BTV',
#         'BZN', 'CAE', 'CAK', 'CHS', 'CMX', 'COS', 'CRW', 'DLH', 'EAU',
#         'ELM', 'FOE', 'GRU', 'GSO', 'GSP', 'HNL', 'IAD', 'JAN', 'LAN',
#         'LNK', 'MBS', 'MHT', 'MKG', 'MOB', 'MTY', 'NAS', 'OGG', 'ORF',
#         'PAH', 'PNS', 'PVD', 'PWM', 'RAP', 'ROA', 'SAV', 'SBN', 'SCE',
#         'SJO', 'SMF', 'SPI', 'SRQ', 'STC', 'STT', 'SXM', 'YXE'],
#        dtype=object),
#  array(['AGS', 'ALB', 'BDL', 'BGR', 'BHM', 'BNA', 'BOS', 'BTV', 'BUF',
#         'CAE', 'CAK', 'CHA', 'CHS', 'CLT', 'CMH', 'CRW', 'CVG', 'DAY',
#         'DFW', 'DSM', 'DTW', 'FAY', 'FLL', 'GSO', 'GSP', 'HHH', 'HPN',
#         'HSV', 'ILM', 'IND', 'ISP', 'JAN', 'JAX', 'JFK', 'LAS', 'LAX',
#         'LGA', 'LIT', 'MCI', 'MCO', 'MEM', 'MHT', 'MIA', 'MSP', 'MSY',
#         'MYR', 'NAS', 'OAJ', 'OMA', 'ORD', 'ORF', 'PBI', 'PDX', 'PHL',
#         'PHX', 'PIT', 'PNS', 'PVD', 'PWM', 'RDU', 'ROC', 'RSW', 'SAN',
#         'SAV', 'SDF', 'SRQ', 'STL', 'SYR', 'TLH', 'TPA', 'TYS', 'VPS',
#         'YHZ', 'YUL', 'YYZ', 'YOW', 'ATL', 'SEA', 'SJU', 'LEX', 'MSN',
#         'SLC', 'DEN', 'MKE', 'LAN', 'CLE', 'EWR', 'IAH', 'SFO', 'AUS',
#         'HOU'], dtype=object),
#  array(['MSY', 'CLT', 'DCA', 'DFW', 'LGA', 'MIA', 'ORD', 'PHL', 'PHX',
#         'YUL', 'YYZ', 'ATL', 'CDG', 'FRA', 'LHR', 'CUN', 'MEX', 'MTY',
#         'PDX', 'SAN', 'BOS', 'PEK', 'PVG', 'ABE', 'ALB', 'AMS', 'APN',
#         'ATW', 'AUS', 'AVL', 'AVP', 'AZO', 'BDL', 'BGM', 'BGR', 'BHM',
#         'BMI', 'BNA', 'BTV', 'BUF', 'BWI', 'CAE', 'CAK', 'CHA', 'CHS',
#         'CID', 'CIU', 'CLE', 'CMH', 'CRW', 'CVG', 'CWA', 'DAY', 'DEN',
#         'DSM', 'ELM', 'ERI', 'ESC', 'EVV', 'EWR', 'FLL', 'FWA', 'GCM',
#         'GRB', 'GRR', 'GRU', 'GSO', 'GSP', 'HPN', 'HSV', 'IAD', 'IAH',
#         'ICN', 'IND', 'ITH', 'JAX', 'JFK', 'LAN', 'LAS', 'LAX', 'LEX',
#         'LIT', 'MBJ', 'MBS', 'MCI', 'MCO', 'MDT', 'MDW', 'MEM', 'MHT',
#         'MKE', 'MLI', 'MQT', 'MSN', 'MSP', 'MYR', 'NAS', 'NGO', 'NRT',
#         'OKC', 'OMA', 'ORF', 'PBI', 'PIA', 'PIT', 'PLN', 'PUJ', 'PVD',
#         'PWM', 'RDU', 'RIC', 'ROA', 'ROC', 'RSW', 'SAT', 'SAV', 'SBN',
#         'SCE', 'SDF', 'SEA', 'SFO', 'SJU', 'SLC', 'STL', 'SWF', 'SYR',
#         'TPA', 'TUL', 'TVC', 'TYS', 'XNA', 'YOW', 'ILG', 'TTN', 'ACY'],
#        dtype=object),
#  array(['MSY', 'BNA', 'BOS', 'CHO', 'CLT', 'CMH', 'DAY', 'DCA', 'DFW',
#         'DTW', 'GSO', 'ILM', 'LIT', 'MIA', 'ORD', 'ORF', 'PBI', 'PHL',
#         'PIT', 'RDU', 'RIC', 'ROA', 'SDF', 'STL', 'TYS', 'XNA', 'YUL',
#         'YYZ', 'YOW', 'ATL', 'FLL', 'MCO', 'RSW', 'SRQ', 'TPA', 'AUA',
#         'BGR', 'BHM', 'BTV', 'BUF', 'CAE', 'CHS', 'CLE', 'CVG', 'DEN',
#         'DSM', 'EYW', 'GRR', 'GSP', 'IAH', 'IND', 'JAX', 'LEX', 'MCI',
#         'MEM', 'MHT', 'MKE', 'MSN', 'MSP', 'MYR', 'OMA', 'PWM', 'ROC',
#         'SAV', 'SYR', 'YHZ', 'CAK', 'MDW', 'IAD', 'HOU'], dtype=object),
#  array(['ATL', 'MSY', 'CLT', 'DCA', 'DFW', 'MIA', 'ORD', 'PHL', 'PHX',
#         'YYZ', 'CDG', 'LAX', 'LHR', 'SEA', 'SFO', 'CUN', 'SAN', 'ABQ',
#         'ABR', 'ALB', 'AMS', 'ANC', 'APN', 'ATW', 'AUS', 'AZO', 'BDL',
#         'BHM', 'BIL', 'BIS', 'BJI', 'BMI', 'BNA', 'BOI', 'BOS', 'BRD',
#         'BUF', 'BWI', 'BZN', 'CID', 'CLE', 'CMH', 'CVG', 'CWA', 'DAY',
#         'DEN', 'DIK', 'DLH', 'DSM', 'DTW', 'EWR', 'FAR', 'FCA', 'FLL',
#         'FNT', 'FSD', 'FWA', 'GEG', 'GFK', 'GRB', 'GRR', 'GTF', 'HIB',
#         'HLN', 'IAD', 'IAH', 'ICT', 'IMT', 'IND', 'INL', 'ISN', 'JAX',
#         'JFK', 'LAN', 'LAS', 'LEX', 'LGA', 'LNK', 'LSE', 'MBS', 'MCI',
#         'MCO', 'MDW', 'MEM', 'MKE', 'MLI', 'MOT', 'MSN', 'MSO', 'NRT',
#         'OKC', 'OMA', 'ORF', 'PDX', 'PIA', 'PIT', 'PSC', 'PSP', 'RAP',
#         'RDU', 'RHI', 'RIC', 'ROC', 'RST', 'RSW', 'SAT', 'SBN', 'SDF',
#         'SJC', 'SLC', 'SMF', 'SNA', 'STL', 'SYR', 'TPA', 'TUL', 'TUS',
#         'TVC', 'TYS', 'XNA', 'YEG', 'YQR', 'YUL', 'YVR', 'YWG', 'YXE',
#         'YYC', 'OAK', 'PUJ', 'ATY'], dtype=object),
#  array(['BIM', 'ELH', 'EYW', 'FPO', 'GGT', 'GHB', 'MCO', 'MHH', 'TCB',
#         'TPA', 'CLT', 'DCA', 'DFW', 'ORD', 'PAP', 'PHL', 'PHX', 'YUL',
#         'YYZ', 'ATL', 'SEA', 'BOG', 'AUS', 'BDL', 'BOS', 'CUN', 'EWR',
#         'HPN', 'JFK', 'KIN', 'LAX', 'LGA', 'LIM', 'MBJ', 'MDE', 'NAS',
#         'ORH', 'POS', 'PUJ', 'PVD', 'RDU', 'RIC', 'SDQ', 'SFO', 'SJO',
#         'SJU', 'SWF', 'CVG', 'DTW', 'MSP', 'ARN', 'CPH', 'OSL', 'DEN',
#         'TTN', 'BWI', 'HOU', 'MKE', 'MSY', 'AVL', 'GSP', 'LEX', 'PBG',
#         'TYS', 'ACY', 'AUA', 'AXM', 'BQN', 'CTG', 'GUA', 'IAG', 'LAS',
#         'LBE', 'MGA', 'MYR', 'PTY', 'SAL', 'SAP', 'STI', 'STT', 'SXM',
#         'TLC', 'ZSA', 'CLE', 'IAD', 'IAH', 'ALB', 'BNA', 'BUF', 'CMH',
#         'IND', 'ISP', 'JAX', 'MCI', 'MDW', 'PIT', 'STL'], dtype=object),
#  array(['ABE', 'AVL', 'CID', 'CVG', 'DSM', 'FWA', 'GSP', 'IAG', 'ISP',
#         'LEX', 'PIA', 'RFD', 'SBN', 'SGF', 'SPI', 'TOL', 'TYS', 'YNG'],
#        dtype=object),
#  array(['ABE', 'AVL', 'BGR', 'CHA', 'CID', 'DSM', 'ELM', 'FAR', 'FSD',
#         'FWA', 'GRR', 'GSO', 'GSP', 'HTS', 'IAG', 'LCK', 'LEX', 'MDT',
#         'MLI', 'PBG', 'PIA', 'RFD', 'ROA', 'SBN', 'SGF', 'SWF', 'SYR',
#         'TOL', 'TRI', 'TYS', 'YNG'], dtype=object),
#  array(['KEF', 'ABE', 'ATW', 'AVL', 'AVP', 'BGR', 'BIS', 'BLV', 'BMI',
#         'BTV', 'CHA', 'CID', 'CKB', 'CVG', 'DSM', 'ELM', 'FAR', 'FSD',
#         'FWA', 'GFK', 'GRR', 'GSO', 'GSP', 'HGR', 'HTS', 'IAG', 'LAN',
#         'LCK', 'LEX', 'LIT', 'MDT', 'MLI', 'OKC', 'OWB', 'PBG', 'PHF',
#         'PSM', 'RFD', 'ROA', 'SBN', 'SGF', 'SPI', 'TOL', 'TRI', 'TUL',
#         'TYS', 'XNA', 'YNG', 'MIA'], dtype=object),
#  array(['CLT', 'DFW', 'DOH', 'LAX', 'LHR', 'MIA', 'ORD', 'PHL', 'PHX',
#         'MSY', 'YEG', 'YUL', 'YYC', 'YYZ', 'ATL', 'CDG', 'MEX', 'SEA',
#         'BOG', 'SAL', 'DXB', 'CUN', 'PEK', 'PTY', 'SFO', 'AMS', 'CVG',
#         'DTW', 'LGA', 'MEM', 'MSP', 'SLC', 'DEN', 'ICN', 'FRA', 'VCT',
#         'NRT', 'LAS', 'MCO', 'DME', 'IST', 'ABQ', 'ACA', 'ACY', 'AEX',
#         'AGU', 'AMA', 'AUS', 'BFL', 'BHM', 'BJX', 'BNA', 'BON', 'BOS',
#         'BRO', 'BTR', 'BWI', 'BZE', 'CAE', 'CCS', 'CHS', 'CLE', 'CLL',
#         'CME', 'CMH', 'COS', 'CRP', 'CRW', 'CUU', 'CZM', 'DAL', 'DCA',
#         'DGO', 'DSM', 'ELP', 'EWR', 'EZE', 'FLL', 'GCM', 'GDL', 'GIG',
#         'GJT', 'GPT', 'GRK', 'GRR', 'GRU', 'GSP', 'GUA', 'HNL', 'HOB',
#         'HRL', 'HSV', 'HUX', 'IAD', 'ICT', 'IND', 'JAN', 'JAX', 'LBB',
#         'LCH', 'LEX', 'LFT', 'LIM', 'LIR', 'LIT', 'LOS', 'LRD', 'MAF',
#         'MBJ', 'MCI', 'MFE', 'MGA', 'MID', 'MKE', 'MLM', 'MLU', 'MOB',
#         'MTY', 'MUC', 'NAS', 'OAX', 'OKC', 'OMA', 'ONT', 'ORF', 'PBC',
#         'PBI', 'PDX', 'PIT', 'PNS', 'POS', 'PSP', 'PVR', 'QRO', 'RDU',
#         'RIC', 'RSW', 'RTB', 'SAN', 'SAP', 'SAT', 'SAV', 'SDF', 'SHV',
#         'SJC', 'SJD', 'SJO', 'SJU', 'SLP', 'SLW', 'SMF', 'SNA', 'STL',
#         'TAM', 'TGU', 'TPA', 'TRC', 'TUL', 'TUS', 'TYR', 'TYS', 'UIO',
#         'VER', 'VPS', 'VSA', 'XNA', 'YVR', 'ZIH', 'ZLO'], dtype=object)]

# %%
two_transfers_4m_lex = [(x,y,z) for x in source for y in firstdestination for z in seconddestination]
print(two_transfers_4m_lex)
# Out:
# [('L', 'ATL', array(['LWB', 'MCN', 'MEI', 'MSL', 'PIB', 'TUP', 'AZO', 'CHA', 'CID',
#        'CRW', 'CVG', 'EVV', 'FWA', 'GSO', 'GSP', 'LAN', 'LEX', 'MBS',
#        'MSP', 'ROA', 'SYR', 'TYS', 'XNA', 'CLT', 'DFW', 'LHR', 'MIA',
#        'ORD', 'PHL', 'PHX', 'DEN', 'YYZ', 'ABE', 'ABQ', 'ABY', 'AEX',
#        'AGS', 'ALB', 'ATW', 'AUS', 'AVL', 'AVP', 'BDL', 'BHM', 'BMI',
#        'BNA', 'BOS', 'BQK', 'BRU', 'BTR', 'BTV', 'BUF', 'BWI', 'CAE',
#        'CAK', 'CDG', 'CHO', 'CHS', 'CLE', 'CMH', 'COS', 'CSG', 'CUN',
#        'CZM', 'DAB', 'DAL', 'DAY', 'DCA', 'DHN', 'DSM', 'DTW', 'DUB',
#        'DUS', 'ECP', 'ELP', 'EWN', 'EWR', 'EYW', 'FAY', 'FCO', 'FLL',
#        'FNT', 'FRA', 'FSM', 'GDL', 'GNV', 'GPT', 'GRB', 'GRK', 'GRR',
#        'GTR', 'HPN', 'HSV', 'IAD', 'IAH', 'ICT', 'ILM', 'IND', 'JAN',
#        'JAX', 'JFK', 'LAS', 'LAX', 'LFT', 'LGA', 'LIT', 'MAD', 'MAN',
#        'MCI', 'MCO', 'MDT', 'MDW', 'MEM', 'MEX', 'MGM', 'MHT', 'MKE',
#        'MLB', 'MLI', 'MLU', 'MOB', 'MSN', 'MSY', 'MTY', 'MUC', 'MYR',
#        'NAS', 'OAJ', 'OKC', 'OMA', 'ORF', 'PBI', 'PDX', 'PHF', 'PIA',
#        'PIT', 'PNS', 'PTY', 'PVD', 'PWM', 'RDU', 'RIC', 'ROC', 'RSW',
#        'SAN', 'SAT', 'SAV', 'SBN', 'SDF', 'SEA', 'SFO', 'SGF', 'SHV',
#        'SJO', 'SJU', 'SLC', 'SMF', 'SNA', 'SRQ', 'STL', 'STR', 'TLH',
#        'TPA', 'TRI', 'TUL', 'TUS', 'VLD', 'VPS', 'YUL', 'PVR', 'SJD',
#        'HOU', 'AMS', 'AUA', 'BDA', 'BJX', 'BOG', 'BON', 'BSB', 'BZE',
#        'CCS', 'DXB', 'EZE', 'FAR', 'FPO', 'FSD', 'GCM', 'GGT', 'GIG',
#        'GRU', 'GUA', 'HNL', 'ICN', 'JNB', 'KIN', 'LIM', 'LIR', 'LOS',
#        'MBJ', 'MGA', 'NRT', 'PAP', 'PLS', 'PUJ', 'RTB', 'SAL', 'SAP',
#        'SCL', 'SDQ', 'SJC', 'STT', 'SXM', 'TGU', 'UIO', 'UVF', 'ZRH',
#        'TTN'], dtype=object)), ('L', 'ATL', array(['CUR', 'ABE', 'AGS', 'ALB', 'ANU', 'ATL', 'AUA', 'AUS', 'AVL',
#        'AVP', 'BDL', 'BHM', 'BNA', 'BOS', 'BTR', 'BUF', 'BWI', 'BZE',
#        'CAE', 'CAK', 'CDG', 'CHA', 'CHO', 'CHS', 'CLE', 'CMH', 'CRW',
#        'CUN', 'CVG', 'CZM', 'DAB', 'DAY', 'DCA', 'DEN', 'DFW', 'DSM',
#        'DTW', 'DUB', 'EWN', 'EWR', 'FAY', 'FCO', 'FLL', 'FLO', 'FPO',
#        'FRA', 'GCM', 'GNV', 'GPT', 'GRU', 'GSO', 'GSP', 'HHH', 'HPN',
#        'HSV', 'HTS', 'IAD', 'IAH', 'ILM', 'IND', 'JAN', 'JAX', 'JFK',
#        'LAS', 'LAX', 'LEX', 'LGA', 'LHR', 'LIR', 'LIT', 'LYH', 'MBJ',
#        'MCI', 'MCO', 'MDT', 'MEM', 'MEX', 'MGM', 'MHT', 'MIA', 'MKE',
#        'MLB', 'MOB', 'MSP', 'MSY', 'MYR', 'NAS', 'OAJ', 'OMA', 'ORD',
#        'ORF', 'PBI', 'PDX', 'PGV', 'PHF', 'PHL', 'PHX', 'PIT', 'PLS',
#        'PNS', 'PUJ', 'PVD', 'PWM', 'RDU', 'RIC', 'ROA', 'ROC', 'RSW',
#        'SAN', 'SAT', 'SAV', 'SBY', 'SDF', 'SEA', 'SFO', 'SJD', 'SJO',
#        'SJU', 'SLC', 'SMF', 'SRQ', 'STL', 'STT', 'SXM', 'SYR', 'TLH',
#        'TPA', 'TRI', 'TYS', 'UVF', 'VPS', 'XNA', 'YOW', 'YUL', 'YYZ',
#        'TTN', 'MDW', 'MUC', 'LUK', 'GIG', 'HOU'], dtype=object)), ('L', 'ATL', array(['EZE', 'ABI', 'ABQ', 'ACT', 'AEX', 'AGU', 'AMA', 'ATL', 'AUS',
#        'BDL', 'BHM', 'BJX', 'BMI', 'BNA', 'BNE', 'BOG', 'BOS', 'BPT',
#        'BRO', 'BTR', 'BWI', 'BZE', 'CAE', 'CCS', 'CDG', 'CHA', 'CHS',
#        'CID', 'CLE', 'CLL', 'CLT', 'CMH', 'CMI', 'COS', 'COU', 'CRP',
#        'CRW', 'CUN', 'CUU', 'CVG', 'CZM', 'DAY', 'DCA', 'DEN', 'DRO',
#        'DSM', 'DTW', 'ELP', 'EVV', 'EWR', 'FAR', 'FAT', 'FLL', 'FRA',
#        'FSD', 'FSM', 'FWA', 'GCK', 'GDL', 'GGG', 'GIG', 'GJT', 'GPT',
#        'GRI', 'GRK', 'GRR', 'GRU', 'GSO', 'GSP', 'GUA', 'HNL', 'HOU',
#        'HSV', 'IAD', 'IAH', 'ICN', 'ICT', 'IND', 'JAN', 'JAX', 'JFK',
#        'JLN', 'LAS', 'LAW', 'LAX', 'LBB', 'LCH', 'LEX', 'LFT', 'LGA',
#        'LHR', 'LIM', 'LIR', 'LIT', 'LRD', 'MAD', 'MAF', 'MBJ', 'MCI',
#        'MCO', 'MEM', 'MEX', 'MFE', 'MGM', 'MHK', 'MIA', 'MKE', 'MLI',
#        'MLM', 'MLU', 'MOB', 'MSN', 'MSP', 'MSY', 'MTY', 'MZT', 'NAS',
#        'NRT', 'OGG', 'OKC', 'OMA', 'ONT', 'ORD', 'ORF', 'PBC', 'PBI',
#        'PDX', 'PHL', 'PHX', 'PIA', 'PIT', 'PLS', 'PNS', 'PSP', 'PTY',
#        'PVR', 'QRO', 'RAP', 'RDU', 'RIC', 'RNO', 'ROW', 'RSW', 'RTB',
#        'SAF', 'SAL', 'SAN', 'SAT', 'SAV', 'SCL', 'SDF', 'SEA', 'SFO',
#        'SGF', 'SHV', 'SJC', 'SJD', 'SJO', 'SJT', 'SJU', 'SLC', 'SLP',
#        'SMF', 'SNA', 'SPI', 'SPS', 'STL', 'TLH', 'TPA', 'TRC', 'TUL',
#        'TUS', 'TXK', 'TYR', 'TYS', 'VPS', 'XNA', 'YEG', 'YUL', 'YVR',
#        'YYC', 'YYZ', 'ZCL', 'DXB', 'AMS', 'MYR', 'OAK'], dtype=object)), ('L', 'ATL', array(['BRL', 'DEC', 'ABQ', 'ALO', 'AMM', 'ART', 'ATL', 'AUH', 'AUS',
#        'AZO', 'BDL', 'BMI', 'BNA', 'BOS', 'BUF', 'BWI', 'CDG', 'CHA',
#        'CHO', 'CID', 'CLE', 'CLT', 'CMH', 'CMI', 'COU', 'CUN', 'CVG',
#        'CWA', 'DAY', 'DBQ', 'DCA', 'DEN', 'DFW', 'DOH', 'DSM', 'DTW',
#        'DUB', 'DUS', 'ELP', 'EVV', 'EWR', 'FAR', 'FCO', 'FLL', 'FNT',
#        'FSD', 'FWA', 'GRB', 'GRR', 'HKG', 'HPN', 'HSV', 'IAH', 'ICT',
#        'IND', 'JAX', 'JFK', 'LAS', 'LAX', 'LEX', 'LGA', 'LHR', 'LIT',
#        'LSE', 'MAD', 'MAN', 'MBJ', 'MCI', 'MCO', 'MDT', 'MEM', 'MEX',
#        'MHK', 'MIA', 'MKE', 'MLI', 'MQT', 'MSN', 'MSP', 'MSY', 'NRT',
#        'OKC', 'OMA', 'PBI', 'PDX', 'PEK', 'PHL', 'PHX', 'PIA', 'PIT',
#        'PSP', 'PVG', 'PVR', 'RDU', 'RIC', 'RNO', 'ROC', 'RST', 'RSW',
#        'SAN', 'SAT', 'SDF', 'SEA', 'SFO', 'SGF', 'SJC', 'SJD', 'SJU',
#        'SLC', 'SNA', 'STL', 'SUX', 'SYR', 'TOL', 'TPA', 'TUL', 'TUS',
#        'TVC', 'TXL', 'TYS', 'XNA', 'YKF', 'YUL', 'YVR', 'YYC', 'YYZ',
#        'YEG', 'YHZ', 'YOW', 'YQB', 'YQR', 'YWG', 'YXU', 'DEL', 'GDL',
#        'ANC', 'SAL', 'PTY', 'AMS', 'ICN', 'PUJ', 'GCM', 'FRA', 'MUC',
#        'WAW', 'ZRH', 'ACY', 'MYR', 'OAK', 'VIE', 'ARN', 'CPH', 'BRU',
#        'IST', 'ABE', 'ALB', 'ATW', 'AVL', 'AVP', 'BHM', 'BOI', 'BTV',
#        'BZN', 'CAE', 'CAK', 'CHS', 'CMX', 'COS', 'CRW', 'DLH', 'EAU',
#        'ELM', 'FOE', 'GRU', 'GSO', 'GSP', 'HNL', 'IAD', 'JAN', 'LAN',
#        'LNK', 'MBS', 'MHT', 'MKG', 'MOB', 'MTY', 'NAS', 'OGG', 'ORF',
#        'PAH', 'PNS', 'PVD', 'PWM', 'RAP', 'ROA', 'SAV', 'SBN', 'SCE',
#        'SJO', 'SMF', 'SPI', 'SRQ', 'STC', 'STT', 'SXM', 'YXE'],
#       dtype=object)), ('L', 'ATL', array(['AGS', 'ALB', 'BDL', 'BGR', 'BHM', 'BNA', 'BOS', 'BTV', 'BUF',
#        'CAE', 'CAK', 'CHA', 'CHS', 'CLT', 'CMH', 'CRW', 'CVG', 'DAY',
#        'DFW', 'DSM', 'DTW', 'FAY', 'FLL', 'GSO', 'GSP', 'HHH', 'HPN',
#        'HSV', 'ILM', 'IND', 'ISP', 'JAN', 'JAX', 'JFK', 'LAS', 'LAX',
#        'LGA', 'LIT', 'MCI', 'MCO', 'MEM', 'MHT', 'MIA', 'MSP', 'MSY',
#        'MYR', 'NAS', 'OAJ', 'OMA', 'ORD', 'ORF', 'PBI', 'PDX', 'PHL',
#        'PHX', 'PIT', 'PNS', 'PVD', 'PWM', 'RDU', 'ROC', 'RSW', 'SAN',
#        'SAV', 'SDF', 'SRQ', 'STL', 'SYR', 'TLH', 'TPA', 'TYS', 'VPS',
#        'YHZ', 'YUL', 'YYZ', 'YOW', 'ATL', 'SEA', 'SJU', 'LEX', 'MSN',
#        'SLC', 'DEN', 'MKE', 'LAN', 'CLE', 'EWR', 'IAH', 'SFO', 'AUS',
#        'HOU'], dtype=object)), ('L', 'ATL', array(['MSY', 'CLT', 'DCA', 'DFW', 'LGA', 'MIA', 'ORD', 'PHL', 'PHX',
#        'YUL', 'YYZ', 'ATL', 'CDG', 'FRA', 'LHR', 'CUN', 'MEX', 'MTY',
#        'PDX', 'SAN', 'BOS', 'PEK', 'PVG', 'ABE', 'ALB', 'AMS', 'APN',
#        'ATW', 'AUS', 'AVL', 'AVP', 'AZO', 'BDL', 'BGM', 'BGR', 'BHM',
#        'BMI', 'BNA', 'BTV', 'BUF', 'BWI', 'CAE', 'CAK', 'CHA', 'CHS',
#        'CID', 'CIU', 'CLE', 'CMH', 'CRW', 'CVG', 'CWA', 'DAY', 'DEN',
#        'DSM', 'ELM', 'ERI', 'ESC', 'EVV', 'EWR', 'FLL', 'FWA', 'GCM',
#        'GRB', 'GRR', 'GRU', 'GSO', 'GSP', 'HPN', 'HSV', 'IAD', 'IAH',
#        'ICN', 'IND', 'ITH', 'JAX', 'JFK', 'LAN', 'LAS', 'LAX', 'LEX',
#        'LIT', 'MBJ', 'MBS', 'MCI', 'MCO', 'MDT', 'MDW', 'MEM', 'MHT',
#        'MKE', 'MLI', 'MQT', 'MSN', 'MSP', 'MYR', 'NAS', 'NGO', 'NRT',
#        'OKC', 'OMA', 'ORF', 'PBI', 'PIA', 'PIT', 'PLN', 'PUJ', 'PVD',
#        'PWM', 'RDU', 'RIC', 'ROA', 'ROC', 'RSW', 'SAT', 'SAV', 'SBN',
#        'SCE', 'SDF', 'SEA', 'SFO', 'SJU', 'SLC', 'STL', 'SWF', 'SYR',
#        'TPA', 'TUL', 'TVC', 'TYS', 'XNA', 'YOW', 'ILG', 'TTN', 'ACY'],
#       dtype=object)), ('L', 'ATL', array(['MSY', 'BNA', 'BOS', 'CHO', 'CLT', 'CMH', 'DAY', 'DCA', 'DFW',
#        'DTW', 'GSO', 'ILM', 'LIT', 'MIA', 'ORD', 'ORF', 'PBI', 'PHL',
#        'PIT', 'RDU', 'RIC', 'ROA', 'SDF', 'STL', 'TYS', 'XNA', 'YUL',
#        'YYZ', 'YOW', 'ATL', 'FLL', 'MCO', 'RSW', 'SRQ', 'TPA', 'AUA',
#        'BGR', 'BHM', 'BTV', 'BUF', 'CAE', 'CHS', 'CLE', 'CVG', 'DEN',
#        'DSM', 'EYW', 'GRR', 'GSP', 'IAH', 'IND', 'JAX', 'LEX', 'MCI',
#        'MEM', 'MHT', 'MKE', 'MSN', 'MSP', 'MYR', 'OMA', 'PWM', 'ROC',
#        'SAV', 'SYR', 'YHZ', 'CAK', 'MDW', 'IAD', 'HOU'], dtype=object)), ('L', 'ATL', array(['ATL', 'MSY', 'CLT', 'DCA', 'DFW', 'MIA', 'ORD', 'PHL', 'PHX',
#        'YYZ', 'CDG', 'LAX', 'LHR', 'SEA', 'SFO', 'CUN', 'SAN', 'ABQ',
#        'ABR', 'ALB', 'AMS', 'ANC', 'APN', 'ATW', 'AUS', 'AZO', 'BDL',
#        'BHM', 'BIL', 'BIS', 'BJI', 'BMI', 'BNA', 'BOI', 'BOS', 'BRD',
#        'BUF', 'BWI', 'BZN', 'CID', 'CLE', 'CMH', 'CVG', 'CWA', 'DAY',
#        'DEN', 'DIK', 'DLH', 'DSM', 'DTW', 'EWR', 'FAR', 'FCA', 'FLL',
#        'FNT', 'FSD', 'FWA', 'GEG', 'GFK', 'GRB', 'GRR', 'GTF', 'HIB',
#        'HLN', 'IAD', 'IAH', 'ICT', 'IMT', 'IND', 'INL', 'ISN', 'JAX',
#        'JFK', 'LAN', 'LAS', 'LEX', 'LGA', 'LNK', 'LSE', 'MBS', 'MCI',
#        'MCO', 'MDW', 'MEM', 'MKE', 'MLI', 'MOT', 'MSN', 'MSO', 'NRT',
#        'OKC', 'OMA', 'ORF', 'PDX', 'PIA', 'PIT', 'PSC', 'PSP', 'RAP',
#        'RDU', 'RHI', 'RIC', 'ROC', 'RST', 'RSW', 'SAT', 'SBN', 'SDF',
#        'SJC', 'SLC', 'SMF', 'SNA', 'STL', 'SYR', 'TPA', 'TUL', 'TUS',
#        'TVC', 'TYS', 'XNA', 'YEG', 'YQR', 'YUL', 'YVR', 'YWG', 'YXE',
#        'YYC', 'OAK', 'PUJ', 'ATY'], dtype=object)), ('L', 'ATL', array(['BIM', 'ELH', 'EYW', 'FPO', 'GGT', 'GHB', 'MCO', 'MHH', 'TCB',
#        'TPA', 'CLT', 'DCA', 'DFW', 'ORD', 'PAP', 'PHL', 'PHX', 'YUL',
#        'YYZ', 'ATL', 'SEA', 'BOG', 'AUS', 'BDL', 'BOS', 'CUN', 'EWR',
#        'HPN', 'JFK', 'KIN', 'LAX', 'LGA', 'LIM', 'MBJ', 'MDE', 'NAS',
#        'ORH', 'POS', 'PUJ', 'PVD', 'RDU', 'RIC', 'SDQ', 'SFO', 'SJO',
#        'SJU', 'SWF', 'CVG', 'DTW', 'MSP', 'ARN', 'CPH', 'OSL', 'DEN',
#        'TTN', 'BWI', 'HOU', 'MKE', 'MSY', 'AVL', 'GSP', 'LEX', 'PBG',
#        'TYS', 'ACY', 'AUA', 'AXM', 'BQN', 'CTG', 'GUA', 'IAG', 'LAS',
#        'LBE', 'MGA', 'MYR', 'PTY', 'SAL', 'SAP', 'STI', 'STT', 'SXM',
#        'TLC', 'ZSA', 'CLE', 'IAD', 'IAH', 'ALB', 'BNA', 'BUF', 'CMH',
#        'IND', 'ISP', 'JAX', 'MCI', 'MDW', 'PIT', 'STL'], dtype=object)), ('L', 'ATL', array(['ABE', 'AVL', 'CID', 'CVG', 'DSM', 'FWA', 'GSP', 'IAG', 'ISP',
#        'LEX', 'PIA', 'RFD', 'SBN', 'SGF', 'SPI', 'TOL', 'TYS', 'YNG'],
#       dtype=object)), ('L', 'ATL', array(['ABE', 'AVL', 'BGR', 'CHA', 'CID', 'DSM', 'ELM', 'FAR', 'FSD',
#        'FWA', 'GRR', 'GSO', 'GSP', 'HTS', 'IAG', 'LCK', 'LEX', 'MDT',
#        'MLI', 'PBG', 'PIA', 'RFD', 'ROA', 'SBN', 'SGF', 'SWF', 'SYR',
#        'TOL', 'TRI', 'TYS', 'YNG'], dtype=object)), ('L', 'ATL', array(['KEF', 'ABE', 'ATW', 'AVL', 'AVP', 'BGR', 'BIS', 'BLV', 'BMI',
#        'BTV', 'CHA', 'CID', 'CKB', 'CVG', 'DSM', 'ELM', 'FAR', 'FSD',
#        'FWA', 'GFK', 'GRR', 'GSO', 'GSP', 'HGR', 'HTS', 'IAG', 'LAN',
#        'LCK', 'LEX', 'LIT', 'MDT', 'MLI', 'OKC', 'OWB', 'PBG', 'PHF',
#        'PSM', 'RFD', 'ROA', 'SBN', 'SGF', 'SPI', 'TOL', 'TRI', 'TUL',
#        'TYS', 'XNA', 'YNG', 'MIA'], dtype=object)), ('L', 'ATL', array(['CLT', 'DFW', 'DOH', 'LAX', 'LHR', 'MIA', 'ORD', 'PHL', 'PHX',
#        'MSY', 'YEG', 'YUL', 'YYC', 'YYZ', 'ATL', 'CDG', 'MEX', 'SEA',
#        'BOG', 'SAL', 'DXB', 'CUN', 'PEK', 'PTY', 'SFO', 'AMS', 'CVG',
#        'DTW', 'LGA', 'MEM', 'MSP', 'SLC', 'DEN', 'ICN', 'FRA', 'VCT',
#        'NRT', 'LAS', 'MCO', 'DME', 'IST', 'ABQ', 'ACA', 'ACY', 'AEX',
#        'AGU', 'AMA', 'AUS', 'BFL', 'BHM', 'BJX', 'BNA', 'BON', 'BOS',
#        'BRO', 'BTR', 'BWI', 'BZE', 'CAE', 'CCS', 'CHS', 'CLE', 'CLL',
#        'CME', 'CMH', 'COS', 'CRP', 'CRW', 'CUU', 'CZM', 'DAL', 'DCA',
#        'DGO', 'DSM', 'ELP', 'EWR', 'EZE', 'FLL', 'GCM', 'GDL', 'GIG',
#        'GJT', 'GPT', 'GRK', 'GRR', 'GRU', 'GSP', 'GUA', 'HNL', 'HOB',
#        'HRL', 'HSV', 'HUX', 'IAD', 'ICT', 'IND', 'JAN', 'JAX', 'LBB',
#        'LCH', 'LEX', 'LFT', 'LIM', 'LIR', 'LIT', 'LOS', 'LRD', 'MAF',
#        'MBJ', 'MCI', 'MFE', 'MGA', 'MID', 'MKE', 'MLM', 'MLU', 'MOB',
#        'MTY', 'MUC', 'NAS', 'OAX', 'OKC', 'OMA', 'ONT', 'ORF', 'PBC',
#        'PBI', 'PDX', 'PIT', 'PNS', 'POS', 'PSP', 'PVR', 'QRO', 'RDU',
#        'RIC', 'RSW', 'RTB', 'SAN', 'SAP', 'SAT', 'SAV', 'SDF', 'SHV',
#        'SJC', 'SJD', 'SJO', 'SJU', 'SLP', 'SLW', 'SMF', 'SNA', 'STL',
#        'TAM', 'TGU', 'TPA', 'TRC', 'TUL', 'TUS', 'TYR', 'TYS', 'UIO',
#        'VER', 'VPS', 'VSA', 'XNA', 'YVR', 'ZIH', 'ZLO'], dtype=object)), ('L', 'CLT', array(['LWB', 'MCN', 'MEI', 'MSL', 'PIB', 'TUP', 'AZO', 'CHA', 'CID',
#        'CRW', 'CVG', 'EVV', 'FWA', 'GSO', 'GSP', 'LAN', 'LEX', 'MBS',
#        'MSP', 'ROA', 'SYR', 'TYS', 'XNA', 'CLT', 'DFW', 'LHR', 'MIA',
#        'ORD', 'PHL', 'PHX', 'DEN', 'YYZ', 'ABE', 'ABQ', 'ABY', 'AEX',
#        'AGS', 'ALB', 'ATW', 'AUS', 'AVL', 'AVP', 'BDL', 'BHM', 'BMI',
#        'BNA', 'BOS', 'BQK', 'BRU', 'BTR', 'BTV', 'BUF', 'BWI', 'CAE',
#        'CAK', 'CDG', 'CHO', 'CHS', 'CLE', 'CMH', 'COS', 'CSG', 'CUN',
#        'CZM', 'DAB', 'DAL', 'DAY', 'DCA', 'DHN', 'DSM', 'DTW', 'DUB',
#        'DUS', 'ECP', 'ELP', 'EWN', 'EWR', 'EYW', 'FAY', 'FCO', 'FLL',
#        'FNT', 'FRA', 'FSM', 'GDL', 'GNV', 'GPT', 'GRB', 'GRK', 'GRR',
#        'GTR', 'HPN', 'HSV', 'IAD', 'IAH', 'ICT', 'ILM', 'IND', 'JAN',
#        'JAX', 'JFK', 'LAS', 'LAX', 'LFT', 'LGA', 'LIT', 'MAD', 'MAN',
#        'MCI', 'MCO', 'MDT', 'MDW', 'MEM', 'MEX', 'MGM', 'MHT', 'MKE',
#        'MLB', 'MLI', 'MLU', 'MOB', 'MSN', 'MSY', 'MTY', 'MUC', 'MYR',
#        'NAS', 'OAJ', 'OKC', 'OMA', 'ORF', 'PBI', 'PDX', 'PHF', 'PIA',
#        'PIT', 'PNS', 'PTY', 'PVD', 'PWM', 'RDU', 'RIC', 'ROC', 'RSW',
#        'SAN', 'SAT', 'SAV', 'SBN', 'SDF', 'SEA', 'SFO', 'SGF', 'SHV',
#        'SJO', 'SJU', 'SLC', 'SMF', 'SNA', 'SRQ', 'STL', 'STR', 'TLH',
#        'TPA', 'TRI', 'TUL', 'TUS', 'VLD', 'VPS', 'YUL', 'PVR', 'SJD',
#        'HOU', 'AMS', 'AUA', 'BDA', 'BJX', 'BOG', 'BON', 'BSB', 'BZE',
#        'CCS', 'DXB', 'EZE', 'FAR', 'FPO', 'FSD', 'GCM', 'GGT', 'GIG',
#        'GRU', 'GUA', 'HNL', 'ICN', 'JNB', 'KIN', 'LIM', 'LIR', 'LOS',
#        'MBJ', 'MGA', 'NRT', 'PAP', 'PLS', 'PUJ', 'RTB', 'SAL', 'SAP',
#        'SCL', 'SDQ', 'SJC', 'STT', 'SXM', 'TGU', 'UIO', 'UVF', 'ZRH',
#        'TTN'], dtype=object)), ('L', 'CLT', array(['CUR', 'ABE', 'AGS', 'ALB', 'ANU', 'ATL', 'AUA', 'AUS', 'AVL',
#        'AVP', 'BDL', 'BHM', 'BNA', 'BOS', 'BTR', 'BUF', 'BWI', 'BZE',
#        'CAE', 'CAK', 'CDG', 'CHA', 'CHO', 'CHS', 'CLE', 'CMH', 'CRW',
#        'CUN', 'CVG', 'CZM', 'DAB', 'DAY', 'DCA', 'DEN', 'DFW', 'DSM',
#        'DTW', 'DUB', 'EWN', 'EWR', 'FAY', 'FCO', 'FLL', 'FLO', 'FPO',
#        'FRA', 'GCM', 'GNV', 'GPT', 'GRU', 'GSO', 'GSP', 'HHH', 'HPN',
#        'HSV', 'HTS', 'IAD', 'IAH', 'ILM', 'IND', 'JAN', 'JAX', 'JFK',
#        'LAS', 'LAX', 'LEX', 'LGA', 'LHR', 'LIR', 'LIT', 'LYH', 'MBJ',
#        'MCI', 'MCO', 'MDT', 'MEM', 'MEX', 'MGM', 'MHT', 'MIA', 'MKE',
#        'MLB', 'MOB', 'MSP', 'MSY', 'MYR', 'NAS', 'OAJ', 'OMA', 'ORD',
#        'ORF', 'PBI', 'PDX', 'PGV', 'PHF', 'PHL', 'PHX', 'PIT', 'PLS',
#        'PNS', 'PUJ', 'PVD', 'PWM', 'RDU', 'RIC', 'ROA', 'ROC', 'RSW',
#        'SAN', 'SAT', 'SAV', 'SBY', 'SDF', 'SEA', 'SFO', 'SJD', 'SJO',
#        'SJU', 'SLC', 'SMF', 'SRQ', 'STL', 'STT', 'SXM', 'SYR', 'TLH',
#        'TPA', 'TRI', 'TYS', 'UVF', 'VPS', 'XNA', 'YOW', 'YUL', 'YYZ',
#        'TTN', 'MDW', 'MUC', 'LUK', 'GIG', 'HOU'], dtype=object)), ('L', 'CLT', array(['EZE', 'ABI', 'ABQ', 'ACT', 'AEX', 'AGU', 'AMA', 'ATL', 'AUS',
#        'BDL', 'BHM', 'BJX', 'BMI', 'BNA', 'BNE', 'BOG', 'BOS', 'BPT',
#        'BRO', 'BTR', 'BWI', 'BZE', 'CAE', 'CCS', 'CDG', 'CHA', 'CHS',
#        'CID', 'CLE', 'CLL', 'CLT', 'CMH', 'CMI', 'COS', 'COU', 'CRP',
#        'CRW', 'CUN', 'CUU', 'CVG', 'CZM', 'DAY', 'DCA', 'DEN', 'DRO',
#        'DSM', 'DTW', 'ELP', 'EVV', 'EWR', 'FAR', 'FAT', 'FLL', 'FRA',
#        'FSD', 'FSM', 'FWA', 'GCK', 'GDL', 'GGG', 'GIG', 'GJT', 'GPT',
#        'GRI', 'GRK', 'GRR', 'GRU', 'GSO', 'GSP', 'GUA', 'HNL', 'HOU',
#        'HSV', 'IAD', 'IAH', 'ICN', 'ICT', 'IND', 'JAN', 'JAX', 'JFK',
#        'JLN', 'LAS', 'LAW', 'LAX', 'LBB', 'LCH', 'LEX', 'LFT', 'LGA',
#        'LHR', 'LIM', 'LIR', 'LIT', 'LRD', 'MAD', 'MAF', 'MBJ', 'MCI',
#        'MCO', 'MEM', 'MEX', 'MFE', 'MGM', 'MHK', 'MIA', 'MKE', 'MLI',
#        'MLM', 'MLU', 'MOB', 'MSN', 'MSP', 'MSY', 'MTY', 'MZT', 'NAS',
#        'NRT', 'OGG', 'OKC', 'OMA', 'ONT', 'ORD', 'ORF', 'PBC', 'PBI',
#        'PDX', 'PHL', 'PHX', 'PIA', 'PIT', 'PLS', 'PNS', 'PSP', 'PTY',
#        'PVR', 'QRO', 'RAP', 'RDU', 'RIC', 'RNO', 'ROW', 'RSW', 'RTB',
#        'SAF', 'SAL', 'SAN', 'SAT', 'SAV', 'SCL', 'SDF', 'SEA', 'SFO',
#        'SGF', 'SHV', 'SJC', 'SJD', 'SJO', 'SJT', 'SJU', 'SLC', 'SLP',
#        'SMF', 'SNA', 'SPI', 'SPS', 'STL', 'TLH', 'TPA', 'TRC', 'TUL',
#        'TUS', 'TXK', 'TYR', 'TYS', 'VPS', 'XNA', 'YEG', 'YUL', 'YVR',
#        'YYC', 'YYZ', 'ZCL', 'DXB', 'AMS', 'MYR', 'OAK'], dtype=object)), ('L', 'CLT', array(['BRL', 'DEC', 'ABQ', 'ALO', 'AMM', 'ART', 'ATL', 'AUH', 'AUS',
#        'AZO', 'BDL', 'BMI', 'BNA', 'BOS', 'BUF', 'BWI', 'CDG', 'CHA',
#        'CHO', 'CID', 'CLE', 'CLT', 'CMH', 'CMI', 'COU', 'CUN', 'CVG',
#        'CWA', 'DAY', 'DBQ', 'DCA', 'DEN', 'DFW', 'DOH', 'DSM', 'DTW',
#        'DUB', 'DUS', 'ELP', 'EVV', 'EWR', 'FAR', 'FCO', 'FLL', 'FNT',
#        'FSD', 'FWA', 'GRB', 'GRR', 'HKG', 'HPN', 'HSV', 'IAH', 'ICT',
#        'IND', 'JAX', 'JFK', 'LAS', 'LAX', 'LEX', 'LGA', 'LHR', 'LIT',
#        'LSE', 'MAD', 'MAN', 'MBJ', 'MCI', 'MCO', 'MDT', 'MEM', 'MEX',
#        'MHK', 'MIA', 'MKE', 'MLI', 'MQT', 'MSN', 'MSP', 'MSY', 'NRT',
#        'OKC', 'OMA', 'PBI', 'PDX', 'PEK', 'PHL', 'PHX', 'PIA', 'PIT',
#        'PSP', 'PVG', 'PVR', 'RDU', 'RIC', 'RNO', 'ROC', 'RST', 'RSW',
#        'SAN', 'SAT', 'SDF', 'SEA', 'SFO', 'SGF', 'SJC', 'SJD', 'SJU',
#        'SLC', 'SNA', 'STL', 'SUX', 'SYR', 'TOL', 'TPA', 'TUL', 'TUS',
#        'TVC', 'TXL', 'TYS', 'XNA', 'YKF', 'YUL', 'YVR', 'YYC', 'YYZ',
#        'YEG', 'YHZ', 'YOW', 'YQB', 'YQR', 'YWG', 'YXU', 'DEL', 'GDL',
#        'ANC', 'SAL', 'PTY', 'AMS', 'ICN', 'PUJ', 'GCM', 'FRA', 'MUC',
#        'WAW', 'ZRH', 'ACY', 'MYR', 'OAK', 'VIE', 'ARN', 'CPH', 'BRU',
#        'IST', 'ABE', 'ALB', 'ATW', 'AVL', 'AVP', 'BHM', 'BOI', 'BTV',
#        'BZN', 'CAE', 'CAK', 'CHS', 'CMX', 'COS', 'CRW', 'DLH', 'EAU',
#        'ELM', 'FOE', 'GRU', 'GSO', 'GSP', 'HNL', 'IAD', 'JAN', 'LAN',
#        'LNK', 'MBS', 'MHT', 'MKG', 'MOB', 'MTY', 'NAS', 'OGG', 'ORF',
#        'PAH', 'PNS', 'PVD', 'PWM', 'RAP', 'ROA', 'SAV', 'SBN', 'SCE',
#        'SJO', 'SMF', 'SPI', 'SRQ', 'STC', 'STT', 'SXM', 'YXE'],
#       dtype=object)), ('L', 'CLT', array(['AGS', 'ALB', 'BDL', 'BGR', 'BHM', 'BNA', 'BOS', 'BTV', 'BUF',
#        'CAE', 'CAK', 'CHA', 'CHS', 'CLT', 'CMH', 'CRW', 'CVG', 'DAY',
#        'DFW', 'DSM', 'DTW', 'FAY', 'FLL', 'GSO', 'GSP', 'HHH', 'HPN',
#        'HSV', 'ILM', 'IND', 'ISP', 'JAN', 'JAX', 'JFK', 'LAS', 'LAX',
#        'LGA', 'LIT', 'MCI', 'MCO', 'MEM', 'MHT', 'MIA', 'MSP', 'MSY',
#        'MYR', 'NAS', 'OAJ', 'OMA', 'ORD', 'ORF', 'PBI', 'PDX', 'PHL',
#        'PHX', 'PIT', 'PNS', 'PVD', 'PWM', 'RDU', 'ROC', 'RSW', 'SAN',
#        'SAV', 'SDF', 'SRQ', 'STL', 'SYR', 'TLH', 'TPA', 'TYS', 'VPS',
#        'YHZ', 'YUL', 'YYZ', 'YOW', 'ATL', 'SEA', 'SJU', 'LEX', 'MSN',
#        'SLC', 'DEN', 'MKE', 'LAN', 'CLE', 'EWR', 'IAH', 'SFO', 'AUS',
#        'HOU'], dtype=object)), ('L', 'CLT', array(['MSY', 'CLT', 'DCA', 'DFW', 'LGA', 'MIA', 'ORD', 'PHL', 'PHX',
#        'YUL', 'YYZ', 'ATL', 'CDG', 'FRA', 'LHR', 'CUN', 'MEX', 'MTY',
#        'PDX', 'SAN', 'BOS', 'PEK', 'PVG', 'ABE', 'ALB', 'AMS', 'APN',
#        'ATW', 'AUS', 'AVL', 'AVP', 'AZO', 'BDL', 'BGM', 'BGR', 'BHM',
#        'BMI', 'BNA', 'BTV', 'BUF', 'BWI', 'CAE', 'CAK', 'CHA', 'CHS',
#        'CID', 'CIU', 'CLE', 'CMH', 'CRW', 'CVG', 'CWA', 'DAY', 'DEN',
#        'DSM', 'ELM', 'ERI', 'ESC', 'EVV', 'EWR', 'FLL', 'FWA', 'GCM',
#        'GRB', 'GRR', 'GRU', 'GSO', 'GSP', 'HPN', 'HSV', 'IAD', 'IAH',
#        'ICN', 'IND', 'ITH', 'JAX', 'JFK', 'LAN', 'LAS', 'LAX', 'LEX',
#        'LIT', 'MBJ', 'MBS', 'MCI', 'MCO', 'MDT', 'MDW', 'MEM', 'MHT',
#        'MKE', 'MLI', 'MQT', 'MSN', 'MSP', 'MYR', 'NAS', 'NGO', 'NRT',
#        'OKC', 'OMA', 'ORF', 'PBI', 'PIA', 'PIT', 'PLN', 'PUJ', 'PVD',
#        'PWM', 'RDU', 'RIC', 'ROA', 'ROC', 'RSW', 'SAT', 'SAV', 'SBN',
#        'SCE', 'SDF', 'SEA', 'SFO', 'SJU', 'SLC', 'STL', 'SWF', 'SYR',
#        'TPA', 'TUL', 'TVC', 'TYS', 'XNA', 'YOW', 'ILG', 'TTN', 'ACY'],
#       dtype=object)), ('L', 'CLT', array(['MSY', 'BNA', 'BOS', 'CHO', 'CLT', 'CMH', 'DAY', 'DCA', 'DFW',
#        'DTW', 'GSO', 'ILM', 'LIT', 'MIA', 'ORD', 'ORF', 'PBI', 'PHL',
#        'PIT', 'RDU', 'RIC', 'ROA', 'SDF', 'STL', 'TYS', 'XNA', 'YUL',
#        'YYZ', 'YOW', 'ATL', 'FLL', 'MCO', 'RSW', 'SRQ', 'TPA', 'AUA',
#        'BGR', 'BHM', 'BTV', 'BUF', 'CAE', 'CHS', 'CLE', 'CVG', 'DEN',
#        'DSM', 'EYW', 'GRR', 'GSP', 'IAH', 'IND', 'JAX', 'LEX', 'MCI',
#        'MEM', 'MHT', 'MKE', 'MSN', 'MSP', 'MYR', 'OMA', 'PWM', 'ROC',
#        'SAV', 'SYR', 'YHZ', 'CAK', 'MDW', 'IAD', 'HOU'], dtype=object)), ('L', 'CLT', array(['ATL', 'MSY', 'CLT', 'DCA', 'DFW', 'MIA', 'ORD', 'PHL', 'PHX',
#        'YYZ', 'CDG', 'LAX', 'LHR', 'SEA', 'SFO', 'CUN', 'SAN', 'ABQ',
#        'ABR', 'ALB', 'AMS', 'ANC', 'APN', 'ATW', 'AUS', 'AZO', 'BDL',
#        'BHM', 'BIL', 'BIS', 'BJI', 'BMI', 'BNA', 'BOI', 'BOS', 'BRD',
#        'BUF', 'BWI', 'BZN', 'CID', 'CLE', 'CMH', 'CVG', 'CWA', 'DAY',
#        'DEN', 'DIK', 'DLH', 'DSM', 'DTW', 'EWR', 'FAR', 'FCA', 'FLL',
#        'FNT', 'FSD', 'FWA', 'GEG', 'GFK', 'GRB', 'GRR', 'GTF', 'HIB',
#        'HLN', 'IAD', 'IAH', 'ICT', 'IMT', 'IND', 'INL', 'ISN', 'JAX',
#        'JFK', 'LAN', 'LAS', 'LEX', 'LGA', 'LNK', 'LSE', 'MBS', 'MCI',
#        'MCO', 'MDW', 'MEM', 'MKE', 'MLI', 'MOT', 'MSN', 'MSO', 'NRT',
#        'OKC', 'OMA', 'ORF', 'PDX', 'PIA', 'PIT', 'PSC', 'PSP', 'RAP',
#        'RDU', 'RHI', 'RIC', 'ROC', 'RST', 'RSW', 'SAT', 'SBN', 'SDF',
#        'SJC', 'SLC', 'SMF', 'SNA', 'STL', 'SYR', 'TPA', 'TUL', 'TUS',
#        'TVC', 'TYS', 'XNA', 'YEG', 'YQR', 'YUL', 'YVR', 'YWG', 'YXE',
#        'YYC', 'OAK', 'PUJ', 'ATY'], dtype=object)), ('L', 'CLT', array(['BIM', 'ELH', 'EYW', 'FPO', 'GGT', 'GHB', 'MCO', 'MHH', 'TCB',
#        'TPA', 'CLT', 'DCA', 'DFW', 'ORD', 'PAP', 'PHL', 'PHX', 'YUL',
#        'YYZ', 'ATL', 'SEA', 'BOG', 'AUS', 'BDL', 'BOS', 'CUN', 'EWR',
#        'HPN', 'JFK', 'KIN', 'LAX', 'LGA', 'LIM', 'MBJ', 'MDE', 'NAS',
#        'ORH', 'POS', 'PUJ', 'PVD', 'RDU', 'RIC', 'SDQ', 'SFO', 'SJO',
#        'SJU', 'SWF', 'CVG', 'DTW', 'MSP', 'ARN', 'CPH', 'OSL', 'DEN',
#        'TTN', 'BWI', 'HOU', 'MKE', 'MSY', 'AVL', 'GSP', 'LEX', 'PBG',
#        'TYS', 'ACY', 'AUA', 'AXM', 'BQN', 'CTG', 'GUA', 'IAG', 'LAS',
#        'LBE', 'MGA', 'MYR', 'PTY', 'SAL', 'SAP', 'STI', 'STT', 'SXM',
#        'TLC', 'ZSA', 'CLE', 'IAD', 'IAH', 'ALB', 'BNA', 'BUF', 'CMH',
#        'IND', 'ISP', 'JAX', 'MCI', 'MDW', 'PIT', 'STL'], dtype=object)), ('L', 'CLT', array(['ABE', 'AVL', 'CID', 'CVG', 'DSM', 'FWA', 'GSP', 'IAG', 'ISP',
#        'LEX', 'PIA', 'RFD', 'SBN', 'SGF', 'SPI', 'TOL', 'TYS', 'YNG'],
#       dtype=object)), ('L', 'CLT', array(['ABE', 'AVL', 'BGR', 'CHA', 'CID', 'DSM', 'ELM', 'FAR', 'FSD',
#        'FWA', 'GRR', 'GSO', 'GSP', 'HTS', 'IAG', 'LCK', 'LEX', 'MDT',
#        'MLI', 'PBG', 'PIA', 'RFD', 'ROA', 'SBN', 'SGF', 'SWF', 'SYR',
#        'TOL', 'TRI', 'TYS', 'YNG'], dtype=object)), ('L', 'CLT', array(['KEF', 'ABE', 'ATW', 'AVL', 'AVP', 'BGR', 'BIS', 'BLV', 'BMI',
#        'BTV', 'CHA', 'CID', 'CKB', 'CVG', 'DSM', 'ELM', 'FAR', 'FSD',
#        'FWA', 'GFK', 'GRR', 'GSO', 'GSP', 'HGR', 'HTS', 'IAG', 'LAN',
#        'LCK', 'LEX', 'LIT', 'MDT', 'MLI', 'OKC', 'OWB', 'PBG', 'PHF',
#        'PSM', 'RFD', 'ROA', 'SBN', 'SGF', 'SPI', 'TOL', 'TRI', 'TUL',
#        'TYS', 'XNA', 'YNG', 'MIA'], dtype=object)), ('L', 'CLT', array(['CLT', 'DFW', 'DOH', 'LAX', 'LHR', 'MIA', 'ORD', 'PHL', 'PHX',
#        'MSY', 'YEG', 'YUL', 'YYC', 'YYZ', 'ATL', 'CDG', 'MEX', 'SEA',
#        'BOG', 'SAL', 'DXB', 'CUN', 'PEK', 'PTY', 'SFO', 'AMS', 'CVG',
#        'DTW', 'LGA', 'MEM', 'MSP', 'SLC', 'DEN', 'ICN', 'FRA', 'VCT',
#        'NRT', 'LAS', 'MCO', 'DME', 'IST', 'ABQ', 'ACA', 'ACY', 'AEX',
#        'AGU', 'AMA', 'AUS', 'BFL', 'BHM', 'BJX', 'BNA', 'BON', 'BOS',
#        'BRO', 'BTR', 'BWI', 'BZE', 'CAE', 'CCS', 'CHS', 'CLE', 'CLL',
#        'CME', 'CMH', 'COS', 'CRP', 'CRW', 'CUU', 'CZM', 'DAL', 'DCA',
#        'DGO', 'DSM', 'ELP', 'EWR', 'EZE', 'FLL', 'GCM', 'GDL', 'GIG',
#        'GJT', 'GPT', 'GRK', 'GRR', 'GRU', 'GSP', 'GUA', 'HNL', 'HOB',
#        'HRL', 'HSV', 'HUX', 'IAD', 'ICT', 'IND', 'JAN', 'JAX', 'LBB',
#        'LCH', 'LEX', 'LFT', 'LIM', 'LIR', 'LIT', 'LOS', 'LRD', 'MAF',
#        'MBJ', 'MCI', 'MFE', 'MGA', 'MID', 'MKE', 'MLM', 'MLU', 'MOB',
#        'MTY', 'MUC', 'NAS', 'OAX', 'OKC', 'OMA', 'ONT', 'ORF', 'PBC',
#        'PBI', 'PDX', 'PIT', 'PNS', 'POS', 'PSP', 'PVR', 'QRO', 'RDU',
#        'RIC', 'RSW', 'RTB', 'SAN', 'SAP', 'SAT', 'SAV', 'SDF', 'SHV',
#        'SJC', 'SJD', 'SJO', 'SJU', 'SLP', 'SLW', 'SMF', 'SNA', 'STL',
#        'TAM', 'TGU', 'TPA', 'TRC', 'TUL', 'TUS', 'TYR', 'TYS', 'UIO',
#        'VER', 'VPS', 'VSA', 'XNA', 'YVR', 'ZIH', 'ZLO'], dtype=object)), ('L', 'DFW', array(['LWB', 'MCN', 'MEI', 'MSL', 'PIB', 'TUP', 'AZO', 'CHA', 'CID',
#        'CRW', 'CVG', 'EVV', 'FWA', 'GSO', 'GSP', 'LAN', 'LEX', 'MBS',
#        'MSP', 'ROA', 'SYR', 'TYS', 'XNA', 'CLT', 'DFW', 'LHR', 'MIA',
#        'ORD', 'PHL', 'PHX', 'DEN', 'YYZ', 'ABE', 'ABQ', 'ABY', 'AEX',
#        'AGS', 'ALB', 'ATW', 'AUS', 'AVL', 'AVP', 'BDL', 'BHM', 'BMI',
#        'BNA', 'BOS', 'BQK', 'BRU', 'BTR', 'BTV', 'BUF', 'BWI', 'CAE',
#        'CAK', 'CDG', 'CHO', 'CHS', 'CLE', 'CMH', 'COS', 'CSG', 'CUN',
#        'CZM', 'DAB', 'DAL', 'DAY', 'DCA', 'DHN', 'DSM', 'DTW', 'DUB',
#        'DUS', 'ECP', 'ELP', 'EWN', 'EWR', 'EYW', 'FAY', 'FCO', 'FLL',
#        'FNT', 'FRA', 'FSM', 'GDL', 'GNV', 'GPT', 'GRB', 'GRK', 'GRR',
#        'GTR', 'HPN', 'HSV', 'IAD', 'IAH', 'ICT', 'ILM', 'IND', 'JAN',
#        'JAX', 'JFK', 'LAS', 'LAX', 'LFT', 'LGA', 'LIT', 'MAD', 'MAN',
#        'MCI', 'MCO', 'MDT', 'MDW', 'MEM', 'MEX', 'MGM', 'MHT', 'MKE',
#        'MLB', 'MLI', 'MLU', 'MOB', 'MSN', 'MSY', 'MTY', 'MUC', 'MYR',
#        'NAS', 'OAJ', 'OKC', 'OMA', 'ORF', 'PBI', 'PDX', 'PHF', 'PIA',
#        'PIT', 'PNS', 'PTY', 'PVD', 'PWM', 'RDU', 'RIC', 'ROC', 'RSW',
#        'SAN', 'SAT', 'SAV', 'SBN', 'SDF', 'SEA', 'SFO', 'SGF', 'SHV',
#        'SJO', 'SJU', 'SLC', 'SMF', 'SNA', 'SRQ', 'STL', 'STR', 'TLH',
#        'TPA', 'TRI', 'TUL', 'TUS', 'VLD', 'VPS', 'YUL', 'PVR', 'SJD',
#        'HOU', 'AMS', 'AUA', 'BDA', 'BJX', 'BOG', 'BON', 'BSB', 'BZE',
#        'CCS', 'DXB', 'EZE', 'FAR', 'FPO', 'FSD', 'GCM', 'GGT', 'GIG',
#        'GRU', 'GUA', 'HNL', 'ICN', 'JNB', 'KIN', 'LIM', 'LIR', 'LOS',
#        'MBJ', 'MGA', 'NRT', 'PAP', 'PLS', 'PUJ', 'RTB', 'SAL', 'SAP',
#        'SCL', 'SDQ', 'SJC', 'STT', 'SXM', 'TGU', 'UIO', 'UVF', 'ZRH',
#        'TTN'], dtype=object)), ('L', 'DFW', array(['CUR', 'ABE', 'AGS', 'ALB', 'ANU', 'ATL', 'AUA', 'AUS', 'AVL',
#        'AVP', 'BDL', 'BHM', 'BNA', 'BOS', 'BTR', 'BUF', 'BWI', 'BZE',
#        'CAE', 'CAK', 'CDG', 'CHA', 'CHO', 'CHS', 'CLE', 'CMH', 'CRW',
#        'CUN', 'CVG', 'CZM', 'DAB', 'DAY', 'DCA', 'DEN', 'DFW', 'DSM',
#        'DTW', 'DUB', 'EWN', 'EWR', 'FAY', 'FCO', 'FLL', 'FLO', 'FPO',
#        'FRA', 'GCM', 'GNV', 'GPT', 'GRU', 'GSO', 'GSP', 'HHH', 'HPN',
#        'HSV', 'HTS', 'IAD', 'IAH', 'ILM', 'IND', 'JAN', 'JAX', 'JFK',
#        'LAS', 'LAX', 'LEX', 'LGA', 'LHR', 'LIR', 'LIT', 'LYH', 'MBJ',
#        'MCI', 'MCO', 'MDT', 'MEM', 'MEX', 'MGM', 'MHT', 'MIA', 'MKE',
#        'MLB', 'MOB', 'MSP', 'MSY', 'MYR', 'NAS', 'OAJ', 'OMA', 'ORD',
#        'ORF', 'PBI', 'PDX', 'PGV', 'PHF', 'PHL', 'PHX', 'PIT', 'PLS',
#        'PNS', 'PUJ', 'PVD', 'PWM', 'RDU', 'RIC', 'ROA', 'ROC', 'RSW',
#        'SAN', 'SAT', 'SAV', 'SBY', 'SDF', 'SEA', 'SFO', 'SJD', 'SJO',
#        'SJU', 'SLC', 'SMF', 'SRQ', 'STL', 'STT', 'SXM', 'SYR', 'TLH',
#        'TPA', 'TRI', 'TYS', 'UVF', 'VPS', 'XNA', 'YOW', 'YUL', 'YYZ',
#        'TTN', 'MDW', 'MUC', 'LUK', 'GIG', 'HOU'], dtype=object)), ('L', 'DFW', array(['EZE', 'ABI', 'ABQ', 'ACT', 'AEX', 'AGU', 'AMA', 'ATL', 'AUS',
#        'BDL', 'BHM', 'BJX', 'BMI', 'BNA', 'BNE', 'BOG', 'BOS', 'BPT',
#        'BRO', 'BTR', 'BWI', 'BZE', 'CAE', 'CCS', 'CDG', 'CHA', 'CHS',
#        'CID', 'CLE', 'CLL', 'CLT', 'CMH', 'CMI', 'COS', 'COU', 'CRP',
#        'CRW', 'CUN', 'CUU', 'CVG', 'CZM', 'DAY', 'DCA', 'DEN', 'DRO',
#        'DSM', 'DTW', 'ELP', 'EVV', 'EWR', 'FAR', 'FAT', 'FLL', 'FRA',
#        'FSD', 'FSM', 'FWA', 'GCK', 'GDL', 'GGG', 'GIG', 'GJT', 'GPT',
#        'GRI', 'GRK', 'GRR', 'GRU', 'GSO', 'GSP', 'GUA', 'HNL', 'HOU',
#        'HSV', 'IAD', 'IAH', 'ICN', 'ICT', 'IND', 'JAN', 'JAX', 'JFK',
#        'JLN', 'LAS', 'LAW', 'LAX', 'LBB', 'LCH', 'LEX', 'LFT', 'LGA',
#        'LHR', 'LIM', 'LIR', 'LIT', 'LRD', 'MAD', 'MAF', 'MBJ', 'MCI',
#        'MCO', 'MEM', 'MEX', 'MFE', 'MGM', 'MHK', 'MIA', 'MKE', 'MLI',
#        'MLM', 'MLU', 'MOB', 'MSN', 'MSP', 'MSY', 'MTY', 'MZT', 'NAS',
#        'NRT', 'OGG', 'OKC', 'OMA', 'ONT', 'ORD', 'ORF', 'PBC', 'PBI',
#        'PDX', 'PHL', 'PHX', 'PIA', 'PIT', 'PLS', 'PNS', 'PSP', 'PTY',
#        'PVR', 'QRO', 'RAP', 'RDU', 'RIC', 'RNO', 'ROW', 'RSW', 'RTB',
#        'SAF', 'SAL', 'SAN', 'SAT', 'SAV', 'SCL', 'SDF', 'SEA', 'SFO',
#        'SGF', 'SHV', 'SJC', 'SJD', 'SJO', 'SJT', 'SJU', 'SLC', 'SLP',
#        'SMF', 'SNA', 'SPI', 'SPS', 'STL', 'TLH', 'TPA', 'TRC', 'TUL',
#        'TUS', 'TXK', 'TYR', 'TYS', 'VPS', 'XNA', 'YEG', 'YUL', 'YVR',
#        'YYC', 'YYZ', 'ZCL', 'DXB', 'AMS', 'MYR', 'OAK'], dtype=object)), ('L', 'DFW', array(['BRL', 'DEC', 'ABQ', 'ALO', 'AMM', 'ART', 'ATL', 'AUH', 'AUS',
#        'AZO', 'BDL', 'BMI', 'BNA', 'BOS', 'BUF', 'BWI', 'CDG', 'CHA',
#        'CHO', 'CID', 'CLE', 'CLT', 'CMH', 'CMI', 'COU', 'CUN', 'CVG',
#        'CWA', 'DAY', 'DBQ', 'DCA', 'DEN', 'DFW', 'DOH', 'DSM', 'DTW',
#        'DUB', 'DUS', 'ELP', 'EVV', 'EWR', 'FAR', 'FCO', 'FLL', 'FNT',
#        'FSD', 'FWA', 'GRB', 'GRR', 'HKG', 'HPN', 'HSV', 'IAH', 'ICT',
#        'IND', 'JAX', 'JFK', 'LAS', 'LAX', 'LEX', 'LGA', 'LHR', 'LIT',
#        'LSE', 'MAD', 'MAN', 'MBJ', 'MCI', 'MCO', 'MDT', 'MEM', 'MEX',
#        'MHK', 'MIA', 'MKE', 'MLI', 'MQT', 'MSN', 'MSP', 'MSY', 'NRT',
#        'OKC', 'OMA', 'PBI', 'PDX', 'PEK', 'PHL', 'PHX', 'PIA', 'PIT',
#        'PSP', 'PVG', 'PVR', 'RDU', 'RIC', 'RNO', 'ROC', 'RST', 'RSW',
#        'SAN', 'SAT', 'SDF', 'SEA', 'SFO', 'SGF', 'SJC', 'SJD', 'SJU',
#        'SLC', 'SNA', 'STL', 'SUX', 'SYR', 'TOL', 'TPA', 'TUL', 'TUS',
#        'TVC', 'TXL', 'TYS', 'XNA', 'YKF', 'YUL', 'YVR', 'YYC', 'YYZ',
#        'YEG', 'YHZ', 'YOW', 'YQB', 'YQR', 'YWG', 'YXU', 'DEL', 'GDL',
#        'ANC', 'SAL', 'PTY', 'AMS', 'ICN', 'PUJ', 'GCM', 'FRA', 'MUC',
#        'WAW', 'ZRH', 'ACY', 'MYR', 'OAK', 'VIE', 'ARN', 'CPH', 'BRU',
#        'IST', 'ABE', 'ALB', 'ATW', 'AVL', 'AVP', 'BHM', 'BOI', 'BTV',
#        'BZN', 'CAE', 'CAK', 'CHS', 'CMX', 'COS', 'CRW', 'DLH', 'EAU',
#        'ELM', 'FOE', 'GRU', 'GSO', 'GSP', 'HNL', 'IAD', 'JAN', 'LAN',
#        'LNK', 'MBS', 'MHT', 'MKG', 'MOB', 'MTY', 'NAS', 'OGG', 'ORF',
#        'PAH', 'PNS', 'PVD', 'PWM', 'RAP', 'ROA', 'SAV', 'SBN', 'SCE',
#        'SJO', 'SMF', 'SPI', 'SRQ', 'STC', 'STT', 'SXM', 'YXE'],
#       dtype=object)), ('L', 'DFW', array(['AGS', 'ALB', 'BDL', 'BGR', 'BHM', 'BNA', 'BOS', 'BTV', 'BUF',
#        'CAE', 'CAK', 'CHA', 'CHS', 'CLT', 'CMH', 'CRW', 'CVG', 'DAY',
#        'DFW', 'DSM', 'DTW', 'FAY', 'FLL', 'GSO', 'GSP', 'HHH', 'HPN',
#        'HSV', 'ILM', 'IND', 'ISP', 'JAN', 'JAX', 'JFK', 'LAS', 'LAX',
#        'LGA', 'LIT', 'MCI', 'MCO', 'MEM', 'MHT', 'MIA', 'MSP', 'MSY',
#        'MYR', 'NAS', 'OAJ', 'OMA', 'ORD', 'ORF', 'PBI', 'PDX', 'PHL',
#        'PHX', 'PIT', 'PNS', 'PVD', 'PWM', 'RDU', 'ROC', 'RSW', 'SAN',
#        'SAV', 'SDF', 'SRQ', 'STL', 'SYR', 'TLH', 'TPA', 'TYS', 'VPS',
#        'YHZ', 'YUL', 'YYZ', 'YOW', 'ATL', 'SEA', 'SJU', 'LEX', 'MSN',
#        'SLC', 'DEN', 'MKE', 'LAN', 'CLE', 'EWR', 'IAH', 'SFO', 'AUS',
#        'HOU'], dtype=object)), ('L', 'DFW', array(['MSY', 'CLT', 'DCA', 'DFW', 'LGA', 'MIA', 'ORD', 'PHL', 'PHX',
#        'YUL', 'YYZ', 'ATL', 'CDG', 'FRA', 'LHR', 'CUN', 'MEX', 'MTY',
#        'PDX', 'SAN', 'BOS', 'PEK', 'PVG', 'ABE', 'ALB', 'AMS', 'APN',
#        'ATW', 'AUS', 'AVL', 'AVP', 'AZO', 'BDL', 'BGM', 'BGR', 'BHM',
#        'BMI', 'BNA', 'BTV', 'BUF', 'BWI', 'CAE', 'CAK', 'CHA', 'CHS',
#        'CID', 'CIU', 'CLE', 'CMH', 'CRW', 'CVG', 'CWA', 'DAY', 'DEN',
#        'DSM', 'ELM', 'ERI', 'ESC', 'EVV', 'EWR', 'FLL', 'FWA', 'GCM',
#        'GRB', 'GRR', 'GRU', 'GSO', 'GSP', 'HPN', 'HSV', 'IAD', 'IAH',
#        'ICN', 'IND', 'ITH', 'JAX', 'JFK', 'LAN', 'LAS', 'LAX', 'LEX',
#        'LIT', 'MBJ', 'MBS', 'MCI', 'MCO', 'MDT', 'MDW', 'MEM', 'MHT',
#        'MKE', 'MLI', 'MQT', 'MSN', 'MSP', 'MYR', 'NAS', 'NGO', 'NRT',
#        'OKC', 'OMA', 'ORF', 'PBI', 'PIA', 'PIT', 'PLN', 'PUJ', 'PVD',
#        'PWM', 'RDU', 'RIC', 'ROA', 'ROC', 'RSW', 'SAT', 'SAV', 'SBN',
#        'SCE', 'SDF', 'SEA', 'SFO', 'SJU', 'SLC', 'STL', 'SWF', 'SYR',
#        'TPA', 'TUL', 'TVC', 'TYS', 'XNA', 'YOW', 'ILG', 'TTN', 'ACY'],
#       dtype=object)), ('L', 'DFW', array(['MSY', 'BNA', 'BOS', 'CHO', 'CLT', 'CMH', 'DAY', 'DCA', 'DFW',
#        'DTW', 'GSO', 'ILM', 'LIT', 'MIA', 'ORD', 'ORF', 'PBI', 'PHL',
#        'PIT', 'RDU', 'RIC', 'ROA', 'SDF', 'STL', 'TYS', 'XNA', 'YUL',
#        'YYZ', 'YOW', 'ATL', 'FLL', 'MCO', 'RSW', 'SRQ', 'TPA', 'AUA',
#        'BGR', 'BHM', 'BTV', 'BUF', 'CAE', 'CHS', 'CLE', 'CVG', 'DEN',
#        'DSM', 'EYW', 'GRR', 'GSP', 'IAH', 'IND', 'JAX', 'LEX', 'MCI',
#        'MEM', 'MHT', 'MKE', 'MSN', 'MSP', 'MYR', 'OMA', 'PWM', 'ROC',
#        'SAV', 'SYR', 'YHZ', 'CAK', 'MDW', 'IAD', 'HOU'], dtype=object)), ('L', 'DFW', array(['ATL', 'MSY', 'CLT', 'DCA', 'DFW', 'MIA', 'ORD', 'PHL', 'PHX',
#        'YYZ', 'CDG', 'LAX', 'LHR', 'SEA', 'SFO', 'CUN', 'SAN', 'ABQ',
#        'ABR', 'ALB', 'AMS', 'ANC', 'APN', 'ATW', 'AUS', 'AZO', 'BDL',
#        'BHM', 'BIL', 'BIS', 'BJI', 'BMI', 'BNA', 'BOI', 'BOS', 'BRD',
#        'BUF', 'BWI', 'BZN', 'CID', 'CLE', 'CMH', 'CVG', 'CWA', 'DAY',
#        'DEN', 'DIK', 'DLH', 'DSM', 'DTW', 'EWR', 'FAR', 'FCA', 'FLL',
#        'FNT', 'FSD', 'FWA', 'GEG', 'GFK', 'GRB', 'GRR', 'GTF', 'HIB',
#        'HLN', 'IAD', 'IAH', 'ICT', 'IMT', 'IND', 'INL', 'ISN', 'JAX',
#        'JFK', 'LAN', 'LAS', 'LEX', 'LGA', 'LNK', 'LSE', 'MBS', 'MCI',
#        'MCO', 'MDW', 'MEM', 'MKE', 'MLI', 'MOT', 'MSN', 'MSO', 'NRT',
#        'OKC', 'OMA', 'ORF', 'PDX', 'PIA', 'PIT', 'PSC', 'PSP', 'RAP',
#        'RDU', 'RHI', 'RIC', 'ROC', 'RST', 'RSW', 'SAT', 'SBN', 'SDF',
#        'SJC', 'SLC', 'SMF', 'SNA', 'STL', 'SYR', 'TPA', 'TUL', 'TUS',
#        'TVC', 'TYS', 'XNA', 'YEG', 'YQR', 'YUL', 'YVR', 'YWG', 'YXE',
#        'YYC', 'OAK', 'PUJ', 'ATY'], dtype=object)), ('L', 'DFW', array(['BIM', 'ELH', 'EYW', 'FPO', 'GGT', 'GHB', 'MCO', 'MHH', 'TCB',
#        'TPA', 'CLT', 'DCA', 'DFW', 'ORD', 'PAP', 'PHL', 'PHX', 'YUL',
#        'YYZ', 'ATL', 'SEA', 'BOG', 'AUS', 'BDL', 'BOS', 'CUN', 'EWR',
#        'HPN', 'JFK', 'KIN', 'LAX', 'LGA', 'LIM', 'MBJ', 'MDE', 'NAS',
#        'ORH', 'POS', 'PUJ', 'PVD', 'RDU', 'RIC', 'SDQ', 'SFO', 'SJO',
#        'SJU', 'SWF', 'CVG', 'DTW', 'MSP', 'ARN', 'CPH', 'OSL', 'DEN',
#        'TTN', 'BWI', 'HOU', 'MKE', 'MSY', 'AVL', 'GSP', 'LEX', 'PBG',
#        'TYS', 'ACY', 'AUA', 'AXM', 'BQN', 'CTG', 'GUA', 'IAG', 'LAS',
#        'LBE', 'MGA', 'MYR', 'PTY', 'SAL', 'SAP', 'STI', 'STT', 'SXM',
#        'TLC', 'ZSA', 'CLE', 'IAD', 'IAH', 'ALB', 'BNA', 'BUF', 'CMH',
#        'IND', 'ISP', 'JAX', 'MCI', 'MDW', 'PIT', 'STL'], dtype=object)), ('L', 'DFW', array(['ABE', 'AVL', 'CID', 'CVG', 'DSM', 'FWA', 'GSP', 'IAG', 'ISP',
#        'LEX', 'PIA', 'RFD', 'SBN', 'SGF', 'SPI', 'TOL', 'TYS', 'YNG'],
#       dtype=object)), ('L', 'DFW', array(['ABE', 'AVL', 'BGR', 'CHA', 'CID', 'DSM', 'ELM', 'FAR', 'FSD',
#        'FWA', 'GRR', 'GSO', 'GSP', 'HTS', 'IAG', 'LCK', 'LEX', 'MDT',
#        'MLI', 'PBG', 'PIA', 'RFD', 'ROA', 'SBN', 'SGF', 'SWF', 'SYR',
#        'TOL', 'TRI', 'TYS', 'YNG'], dtype=object)), ('L', 'DFW', array(['KEF', 'ABE', 'ATW', 'AVL', 'AVP', 'BGR', 'BIS', 'BLV', 'BMI',
#        'BTV', 'CHA', 'CID', 'CKB', 'CVG', 'DSM', 'ELM', 'FAR', 'FSD',
#        'FWA', 'GFK', 'GRR', 'GSO', 'GSP', 'HGR', 'HTS', 'IAG', 'LAN',
#        'LCK', 'LEX', 'LIT', 'MDT', 'MLI', 'OKC', 'OWB', 'PBG', 'PHF',
#        'PSM', 'RFD', 'ROA', 'SBN', 'SGF', 'SPI', 'TOL', 'TRI', 'TUL',
#        'TYS', 'XNA', 'YNG', 'MIA'], dtype=object)), ('L', 'DFW', array(['CLT', 'DFW', 'DOH', 'LAX', 'LHR', 'MIA', 'ORD', 'PHL', 'PHX',
#        'MSY', 'YEG', 'YUL', 'YYC', 'YYZ', 'ATL', 'CDG', 'MEX', 'SEA',
#        'BOG', 'SAL', 'DXB', 'CUN', 'PEK', 'PTY', 'SFO', 'AMS', 'CVG',
#        'DTW', 'LGA', 'MEM', 'MSP', 'SLC', 'DEN', 'ICN', 'FRA', 'VCT',
#        'NRT', 'LAS', 'MCO', 'DME', 'IST', 'ABQ', 'ACA', 'ACY', 'AEX',
#        'AGU', 'AMA', 'AUS', 'BFL', 'BHM', 'BJX', 'BNA', 'BON', 'BOS',
#        'BRO', 'BTR', 'BWI', 'BZE', 'CAE', 'CCS', 'CHS', 'CLE', 'CLL',
#        'CME', 'CMH', 'COS', 'CRP', 'CRW', 'CUU', 'CZM', 'DAL', 'DCA',
#        'DGO', 'DSM', 'ELP', 'EWR', 'EZE', 'FLL', 'GCM', 'GDL', 'GIG',
#        'GJT', 'GPT', 'GRK', 'GRR', 'GRU', 'GSP', 'GUA', 'HNL', 'HOB',
#        'HRL', 'HSV', 'HUX', 'IAD', 'ICT', 'IND', 'JAN', 'JAX', 'LBB',
#        'LCH', 'LEX', 'LFT', 'LIM', 'LIR', 'LIT', 'LOS', 'LRD', 'MAF',
#        'MBJ', 'MCI', 'MFE', 'MGA', 'MID', 'MKE', 'MLM', 'MLU', 'MOB',
#        'MTY', 'MUC', 'NAS', 'OAX', 'OKC', 'OMA', 'ONT', 'ORF', 'PBC',
#        'PBI', 'PDX', 'PIT', 'PNS', 'POS', 'PSP', 'PVR', 'QRO', 'RDU',
#        'RIC', 'RSW', 'RTB', 'SAN', 'SAP', 'SAT', 'SAV', 'SDF', 'SHV',
#        'SJC', 'SJD', 'SJO', 'SJU', 'SLP', 'SLW', 'SMF', 'SNA', 'STL',
#        'TAM', 'TGU', 'TPA', 'TRC', 'TUL', 'TUS', 'TYR', 'TYS', 'UIO',
#        'VER', 'VPS', 'VSA', 'XNA', 'YVR', 'ZIH', 'ZLO'], dtype=object)), ('L', 'ORD', array(['LWB', 'MCN', 'MEI', 'MSL', 'PIB', 'TUP', 'AZO', 'CHA', 'CID',
#        'CRW', 'CVG', 'EVV', 'FWA', 'GSO', 'GSP', 'LAN', 'LEX', 'MBS',
#        'MSP', 'ROA', 'SYR', 'TYS', 'XNA', 'CLT', 'DFW', 'LHR', 'MIA',
#        'ORD', 'PHL', 'PHX', 'DEN', 'YYZ', 'ABE', 'ABQ', 'ABY', 'AEX',
#        'AGS', 'ALB', 'ATW', 'AUS', 'AVL', 'AVP', 'BDL', 'BHM', 'BMI',
#        'BNA', 'BOS', 'BQK', 'BRU', 'BTR', 'BTV', 'BUF', 'BWI', 'CAE',
#        'CAK', 'CDG', 'CHO', 'CHS', 'CLE', 'CMH', 'COS', 'CSG', 'CUN',
#        'CZM', 'DAB', 'DAL', 'DAY', 'DCA', 'DHN', 'DSM', 'DTW', 'DUB',
#        'DUS', 'ECP', 'ELP', 'EWN', 'EWR', 'EYW', 'FAY', 'FCO', 'FLL',
#        'FNT', 'FRA', 'FSM', 'GDL', 'GNV', 'GPT', 'GRB', 'GRK', 'GRR',
#        'GTR', 'HPN', 'HSV', 'IAD', 'IAH', 'ICT', 'ILM', 'IND', 'JAN',
#        'JAX', 'JFK', 'LAS', 'LAX', 'LFT', 'LGA', 'LIT', 'MAD', 'MAN',
#        'MCI', 'MCO', 'MDT', 'MDW', 'MEM', 'MEX', 'MGM', 'MHT', 'MKE',
#        'MLB', 'MLI', 'MLU', 'MOB', 'MSN', 'MSY', 'MTY', 'MUC', 'MYR',
#        'NAS', 'OAJ', 'OKC', 'OMA', 'ORF', 'PBI', 'PDX', 'PHF', 'PIA',
#        'PIT', 'PNS', 'PTY', 'PVD', 'PWM', 'RDU', 'RIC', 'ROC', 'RSW',
#        'SAN', 'SAT', 'SAV', 'SBN', 'SDF', 'SEA', 'SFO', 'SGF', 'SHV',
#        'SJO', 'SJU', 'SLC', 'SMF', 'SNA', 'SRQ', 'STL', 'STR', 'TLH',
#        'TPA', 'TRI', 'TUL', 'TUS', 'VLD', 'VPS', 'YUL', 'PVR', 'SJD',
#        'HOU', 'AMS', 'AUA', 'BDA', 'BJX', 'BOG', 'BON', 'BSB', 'BZE',
#        'CCS', 'DXB', 'EZE', 'FAR', 'FPO', 'FSD', 'GCM', 'GGT', 'GIG',
#        'GRU', 'GUA', 'HNL', 'ICN', 'JNB', 'KIN', 'LIM', 'LIR', 'LOS',
#        'MBJ', 'MGA', 'NRT', 'PAP', 'PLS', 'PUJ', 'RTB', 'SAL', 'SAP',
#        'SCL', 'SDQ', 'SJC', 'STT', 'SXM', 'TGU', 'UIO', 'UVF', 'ZRH',
#        'TTN'], dtype=object)), ('L', 'ORD', array(['CUR', 'ABE', 'AGS', 'ALB', 'ANU', 'ATL', 'AUA', 'AUS', 'AVL',
#        'AVP', 'BDL', 'BHM', 'BNA', 'BOS', 'BTR', 'BUF', 'BWI', 'BZE',
#        'CAE', 'CAK', 'CDG', 'CHA', 'CHO', 'CHS', 'CLE', 'CMH', 'CRW',
#        'CUN', 'CVG', 'CZM', 'DAB', 'DAY', 'DCA', 'DEN', 'DFW', 'DSM',
#        'DTW', 'DUB', 'EWN', 'EWR', 'FAY', 'FCO', 'FLL', 'FLO', 'FPO',
#        'FRA', 'GCM', 'GNV', 'GPT', 'GRU', 'GSO', 'GSP', 'HHH', 'HPN',
#        'HSV', 'HTS', 'IAD', 'IAH', 'ILM', 'IND', 'JAN', 'JAX', 'JFK',
#        'LAS', 'LAX', 'LEX', 'LGA', 'LHR', 'LIR', 'LIT', 'LYH', 'MBJ',
#        'MCI', 'MCO', 'MDT', 'MEM', 'MEX', 'MGM', 'MHT', 'MIA', 'MKE',
#        'MLB', 'MOB', 'MSP', 'MSY', 'MYR', 'NAS', 'OAJ', 'OMA', 'ORD',
#        'ORF', 'PBI', 'PDX', 'PGV', 'PHF', 'PHL', 'PHX', 'PIT', 'PLS',
#        'PNS', 'PUJ', 'PVD', 'PWM', 'RDU', 'RIC', 'ROA', 'ROC', 'RSW',
#        'SAN', 'SAT', 'SAV', 'SBY', 'SDF', 'SEA', 'SFO', 'SJD', 'SJO',
#        'SJU', 'SLC', 'SMF', 'SRQ', 'STL', 'STT', 'SXM', 'SYR', 'TLH',
#        'TPA', 'TRI', 'TYS', 'UVF', 'VPS', 'XNA', 'YOW', 'YUL', 'YYZ',
#        'TTN', 'MDW', 'MUC', 'LUK', 'GIG', 'HOU'], dtype=object)), ('L', 'ORD', array(['EZE', 'ABI', 'ABQ', 'ACT', 'AEX', 'AGU', 'AMA', 'ATL', 'AUS',
#        'BDL', 'BHM', 'BJX', 'BMI', 'BNA', 'BNE', 'BOG', 'BOS', 'BPT',
#        'BRO', 'BTR', 'BWI', 'BZE', 'CAE', 'CCS', 'CDG', 'CHA', 'CHS',
#        'CID', 'CLE', 'CLL', 'CLT', 'CMH', 'CMI', 'COS', 'COU', 'CRP',
#        'CRW', 'CUN', 'CUU', 'CVG', 'CZM', 'DAY', 'DCA', 'DEN', 'DRO',
#        'DSM', 'DTW', 'ELP', 'EVV', 'EWR', 'FAR', 'FAT', 'FLL', 'FRA',
#        'FSD', 'FSM', 'FWA', 'GCK', 'GDL', 'GGG', 'GIG', 'GJT', 'GPT',
#        'GRI', 'GRK', 'GRR', 'GRU', 'GSO', 'GSP', 'GUA', 'HNL', 'HOU',
#        'HSV', 'IAD', 'IAH', 'ICN', 'ICT', 'IND', 'JAN', 'JAX', 'JFK',
#        'JLN', 'LAS', 'LAW', 'LAX', 'LBB', 'LCH', 'LEX', 'LFT', 'LGA',
#        'LHR', 'LIM', 'LIR', 'LIT', 'LRD', 'MAD', 'MAF', 'MBJ', 'MCI',
#        'MCO', 'MEM', 'MEX', 'MFE', 'MGM', 'MHK', 'MIA', 'MKE', 'MLI',
#        'MLM', 'MLU', 'MOB', 'MSN', 'MSP', 'MSY', 'MTY', 'MZT', 'NAS',
#        'NRT', 'OGG', 'OKC', 'OMA', 'ONT', 'ORD', 'ORF', 'PBC', 'PBI',
#        'PDX', 'PHL', 'PHX', 'PIA', 'PIT', 'PLS', 'PNS', 'PSP', 'PTY',
#        'PVR', 'QRO', 'RAP', 'RDU', 'RIC', 'RNO', 'ROW', 'RSW', 'RTB',
#        'SAF', 'SAL', 'SAN', 'SAT', 'SAV', 'SCL', 'SDF', 'SEA', 'SFO',
#        'SGF', 'SHV', 'SJC', 'SJD', 'SJO', 'SJT', 'SJU', 'SLC', 'SLP',
#        'SMF', 'SNA', 'SPI', 'SPS', 'STL', 'TLH', 'TPA', 'TRC', 'TUL',
#        'TUS', 'TXK', 'TYR', 'TYS', 'VPS', 'XNA', 'YEG', 'YUL', 'YVR',
#        'YYC', 'YYZ', 'ZCL', 'DXB', 'AMS', 'MYR', 'OAK'], dtype=object)), ('L', 'ORD', array(['BRL', 'DEC', 'ABQ', 'ALO', 'AMM', 'ART', 'ATL', 'AUH', 'AUS',
#        'AZO', 'BDL', 'BMI', 'BNA', 'BOS', 'BUF', 'BWI', 'CDG', 'CHA',
#        'CHO', 'CID', 'CLE', 'CLT', 'CMH', 'CMI', 'COU', 'CUN', 'CVG',
#        'CWA', 'DAY', 'DBQ', 'DCA', 'DEN', 'DFW', 'DOH', 'DSM', 'DTW',
#        'DUB', 'DUS', 'ELP', 'EVV', 'EWR', 'FAR', 'FCO', 'FLL', 'FNT',
#        'FSD', 'FWA', 'GRB', 'GRR', 'HKG', 'HPN', 'HSV', 'IAH', 'ICT',
#        'IND', 'JAX', 'JFK', 'LAS', 'LAX', 'LEX', 'LGA', 'LHR', 'LIT',
#        'LSE', 'MAD', 'MAN', 'MBJ', 'MCI', 'MCO', 'MDT', 'MEM', 'MEX',
#        'MHK', 'MIA', 'MKE', 'MLI', 'MQT', 'MSN', 'MSP', 'MSY', 'NRT',
#        'OKC', 'OMA', 'PBI', 'PDX', 'PEK', 'PHL', 'PHX', 'PIA', 'PIT',
#        'PSP', 'PVG', 'PVR', 'RDU', 'RIC', 'RNO', 'ROC', 'RST', 'RSW',
#        'SAN', 'SAT', 'SDF', 'SEA', 'SFO', 'SGF', 'SJC', 'SJD', 'SJU',
#        'SLC', 'SNA', 'STL', 'SUX', 'SYR', 'TOL', 'TPA', 'TUL', 'TUS',
#        'TVC', 'TXL', 'TYS', 'XNA', 'YKF', 'YUL', 'YVR', 'YYC', 'YYZ',
#        'YEG', 'YHZ', 'YOW', 'YQB', 'YQR', 'YWG', 'YXU', 'DEL', 'GDL',
#        'ANC', 'SAL', 'PTY', 'AMS', 'ICN', 'PUJ', 'GCM', 'FRA', 'MUC',
#        'WAW', 'ZRH', 'ACY', 'MYR', 'OAK', 'VIE', 'ARN', 'CPH', 'BRU',
#        'IST', 'ABE', 'ALB', 'ATW', 'AVL', 'AVP', 'BHM', 'BOI', 'BTV',
#        'BZN', 'CAE', 'CAK', 'CHS', 'CMX', 'COS', 'CRW', 'DLH', 'EAU',
#        'ELM', 'FOE', 'GRU', 'GSO', 'GSP', 'HNL', 'IAD', 'JAN', 'LAN',
#        'LNK', 'MBS', 'MHT', 'MKG', 'MOB', 'MTY', 'NAS', 'OGG', 'ORF',
#        'PAH', 'PNS', 'PVD', 'PWM', 'RAP', 'ROA', 'SAV', 'SBN', 'SCE',
#        'SJO', 'SMF', 'SPI', 'SRQ', 'STC', 'STT', 'SXM', 'YXE'],
#       dtype=object)), ('L', 'ORD', array(['AGS', 'ALB', 'BDL', 'BGR', 'BHM', 'BNA', 'BOS', 'BTV', 'BUF',
#        'CAE', 'CAK', 'CHA', 'CHS', 'CLT', 'CMH', 'CRW', 'CVG', 'DAY',
#        'DFW', 'DSM', 'DTW', 'FAY', 'FLL', 'GSO', 'GSP', 'HHH', 'HPN',
#        'HSV', 'ILM', 'IND', 'ISP', 'JAN', 'JAX', 'JFK', 'LAS', 'LAX',
#        'LGA', 'LIT', 'MCI', 'MCO', 'MEM', 'MHT', 'MIA', 'MSP', 'MSY',
#        'MYR', 'NAS', 'OAJ', 'OMA', 'ORD', 'ORF', 'PBI', 'PDX', 'PHL',
#        'PHX', 'PIT', 'PNS', 'PVD', 'PWM', 'RDU', 'ROC', 'RSW', 'SAN',
#        'SAV', 'SDF', 'SRQ', 'STL', 'SYR', 'TLH', 'TPA', 'TYS', 'VPS',
#        'YHZ', 'YUL', 'YYZ', 'YOW', 'ATL', 'SEA', 'SJU', 'LEX', 'MSN',
#        'SLC', 'DEN', 'MKE', 'LAN', 'CLE', 'EWR', 'IAH', 'SFO', 'AUS',
#        'HOU'], dtype=object)), ('L', 'ORD', array(['MSY', 'CLT', 'DCA', 'DFW', 'LGA', 'MIA', 'ORD', 'PHL', 'PHX',
#        'YUL', 'YYZ', 'ATL', 'CDG', 'FRA', 'LHR', 'CUN', 'MEX', 'MTY',
#        'PDX', 'SAN', 'BOS', 'PEK', 'PVG', 'ABE', 'ALB', 'AMS', 'APN',
#        'ATW', 'AUS', 'AVL', 'AVP', 'AZO', 'BDL', 'BGM', 'BGR', 'BHM',
#        'BMI', 'BNA', 'BTV', 'BUF', 'BWI', 'CAE', 'CAK', 'CHA', 'CHS',
#        'CID', 'CIU', 'CLE', 'CMH', 'CRW', 'CVG', 'CWA', 'DAY', 'DEN',
#        'DSM', 'ELM', 'ERI', 'ESC', 'EVV', 'EWR', 'FLL', 'FWA', 'GCM',
#        'GRB', 'GRR', 'GRU', 'GSO', 'GSP', 'HPN', 'HSV', 'IAD', 'IAH',
#        'ICN', 'IND', 'ITH', 'JAX', 'JFK', 'LAN', 'LAS', 'LAX', 'LEX',
#        'LIT', 'MBJ', 'MBS', 'MCI', 'MCO', 'MDT', 'MDW', 'MEM', 'MHT',
#        'MKE', 'MLI', 'MQT', 'MSN', 'MSP', 'MYR', 'NAS', 'NGO', 'NRT',
#        'OKC', 'OMA', 'ORF', 'PBI', 'PIA', 'PIT', 'PLN', 'PUJ', 'PVD',
#        'PWM', 'RDU', 'RIC', 'ROA', 'ROC', 'RSW', 'SAT', 'SAV', 'SBN',
#        'SCE', 'SDF', 'SEA', 'SFO', 'SJU', 'SLC', 'STL', 'SWF', 'SYR',
#        'TPA', 'TUL', 'TVC', 'TYS', 'XNA', 'YOW', 'ILG', 'TTN', 'ACY'],
#       dtype=object)), ('L', 'ORD', array(['MSY', 'BNA', 'BOS', 'CHO', 'CLT', 'CMH', 'DAY', 'DCA', 'DFW',
#        'DTW', 'GSO', 'ILM', 'LIT', 'MIA', 'ORD', 'ORF', 'PBI', 'PHL',
#        'PIT', 'RDU', 'RIC', 'ROA', 'SDF', 'STL', 'TYS', 'XNA', 'YUL',
#        'YYZ', 'YOW', 'ATL', 'FLL', 'MCO', 'RSW', 'SRQ', 'TPA', 'AUA',
#        'BGR', 'BHM', 'BTV', 'BUF', 'CAE', 'CHS', 'CLE', 'CVG', 'DEN',
#        'DSM', 'EYW', 'GRR', 'GSP', 'IAH', 'IND', 'JAX', 'LEX', 'MCI',
#        'MEM', 'MHT', 'MKE', 'MSN', 'MSP', 'MYR', 'OMA', 'PWM', 'ROC',
#        'SAV', 'SYR', 'YHZ', 'CAK', 'MDW', 'IAD', 'HOU'], dtype=object)), ('L', 'ORD', array(['ATL', 'MSY', 'CLT', 'DCA', 'DFW', 'MIA', 'ORD', 'PHL', 'PHX',
#        'YYZ', 'CDG', 'LAX', 'LHR', 'SEA', 'SFO', 'CUN', 'SAN', 'ABQ',
#        'ABR', 'ALB', 'AMS', 'ANC', 'APN', 'ATW', 'AUS', 'AZO', 'BDL',
#        'BHM', 'BIL', 'BIS', 'BJI', 'BMI', 'BNA', 'BOI', 'BOS', 'BRD',
#        'BUF', 'BWI', 'BZN', 'CID', 'CLE', 'CMH', 'CVG', 'CWA', 'DAY',
#        'DEN', 'DIK', 'DLH', 'DSM', 'DTW', 'EWR', 'FAR', 'FCA', 'FLL',
#        'FNT', 'FSD', 'FWA', 'GEG', 'GFK', 'GRB', 'GRR', 'GTF', 'HIB',
#        'HLN', 'IAD', 'IAH', 'ICT', 'IMT', 'IND', 'INL', 'ISN', 'JAX',
#        'JFK', 'LAN', 'LAS', 'LEX', 'LGA', 'LNK', 'LSE', 'MBS', 'MCI',
#        'MCO', 'MDW', 'MEM', 'MKE', 'MLI', 'MOT', 'MSN', 'MSO', 'NRT',
#        'OKC', 'OMA', 'ORF', 'PDX', 'PIA', 'PIT', 'PSC', 'PSP', 'RAP',
#        'RDU', 'RHI', 'RIC', 'ROC', 'RST', 'RSW', 'SAT', 'SBN', 'SDF',
#        'SJC', 'SLC', 'SMF', 'SNA', 'STL', 'SYR', 'TPA', 'TUL', 'TUS',
#        'TVC', 'TYS', 'XNA', 'YEG', 'YQR', 'YUL', 'YVR', 'YWG', 'YXE',
#        'YYC', 'OAK', 'PUJ', 'ATY'], dtype=object)), ('L', 'ORD', array(['BIM', 'ELH', 'EYW', 'FPO', 'GGT', 'GHB', 'MCO', 'MHH', 'TCB',
#        'TPA', 'CLT', 'DCA', 'DFW', 'ORD', 'PAP', 'PHL', 'PHX', 'YUL',
#        'YYZ', 'ATL', 'SEA', 'BOG', 'AUS', 'BDL', 'BOS', 'CUN', 'EWR',
#        'HPN', 'JFK', 'KIN', 'LAX', 'LGA', 'LIM', 'MBJ', 'MDE', 'NAS',
#        'ORH', 'POS', 'PUJ', 'PVD', 'RDU', 'RIC', 'SDQ', 'SFO', 'SJO',
#        'SJU', 'SWF', 'CVG', 'DTW', 'MSP', 'ARN', 'CPH', 'OSL', 'DEN',
#        'TTN', 'BWI', 'HOU', 'MKE', 'MSY', 'AVL', 'GSP', 'LEX', 'PBG',
#        'TYS', 'ACY', 'AUA', 'AXM', 'BQN', 'CTG', 'GUA', 'IAG', 'LAS',
#        'LBE', 'MGA', 'MYR', 'PTY', 'SAL', 'SAP', 'STI', 'STT', 'SXM',
#        'TLC', 'ZSA', 'CLE', 'IAD', 'IAH', 'ALB', 'BNA', 'BUF', 'CMH',
#        'IND', 'ISP', 'JAX', 'MCI', 'MDW', 'PIT', 'STL'], dtype=object)), ('L', 'ORD', array(['ABE', 'AVL', 'CID', 'CVG', 'DSM', 'FWA', 'GSP', 'IAG', 'ISP',
#        'LEX', 'PIA', 'RFD', 'SBN', 'SGF', 'SPI', 'TOL', 'TYS', 'YNG'],
#       dtype=object)), ('L', 'ORD', array(['ABE', 'AVL', 'BGR', 'CHA', 'CID', 'DSM', 'ELM', 'FAR', 'FSD',
#        'FWA', 'GRR', 'GSO', 'GSP', 'HTS', 'IAG', 'LCK', 'LEX', 'MDT',
#        'MLI', 'PBG', 'PIA', 'RFD', 'ROA', 'SBN', 'SGF', 'SWF', 'SYR',
# ...
#        'HLN', 'IAD', 'IAH', 'ICT', 'IMT', 'IND', 'INL', 'ISN', 'JAX',
#        'JFK', 'LAN', 'LAS', 'LEX', 'LGA', 'LNK', 'LSE', 'MBS', 'MCI',
#        'MCO', 'MDW', 'MEM', 'MKE', 'MLI', 'MOT', 'MSN', 'MSO', 'NRT',
#        'OKC', 'OMA', 'ORF', 'PDX', 'PIA', 'PIT', 'PSC', 'PSP', 'RAP',
#        'RDU', 'RHI', 'RIC', 'ROC', 'RST', 'RSW', 'SAT', 'SBN', 'SDF',
#        'SJC', 'SLC', 'SMF', 'SNA', 'STL', 'SYR', 'TPA', 'TUL', 'TUS',
#        'TVC', 'TYS', 'XNA', 'YEG', 'YQR', 'YUL', 'YVR', 'YWG', 'YXE',
#        'YYC', 'OAK', 'PUJ', 'ATY'], dtype=object)), ('X', 'SFB', array(['BIM', 'ELH', 'EYW', 'FPO', 'GGT', 'GHB', 'MCO', 'MHH', 'TCB',
#        'TPA', 'CLT', 'DCA', 'DFW', 'ORD', 'PAP', 'PHL', 'PHX', 'YUL',
#        'YYZ', 'ATL', 'SEA', 'BOG', 'AUS', 'BDL', 'BOS', 'CUN', 'EWR',
#        'HPN', 'JFK', 'KIN', 'LAX', 'LGA', 'LIM', 'MBJ', 'MDE', 'NAS',
#        'ORH', 'POS', 'PUJ', 'PVD', 'RDU', 'RIC', 'SDQ', 'SFO', 'SJO',
#        'SJU', 'SWF', 'CVG', 'DTW', 'MSP', 'ARN', 'CPH', 'OSL', 'DEN',
#        'TTN', 'BWI', 'HOU', 'MKE', 'MSY', 'AVL', 'GSP', 'LEX', 'PBG',
#        'TYS', 'ACY', 'AUA', 'AXM', 'BQN', 'CTG', 'GUA', 'IAG', 'LAS',
#        'LBE', 'MGA', 'MYR', 'PTY', 'SAL', 'SAP', 'STI', 'STT', 'SXM',
#        'TLC', 'ZSA', 'CLE', 'IAD', 'IAH', 'ALB', 'BNA', 'BUF', 'CMH',
#        'IND', 'ISP', 'JAX', 'MCI', 'MDW', 'PIT', 'STL'], dtype=object)), ('X', 'SFB', array(['ABE', 'AVL', 'CID', 'CVG', 'DSM', 'FWA', 'GSP', 'IAG', 'ISP',
#        'LEX', 'PIA', 'RFD', 'SBN', 'SGF', 'SPI', 'TOL', 'TYS', 'YNG'],
#       dtype=object)), ('X', 'SFB', array(['ABE', 'AVL', 'BGR', 'CHA', 'CID', 'DSM', 'ELM', 'FAR', 'FSD',
#        'FWA', 'GRR', 'GSO', 'GSP', 'HTS', 'IAG', 'LCK', 'LEX', 'MDT',
#        'MLI', 'PBG', 'PIA', 'RFD', 'ROA', 'SBN', 'SGF', 'SWF', 'SYR',
#        'TOL', 'TRI', 'TYS', 'YNG'], dtype=object)), ('X', 'SFB', array(['KEF', 'ABE', 'ATW', 'AVL', 'AVP', 'BGR', 'BIS', 'BLV', 'BMI',
#        'BTV', 'CHA', 'CID', 'CKB', 'CVG', 'DSM', 'ELM', 'FAR', 'FSD',
#        'FWA', 'GFK', 'GRR', 'GSO', 'GSP', 'HGR', 'HTS', 'IAG', 'LAN',
#        'LCK', 'LEX', 'LIT', 'MDT', 'MLI', 'OKC', 'OWB', 'PBG', 'PHF',
#        'PSM', 'RFD', 'ROA', 'SBN', 'SGF', 'SPI', 'TOL', 'TRI', 'TUL',
#        'TYS', 'XNA', 'YNG', 'MIA'], dtype=object)), ('X', 'SFB', array(['CLT', 'DFW', 'DOH', 'LAX', 'LHR', 'MIA', 'ORD', 'PHL', 'PHX',
#        'MSY', 'YEG', 'YUL', 'YYC', 'YYZ', 'ATL', 'CDG', 'MEX', 'SEA',
#        'BOG', 'SAL', 'DXB', 'CUN', 'PEK', 'PTY', 'SFO', 'AMS', 'CVG',
#        'DTW', 'LGA', 'MEM', 'MSP', 'SLC', 'DEN', 'ICN', 'FRA', 'VCT',
#        'NRT', 'LAS', 'MCO', 'DME', 'IST', 'ABQ', 'ACA', 'ACY', 'AEX',
#        'AGU', 'AMA', 'AUS', 'BFL', 'BHM', 'BJX', 'BNA', 'BON', 'BOS',
#        'BRO', 'BTR', 'BWI', 'BZE', 'CAE', 'CCS', 'CHS', 'CLE', 'CLL',
#        'CME', 'CMH', 'COS', 'CRP', 'CRW', 'CUU', 'CZM', 'DAL', 'DCA',
#        'DGO', 'DSM', 'ELP', 'EWR', 'EZE', 'FLL', 'GCM', 'GDL', 'GIG',
#        'GJT', 'GPT', 'GRK', 'GRR', 'GRU', 'GSP', 'GUA', 'HNL', 'HOB',
#        'HRL', 'HSV', 'HUX', 'IAD', 'ICT', 'IND', 'JAN', 'JAX', 'LBB',
#        'LCH', 'LEX', 'LFT', 'LIM', 'LIR', 'LIT', 'LOS', 'LRD', 'MAF',
#        'MBJ', 'MCI', 'MFE', 'MGA', 'MID', 'MKE', 'MLM', 'MLU', 'MOB',
#        'MTY', 'MUC', 'NAS', 'OAX', 'OKC', 'OMA', 'ONT', 'ORF', 'PBC',
#        'PBI', 'PDX', 'PIT', 'PNS', 'POS', 'PSP', 'PVR', 'QRO', 'RDU',
#        'RIC', 'RSW', 'RTB', 'SAN', 'SAP', 'SAT', 'SAV', 'SDF', 'SHV',
#        'SJC', 'SJD', 'SJO', 'SJU', 'SLP', 'SLW', 'SMF', 'SNA', 'STL',
#        'TAM', 'TGU', 'TPA', 'TRC', 'TUL', 'TUS', 'TYR', 'TYS', 'UIO',
#        'VER', 'VPS', 'VSA', 'XNA', 'YVR', 'ZIH', 'ZLO'], dtype=object)), ('X', 'IAH', array(['LWB', 'MCN', 'MEI', 'MSL', 'PIB', 'TUP', 'AZO', 'CHA', 'CID',
#        'CRW', 'CVG', 'EVV', 'FWA', 'GSO', 'GSP', 'LAN', 'LEX', 'MBS',
#        'MSP', 'ROA', 'SYR', 'TYS', 'XNA', 'CLT', 'DFW', 'LHR', 'MIA',
#        'ORD', 'PHL', 'PHX', 'DEN', 'YYZ', 'ABE', 'ABQ', 'ABY', 'AEX',
#        'AGS', 'ALB', 'ATW', 'AUS', 'AVL', 'AVP', 'BDL', 'BHM', 'BMI',
#        'BNA', 'BOS', 'BQK', 'BRU', 'BTR', 'BTV', 'BUF', 'BWI', 'CAE',
#        'CAK', 'CDG', 'CHO', 'CHS', 'CLE', 'CMH', 'COS', 'CSG', 'CUN',
#        'CZM', 'DAB', 'DAL', 'DAY', 'DCA', 'DHN', 'DSM', 'DTW', 'DUB',
#        'DUS', 'ECP', 'ELP', 'EWN', 'EWR', 'EYW', 'FAY', 'FCO', 'FLL',
#        'FNT', 'FRA', 'FSM', 'GDL', 'GNV', 'GPT', 'GRB', 'GRK', 'GRR',
#        'GTR', 'HPN', 'HSV', 'IAD', 'IAH', 'ICT', 'ILM', 'IND', 'JAN',
#        'JAX', 'JFK', 'LAS', 'LAX', 'LFT', 'LGA', 'LIT', 'MAD', 'MAN',
#        'MCI', 'MCO', 'MDT', 'MDW', 'MEM', 'MEX', 'MGM', 'MHT', 'MKE',
#        'MLB', 'MLI', 'MLU', 'MOB', 'MSN', 'MSY', 'MTY', 'MUC', 'MYR',
#        'NAS', 'OAJ', 'OKC', 'OMA', 'ORF', 'PBI', 'PDX', 'PHF', 'PIA',
#        'PIT', 'PNS', 'PTY', 'PVD', 'PWM', 'RDU', 'RIC', 'ROC', 'RSW',
#        'SAN', 'SAT', 'SAV', 'SBN', 'SDF', 'SEA', 'SFO', 'SGF', 'SHV',
#        'SJO', 'SJU', 'SLC', 'SMF', 'SNA', 'SRQ', 'STL', 'STR', 'TLH',
#        'TPA', 'TRI', 'TUL', 'TUS', 'VLD', 'VPS', 'YUL', 'PVR', 'SJD',
#        'HOU', 'AMS', 'AUA', 'BDA', 'BJX', 'BOG', 'BON', 'BSB', 'BZE',
#        'CCS', 'DXB', 'EZE', 'FAR', 'FPO', 'FSD', 'GCM', 'GGT', 'GIG',
#        'GRU', 'GUA', 'HNL', 'ICN', 'JNB', 'KIN', 'LIM', 'LIR', 'LOS',
#        'MBJ', 'MGA', 'NRT', 'PAP', 'PLS', 'PUJ', 'RTB', 'SAL', 'SAP',
#        'SCL', 'SDQ', 'SJC', 'STT', 'SXM', 'TGU', 'UIO', 'UVF', 'ZRH',
#        'TTN'], dtype=object)), ('X', 'IAH', array(['CUR', 'ABE', 'AGS', 'ALB', 'ANU', 'ATL', 'AUA', 'AUS', 'AVL',
#        'AVP', 'BDL', 'BHM', 'BNA', 'BOS', 'BTR', 'BUF', 'BWI', 'BZE',
#        'CAE', 'CAK', 'CDG', 'CHA', 'CHO', 'CHS', 'CLE', 'CMH', 'CRW',
#        'CUN', 'CVG', 'CZM', 'DAB', 'DAY', 'DCA', 'DEN', 'DFW', 'DSM',
#        'DTW', 'DUB', 'EWN', 'EWR', 'FAY', 'FCO', 'FLL', 'FLO', 'FPO',
#        'FRA', 'GCM', 'GNV', 'GPT', 'GRU', 'GSO', 'GSP', 'HHH', 'HPN',
#        'HSV', 'HTS', 'IAD', 'IAH', 'ILM', 'IND', 'JAN', 'JAX', 'JFK',
#        'LAS', 'LAX', 'LEX', 'LGA', 'LHR', 'LIR', 'LIT', 'LYH', 'MBJ',
#        'MCI', 'MCO', 'MDT', 'MEM', 'MEX', 'MGM', 'MHT', 'MIA', 'MKE',
#        'MLB', 'MOB', 'MSP', 'MSY', 'MYR', 'NAS', 'OAJ', 'OMA', 'ORD',
#        'ORF', 'PBI', 'PDX', 'PGV', 'PHF', 'PHL', 'PHX', 'PIT', 'PLS',
#        'PNS', 'PUJ', 'PVD', 'PWM', 'RDU', 'RIC', 'ROA', 'ROC', 'RSW',
#        'SAN', 'SAT', 'SAV', 'SBY', 'SDF', 'SEA', 'SFO', 'SJD', 'SJO',
#        'SJU', 'SLC', 'SMF', 'SRQ', 'STL', 'STT', 'SXM', 'SYR', 'TLH',
#        'TPA', 'TRI', 'TYS', 'UVF', 'VPS', 'XNA', 'YOW', 'YUL', 'YYZ',
#        'TTN', 'MDW', 'MUC', 'LUK', 'GIG', 'HOU'], dtype=object)), ('X', 'IAH', array(['EZE', 'ABI', 'ABQ', 'ACT', 'AEX', 'AGU', 'AMA', 'ATL', 'AUS',
#        'BDL', 'BHM', 'BJX', 'BMI', 'BNA', 'BNE', 'BOG', 'BOS', 'BPT',
#        'BRO', 'BTR', 'BWI', 'BZE', 'CAE', 'CCS', 'CDG', 'CHA', 'CHS',
#        'CID', 'CLE', 'CLL', 'CLT', 'CMH', 'CMI', 'COS', 'COU', 'CRP',
#        'CRW', 'CUN', 'CUU', 'CVG', 'CZM', 'DAY', 'DCA', 'DEN', 'DRO',
#        'DSM', 'DTW', 'ELP', 'EVV', 'EWR', 'FAR', 'FAT', 'FLL', 'FRA',
#        'FSD', 'FSM', 'FWA', 'GCK', 'GDL', 'GGG', 'GIG', 'GJT', 'GPT',
#        'GRI', 'GRK', 'GRR', 'GRU', 'GSO', 'GSP', 'GUA', 'HNL', 'HOU',
#        'HSV', 'IAD', 'IAH', 'ICN', 'ICT', 'IND', 'JAN', 'JAX', 'JFK',
#        'JLN', 'LAS', 'LAW', 'LAX', 'LBB', 'LCH', 'LEX', 'LFT', 'LGA',
#        'LHR', 'LIM', 'LIR', 'LIT', 'LRD', 'MAD', 'MAF', 'MBJ', 'MCI',
#        'MCO', 'MEM', 'MEX', 'MFE', 'MGM', 'MHK', 'MIA', 'MKE', 'MLI',
#        'MLM', 'MLU', 'MOB', 'MSN', 'MSP', 'MSY', 'MTY', 'MZT', 'NAS',
#        'NRT', 'OGG', 'OKC', 'OMA', 'ONT', 'ORD', 'ORF', 'PBC', 'PBI',
#        'PDX', 'PHL', 'PHX', 'PIA', 'PIT', 'PLS', 'PNS', 'PSP', 'PTY',
#        'PVR', 'QRO', 'RAP', 'RDU', 'RIC', 'RNO', 'ROW', 'RSW', 'RTB',
#        'SAF', 'SAL', 'SAN', 'SAT', 'SAV', 'SCL', 'SDF', 'SEA', 'SFO',
#        'SGF', 'SHV', 'SJC', 'SJD', 'SJO', 'SJT', 'SJU', 'SLC', 'SLP',
#        'SMF', 'SNA', 'SPI', 'SPS', 'STL', 'TLH', 'TPA', 'TRC', 'TUL',
#        'TUS', 'TXK', 'TYR', 'TYS', 'VPS', 'XNA', 'YEG', 'YUL', 'YVR',
#        'YYC', 'YYZ', 'ZCL', 'DXB', 'AMS', 'MYR', 'OAK'], dtype=object)), ('X', 'IAH', array(['BRL', 'DEC', 'ABQ', 'ALO', 'AMM', 'ART', 'ATL', 'AUH', 'AUS',
#        'AZO', 'BDL', 'BMI', 'BNA', 'BOS', 'BUF', 'BWI', 'CDG', 'CHA',
#        'CHO', 'CID', 'CLE', 'CLT', 'CMH', 'CMI', 'COU', 'CUN', 'CVG',
#        'CWA', 'DAY', 'DBQ', 'DCA', 'DEN', 'DFW', 'DOH', 'DSM', 'DTW',
#        'DUB', 'DUS', 'ELP', 'EVV', 'EWR', 'FAR', 'FCO', 'FLL', 'FNT',
#        'FSD', 'FWA', 'GRB', 'GRR', 'HKG', 'HPN', 'HSV', 'IAH', 'ICT',
#        'IND', 'JAX', 'JFK', 'LAS', 'LAX', 'LEX', 'LGA', 'LHR', 'LIT',
#        'LSE', 'MAD', 'MAN', 'MBJ', 'MCI', 'MCO', 'MDT', 'MEM', 'MEX',
#        'MHK', 'MIA', 'MKE', 'MLI', 'MQT', 'MSN', 'MSP', 'MSY', 'NRT',
#        'OKC', 'OMA', 'PBI', 'PDX', 'PEK', 'PHL', 'PHX', 'PIA', 'PIT',
#        'PSP', 'PVG', 'PVR', 'RDU', 'RIC', 'RNO', 'ROC', 'RST', 'RSW',
#        'SAN', 'SAT', 'SDF', 'SEA', 'SFO', 'SGF', 'SJC', 'SJD', 'SJU',
#        'SLC', 'SNA', 'STL', 'SUX', 'SYR', 'TOL', 'TPA', 'TUL', 'TUS',
#        'TVC', 'TXL', 'TYS', 'XNA', 'YKF', 'YUL', 'YVR', 'YYC', 'YYZ',
#        'YEG', 'YHZ', 'YOW', 'YQB', 'YQR', 'YWG', 'YXU', 'DEL', 'GDL',
#        'ANC', 'SAL', 'PTY', 'AMS', 'ICN', 'PUJ', 'GCM', 'FRA', 'MUC',
#        'WAW', 'ZRH', 'ACY', 'MYR', 'OAK', 'VIE', 'ARN', 'CPH', 'BRU',
#        'IST', 'ABE', 'ALB', 'ATW', 'AVL', 'AVP', 'BHM', 'BOI', 'BTV',
#        'BZN', 'CAE', 'CAK', 'CHS', 'CMX', 'COS', 'CRW', 'DLH', 'EAU',
#        'ELM', 'FOE', 'GRU', 'GSO', 'GSP', 'HNL', 'IAD', 'JAN', 'LAN',
#        'LNK', 'MBS', 'MHT', 'MKG', 'MOB', 'MTY', 'NAS', 'OGG', 'ORF',
#        'PAH', 'PNS', 'PVD', 'PWM', 'RAP', 'ROA', 'SAV', 'SBN', 'SCE',
#        'SJO', 'SMF', 'SPI', 'SRQ', 'STC', 'STT', 'SXM', 'YXE'],
#       dtype=object)), ('X', 'IAH', array(['AGS', 'ALB', 'BDL', 'BGR', 'BHM', 'BNA', 'BOS', 'BTV', 'BUF',
#        'CAE', 'CAK', 'CHA', 'CHS', 'CLT', 'CMH', 'CRW', 'CVG', 'DAY',
#        'DFW', 'DSM', 'DTW', 'FAY', 'FLL', 'GSO', 'GSP', 'HHH', 'HPN',
#        'HSV', 'ILM', 'IND', 'ISP', 'JAN', 'JAX', 'JFK', 'LAS', 'LAX',
#        'LGA', 'LIT', 'MCI', 'MCO', 'MEM', 'MHT', 'MIA', 'MSP', 'MSY',
#        'MYR', 'NAS', 'OAJ', 'OMA', 'ORD', 'ORF', 'PBI', 'PDX', 'PHL',
#        'PHX', 'PIT', 'PNS', 'PVD', 'PWM', 'RDU', 'ROC', 'RSW', 'SAN',
#        'SAV', 'SDF', 'SRQ', 'STL', 'SYR', 'TLH', 'TPA', 'TYS', 'VPS',
#        'YHZ', 'YUL', 'YYZ', 'YOW', 'ATL', 'SEA', 'SJU', 'LEX', 'MSN',
#        'SLC', 'DEN', 'MKE', 'LAN', 'CLE', 'EWR', 'IAH', 'SFO', 'AUS',
#        'HOU'], dtype=object)), ('X', 'IAH', array(['MSY', 'CLT', 'DCA', 'DFW', 'LGA', 'MIA', 'ORD', 'PHL', 'PHX',
#        'YUL', 'YYZ', 'ATL', 'CDG', 'FRA', 'LHR', 'CUN', 'MEX', 'MTY',
#        'PDX', 'SAN', 'BOS', 'PEK', 'PVG', 'ABE', 'ALB', 'AMS', 'APN',
#        'ATW', 'AUS', 'AVL', 'AVP', 'AZO', 'BDL', 'BGM', 'BGR', 'BHM',
#        'BMI', 'BNA', 'BTV', 'BUF', 'BWI', 'CAE', 'CAK', 'CHA', 'CHS',
#        'CID', 'CIU', 'CLE', 'CMH', 'CRW', 'CVG', 'CWA', 'DAY', 'DEN',
#        'DSM', 'ELM', 'ERI', 'ESC', 'EVV', 'EWR', 'FLL', 'FWA', 'GCM',
#        'GRB', 'GRR', 'GRU', 'GSO', 'GSP', 'HPN', 'HSV', 'IAD', 'IAH',
#        'ICN', 'IND', 'ITH', 'JAX', 'JFK', 'LAN', 'LAS', 'LAX', 'LEX',
#        'LIT', 'MBJ', 'MBS', 'MCI', 'MCO', 'MDT', 'MDW', 'MEM', 'MHT',
#        'MKE', 'MLI', 'MQT', 'MSN', 'MSP', 'MYR', 'NAS', 'NGO', 'NRT',
#        'OKC', 'OMA', 'ORF', 'PBI', 'PIA', 'PIT', 'PLN', 'PUJ', 'PVD',
#        'PWM', 'RDU', 'RIC', 'ROA', 'ROC', 'RSW', 'SAT', 'SAV', 'SBN',
#        'SCE', 'SDF', 'SEA', 'SFO', 'SJU', 'SLC', 'STL', 'SWF', 'SYR',
#        'TPA', 'TUL', 'TVC', 'TYS', 'XNA', 'YOW', 'ILG', 'TTN', 'ACY'],
#       dtype=object)), ('X', 'IAH', array(['MSY', 'BNA', 'BOS', 'CHO', 'CLT', 'CMH', 'DAY', 'DCA', 'DFW',
#        'DTW', 'GSO', 'ILM', 'LIT', 'MIA', 'ORD', 'ORF', 'PBI', 'PHL',
#        'PIT', 'RDU', 'RIC', 'ROA', 'SDF', 'STL', 'TYS', 'XNA', 'YUL',
#        'YYZ', 'YOW', 'ATL', 'FLL', 'MCO', 'RSW', 'SRQ', 'TPA', 'AUA',
#        'BGR', 'BHM', 'BTV', 'BUF', 'CAE', 'CHS', 'CLE', 'CVG', 'DEN',
#        'DSM', 'EYW', 'GRR', 'GSP', 'IAH', 'IND', 'JAX', 'LEX', 'MCI',
#        'MEM', 'MHT', 'MKE', 'MSN', 'MSP', 'MYR', 'OMA', 'PWM', 'ROC',
#        'SAV', 'SYR', 'YHZ', 'CAK', 'MDW', 'IAD', 'HOU'], dtype=object)), ('X', 'IAH', array(['ATL', 'MSY', 'CLT', 'DCA', 'DFW', 'MIA', 'ORD', 'PHL', 'PHX',
#        'YYZ', 'CDG', 'LAX', 'LHR', 'SEA', 'SFO', 'CUN', 'SAN', 'ABQ',
#        'ABR', 'ALB', 'AMS', 'ANC', 'APN', 'ATW', 'AUS', 'AZO', 'BDL',
#        'BHM', 'BIL', 'BIS', 'BJI', 'BMI', 'BNA', 'BOI', 'BOS', 'BRD',
#        'BUF', 'BWI', 'BZN', 'CID', 'CLE', 'CMH', 'CVG', 'CWA', 'DAY',
#        'DEN', 'DIK', 'DLH', 'DSM', 'DTW', 'EWR', 'FAR', 'FCA', 'FLL',
#        'FNT', 'FSD', 'FWA', 'GEG', 'GFK', 'GRB', 'GRR', 'GTF', 'HIB',
#        'HLN', 'IAD', 'IAH', 'ICT', 'IMT', 'IND', 'INL', 'ISN', 'JAX',
#        'JFK', 'LAN', 'LAS', 'LEX', 'LGA', 'LNK', 'LSE', 'MBS', 'MCI',
#        'MCO', 'MDW', 'MEM', 'MKE', 'MLI', 'MOT', 'MSN', 'MSO', 'NRT',
#        'OKC', 'OMA', 'ORF', 'PDX', 'PIA', 'PIT', 'PSC', 'PSP', 'RAP',
#        'RDU', 'RHI', 'RIC', 'ROC', 'RST', 'RSW', 'SAT', 'SBN', 'SDF',
#        'SJC', 'SLC', 'SMF', 'SNA', 'STL', 'SYR', 'TPA', 'TUL', 'TUS',
#        'TVC', 'TYS', 'XNA', 'YEG', 'YQR', 'YUL', 'YVR', 'YWG', 'YXE',
#        'YYC', 'OAK', 'PUJ', 'ATY'], dtype=object)), ('X', 'IAH', array(['BIM', 'ELH', 'EYW', 'FPO', 'GGT', 'GHB', 'MCO', 'MHH', 'TCB',
#        'TPA', 'CLT', 'DCA', 'DFW', 'ORD', 'PAP', 'PHL', 'PHX', 'YUL',
#        'YYZ', 'ATL', 'SEA', 'BOG', 'AUS', 'BDL', 'BOS', 'CUN', 'EWR',
#        'HPN', 'JFK', 'KIN', 'LAX', 'LGA', 'LIM', 'MBJ', 'MDE', 'NAS',
#        'ORH', 'POS', 'PUJ', 'PVD', 'RDU', 'RIC', 'SDQ', 'SFO', 'SJO',
#        'SJU', 'SWF', 'CVG', 'DTW', 'MSP', 'ARN', 'CPH', 'OSL', 'DEN',
#        'TTN', 'BWI', 'HOU', 'MKE', 'MSY', 'AVL', 'GSP', 'LEX', 'PBG',
#        'TYS', 'ACY', 'AUA', 'AXM', 'BQN', 'CTG', 'GUA', 'IAG', 'LAS',
#        'LBE', 'MGA', 'MYR', 'PTY', 'SAL', 'SAP', 'STI', 'STT', 'SXM',
#        'TLC', 'ZSA', 'CLE', 'IAD', 'IAH', 'ALB', 'BNA', 'BUF', 'CMH',
#        'IND', 'ISP', 'JAX', 'MCI', 'MDW', 'PIT', 'STL'], dtype=object)), ('X', 'IAH', array(['ABE', 'AVL', 'CID', 'CVG', 'DSM', 'FWA', 'GSP', 'IAG', 'ISP',
#        'LEX', 'PIA', 'RFD', 'SBN', 'SGF', 'SPI', 'TOL', 'TYS', 'YNG'],
#       dtype=object)), ('X', 'IAH', array(['ABE', 'AVL', 'BGR', 'CHA', 'CID', 'DSM', 'ELM', 'FAR', 'FSD',
#        'FWA', 'GRR', 'GSO', 'GSP', 'HTS', 'IAG', 'LCK', 'LEX', 'MDT',
#        'MLI', 'PBG', 'PIA', 'RFD', 'ROA', 'SBN', 'SGF', 'SWF', 'SYR',
#        'TOL', 'TRI', 'TYS', 'YNG'], dtype=object)), ('X', 'IAH', array(['KEF', 'ABE', 'ATW', 'AVL', 'AVP', 'BGR', 'BIS', 'BLV', 'BMI',
#        'BTV', 'CHA', 'CID', 'CKB', 'CVG', 'DSM', 'ELM', 'FAR', 'FSD',
#        'FWA', 'GFK', 'GRR', 'GSO', 'GSP', 'HGR', 'HTS', 'IAG', 'LAN',
#        'LCK', 'LEX', 'LIT', 'MDT', 'MLI', 'OKC', 'OWB', 'PBG', 'PHF',
#        'PSM', 'RFD', 'ROA', 'SBN', 'SGF', 'SPI', 'TOL', 'TRI', 'TUL',
#        'TYS', 'XNA', 'YNG', 'MIA'], dtype=object)), ('X', 'IAH', array(['CLT', 'DFW', 'DOH', 'LAX', 'LHR', 'MIA', 'ORD', 'PHL', 'PHX',
#        'MSY', 'YEG', 'YUL', 'YYC', 'YYZ', 'ATL', 'CDG', 'MEX', 'SEA',
#        'BOG', 'SAL', 'DXB', 'CUN', 'PEK', 'PTY', 'SFO', 'AMS', 'CVG',
#        'DTW', 'LGA', 'MEM', 'MSP', 'SLC', 'DEN', 'ICN', 'FRA', 'VCT',
#        'NRT', 'LAS', 'MCO', 'DME', 'IST', 'ABQ', 'ACA', 'ACY', 'AEX',
#        'AGU', 'AMA', 'AUS', 'BFL', 'BHM', 'BJX', 'BNA', 'BON', 'BOS',
#        'BRO', 'BTR', 'BWI', 'BZE', 'CAE', 'CCS', 'CHS', 'CLE', 'CLL',
#        'CME', 'CMH', 'COS', 'CRP', 'CRW', 'CUU', 'CZM', 'DAL', 'DCA',
#        'DGO', 'DSM', 'ELP', 'EWR', 'EZE', 'FLL', 'GCM', 'GDL', 'GIG',
#        'GJT', 'GPT', 'GRK', 'GRR', 'GRU', 'GSP', 'GUA', 'HNL', 'HOB',
#        'HRL', 'HSV', 'HUX', 'IAD', 'ICT', 'IND', 'JAN', 'JAX', 'LBB',
#        'LCH', 'LEX', 'LFT', 'LIM', 'LIR', 'LIT', 'LOS', 'LRD', 'MAF',
#        'MBJ', 'MCI', 'MFE', 'MGA', 'MID', 'MKE', 'MLM', 'MLU', 'MOB',
#        'MTY', 'MUC', 'NAS', 'OAX', 'OKC', 'OMA', 'ONT', 'ORF', 'PBC',
#        'PBI', 'PDX', 'PIT', 'PNS', 'POS', 'PSP', 'PVR', 'QRO', 'RDU',
#        'RIC', 'RSW', 'RTB', 'SAN', 'SAP', 'SAT', 'SAV', 'SDF', 'SHV',
#        'SJC', 'SJD', 'SJO', 'SJU', 'SLP', 'SLW', 'SMF', 'SNA', 'STL',
#        'TAM', 'TGU', 'TPA', 'TRC', 'TUL', 'TUS', 'TYR', 'TYS', 'UIO',
#        'VER', 'VPS', 'VSA', 'XNA', 'YVR', 'ZIH', 'ZLO'], dtype=object))]

# %%
seconddesetination = [(routes[routes["DEST"].str.contains(x)].drop_duplicates("DEST")["DEST"].unique()) for x in firstdestination]

# %%
seconddesetination
# Out:
# [array(['ATL'], dtype=object),
#  array(['CLT'], dtype=object),
#  array(['DFW'], dtype=object),
#  array(['ORD'], dtype=object),
#  array(['DCA'], dtype=object),
#  array(['DTW'], dtype=object),
#  array(['LGA'], dtype=object),
#  array(['MSP'], dtype=object),
#  array(['FLL'], dtype=object),
#  array(['PGD'], dtype=object),
#  array(['PIE'], dtype=object),
#  array(['SFB'], dtype=object),
#  array(['IAH'], dtype=object)]

# %%
flyFromCity = "Lexington KY"
noTransfers = 2

# %%
dfSurLexRoutes = routes[routes['SOURCE'].str.contains("LEX")]
dfnotLexRoutes = routes[~routes["DEST"].str.contains("LEX", na=False)]
# Out:
#       AIRLINE  AIRLINE_ID SOURCE  SOURCE_ID DEST  DEST_ID CODESHARE  STOPS  \
# 0          2B       410.0    AER     2965.0  KZN   2990.0       NaN      0
# 1          2B       410.0    ASF     2966.0  KZN   2990.0       NaN      0
# 2          2B       410.0    ASF     2966.0  MRV   2962.0       NaN      0
# 3          2B       410.0    CEK     2968.0  KZN   2990.0       NaN      0
# 4          2B       410.0    CEK     2968.0  OVB   4078.0       NaN      0
# ...       ...         ...    ...        ...  ...      ...       ...    ...
# 67658      ZL      4178.0    WYA     6334.0  ADL   3341.0       NaN      0
# 67659      ZM     19016.0    DME     4029.0  FRU   2912.0       NaN      0
# 67660      ZM     19016.0    FRU     2912.0  DME   4029.0       NaN      0
# 67661      ZM     19016.0    FRU     2912.0  OSS   2913.0       NaN      0
# 67662      ZM     19016.0    OSS     2913.0  FRU   2912.0       NaN      0
#
#       EQUIPMENT
# 0           CR2
# 1           CR2
# 2           CR2
# 3           CR2
# 4           CR2
# ...         ...
# 67658       SF3
# 67659       734
# 67660       734
# 67661       734
# 67662       734
#
# [67643 rows x 9 columns]

# %%
# pd.merge(dfSourLexRoutes,dfDestLexRoutes,left_on='SOURCE', right_on='DEST', how='outer')[[]]
df1Share = pd.merge(dfSurLexRoutes,dfnotLexRoutes,left_on="DEST",right_on="SOURCE", how="inner",sort=True, suffixes=('_org', '_1'))
df2Share = pd.merge(df1Share,dfnotLexRoutes,left_on="DEST_1",right_on="SOURCE", how="inner",sort=True, suffixes=('_2', '_f'))
df2Share.to_csv("with2transfers.csv")

# %%
routes.head()
cUnique = set()

# %%
route_sub = routes[["SOURCE","DEST"]]

# %%
cUnique.add("LEX")
lexroutes = routes[routes["SOURCE"]=="LEX"].drop_duplicates(subset=["SOURCE","DEST"])[["SOURCE","DEST"]]
clist = lexroutes["DEST"].to_list()
cUnique = cUnique.union(clist)

# %%
xfer1 = pd.merge(lexroutes,route_sub,left_on="DEST",right_on="SOURCE", how="inner",suffixes=('_org', '_1'))
xfer1["drop"] = xfer1["DEST_1"].apply(lambda x: x in cUnique)
xfer1 = xfer1[xfer1["drop"]==True]
len(xfer1)
# Out:
# 402

# %%
xfer2 = pd.merge(xfer1,routes,how="inner",left_on="DEST_1", right_on="SOURCE")
xfer2.rename(columns={"SOURCE":"source_3", "DEST":"dest_3"})
# xfer2["drop"] = xfer2["dest_3"].apply(lambda x: x in cUnique)
# xfer2 = xfer2[xfer2["drop"]==True]
xfer2
# Out:
#        SOURCE_org DEST_org SOURCE_1 DEST_1  drop AIRLINE  AIRLINE_ID SOURCE  \
# 0             LEX      ATL      ATL    LEX  True      9E      3976.0    LEX
# 1             LEX      ATL      ATL    LEX  True      AA        24.0    LEX
# 2             LEX      ATL      ATL    LEX  True      AA        24.0    LEX
# 3             LEX      ATL      ATL    LEX  True      AA        24.0    LEX
# 4             LEX      ATL      ATL    LEX  True      AF       137.0    LEX
# ...           ...      ...      ...    ...   ...     ...         ...    ...
# 168705        LEX      IAH      IAH    ATL  True      WN      4547.0    ATL
# 168706        LEX      IAH      IAH    ATL  True      WN      4547.0    ATL
# 168707        LEX      IAH      IAH    ATL  True      WS      5416.0    ATL
# 168708        LEX      IAH      IAH    ATL  True      WS      5416.0    ATL
# 168709        LEX      IAH      IAH    ATL  True      WS      5416.0    ATL
#
#         SOURCE_ID DEST  DEST_ID CODESHARE  STOPS                    EQUIPMENT
# 0          4017.0  ATL   3682.0       NaN      0                          CRJ
# 1          4017.0  CLT   3876.0         Y      0                      CR7 CRJ
# 2          4017.0  DFW   3670.0         Y      0                      ERD ER4
# 3          4017.0  ORD   3830.0         Y      0                      ERD ER4
# 4          4017.0  ATL   3682.0         Y      0                      CRJ CR9
# ...           ...  ...      ...       ...    ...                          ...
# 168705     3682.0  STL   3678.0       NaN      0                      73W 733
# 168706     3682.0  TPA   3646.0       NaN      0                 73W  733 73C
# 168707     3682.0  JFK   3797.0         Y      0                          738
# 168708     3682.0  LGA   3697.0         Y      0  320 757 M88 738 739 73H 73W
# 168709     3682.0  YYZ    193.0         Y      0                      CR7 CR9
#
# [168710 rows x 14 columns]
